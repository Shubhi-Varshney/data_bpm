# %%
import pandas as pd
import os.path as Path
import numpy as np
import string as str
import unicodedata

# %%
def first_non_null(series):
    '''
    Utility function to get the first non-null value
    '''
    return series.dropna().iloc[0] if not series.dropna().empty else None


def process_name(name):
    '''
    Utility function to process names
    '''
    # replace NaN with an empty string
    if pd.isna(name):
        return ''
    # strip dots and spaces and get only the longest/first word
    words = name.lower().strip(" .").split()

    # Initialize variables to keep track of the longest word
    longest_word = ''
    longest_length = 0

    # Iterate through each word
    for word in words:
        # If the current word is longer than the longest word found so far, or if it's equal in length but appears earlier
        if len(word) > longest_length or (len(word) == longest_length and words.index(word) < words.index(longest_word)):
            longest_word = word
            longest_length = len(word)

    # Normalize the string to decomposed Unicode form
    normalized_s = unicodedata.normalize('NFD', longest_word)

    # Remove non-spacing marks (special characters)
    stripped_s = ''.join(c for c in normalized_s if unicodedata.category(c) != 'Mn')

    return stripped_s

# %%
data_events_ppl = pd.read_csv(Path.join("..", "raw_data", "raw_all.csv"))
data_events_ppl
# Out:
#       Event    First Name    Surname                       Email  \
# 0         2       Patrick     Beeker    patrick.beeker@gmail.com
# 1         2         Teena     Kumari         teena2768@gmail.com
# 2         2         Nesha       Siwi              i@neshasiwi.de
# 3         2  Shuvam kumar        Sah   shuvamshah98152@gmail.com
# 4         2         Ayman   Chalhoub            aymanc@gmail.com
# ...     ...           ...        ...                         ...
# 1199      7           Ira  Sheveleva  hiirinasheveleva@gmail.com
# 1200      7       Dominik     Wenzel  Dominik.wenzel@outlook.com
# 1201      7         Marta  Osowiecka     m.osowiecka.m@gmail.com
# 1202      7        akshay       rote       akshay.rote@gmail.com
# 1203      7      Johannes    Caspari        johannes@caspari5.de
#
#      Attendee Status Your Job Position Choose your role Choose your role.1  \
# 0          Attending           Product  Product Manager                NaN
# 1          Attending           Product  Product Manager                NaN
# 2          Attending            Design              NaN                NaN
# 3          Attending           Student              NaN                NaN
# 4          Attending     Founder / CXO              NaN                NaN
# ...              ...               ...              ...                ...
# 1199      Checked In         Marketing              NaN  Product Marketing
# 1200      Checked In           Product  Product Manager                NaN
# 1201      Checked In            Design              NaN                NaN
# 1202   Not Attending               NaN              NaN                NaN
# 1203      Checked In     Founder / CxO              NaN                NaN
#
#      Seniority How did you hear from us?             Company Rain      Day
# 0          NaN          BPM Meetup group      Smartbroker AG  Yes  Tuesday
# 1          NaN                  LinkedIn  World simplifed Ug  Yes  Tuesday
# 2          NaN                  LinkedIn          Freelancer  Yes  Tuesday
# 3          NaN          BPM Meetup group                ATEM  Yes  Tuesday
# 4          NaN        Lenny's Newsletter               Clink  Yes  Tuesday
# ...        ...                       ...                 ...  ...      ...
# 1199       NaN  Word of Mouth / Referral             Sticked   No  Tuesday
# 1200       NaN         Handpicked Berlin          OpenToWork   No  Tuesday
# 1201       NaN  Word of Mouth / Referral                SWAP   No  Tuesday
# 1202       NaN                       NaN        PAIR Finance   No  Tuesday
# 1203       NaN     I know the organizers               Meryt   No  Tuesday
#
# [1204 rows x 13 columns]

# %%
data_scraped = pd.read_csv(Path.join("..", "raw_data", "raw_scrapped.csv"))
data_scraped
# Out:
#                                                    url  \
# 0       https://linkedin.com/in/patrick-beeker-4673311
# 1       https://linkedin.com/in/teena-kumari-0b8359271
# 2              https://linkedin.com/in/mischagawronski
# 3    https://linkedin.com/in/shuvam-kumar-sah-88590...
# 4                     https://linkedin.com/in/chalhoub
# ..                                                 ...
# 676                 https://linkedin.com/in/alikhanmba
# 677               https://linkedin.com/in/daniellopezc
# 678           https://linkedin.com/in/rim-bensouf-link
# 679               https://linkedin.com/in/oguzcelikada
# 680              https://linkedin.com/in/althafalim/de
#
#                                                  title  \
# 0                                       Patrick Beeker
# 1    Teena Kumari – Tech product support intern – H...
# 2     Mischa Gawronski – Creative Director – Freelance
# 3                      Shuvam Kumar Sah – Web Designer
# 4                               Ayman Chalhoub - Clink
# ..                                                 ...
# 676                Ali Akbar Khan, MBA - Delivery Hero
# 677              Daniel López Contreras - Masterschool
# 678       Rim Bensouf - Product Owner - SPORTTOTAL ...
# 679        Oguz Celikada – Berlin, Berlin, Deutschland
# 680              Althaf Ali Mattummathodi - Schaeffler
#
#                                     linkedinProfileUrl email  \
# 0    https://www.linkedin.com/in/patrick-beeker-467...   NaN
# 1    https://www.linkedin.com/in/teena-kumari-0b835...   NaN
# 2         https://www.linkedin.com/in/mischagawronski/   NaN
# 3    https://www.linkedin.com/in/shuvam-kumar-sah-8...   NaN
# 4                https://www.linkedin.com/in/chalhoub/   NaN
# ..                                                 ...   ...
# 676            https://www.linkedin.com/in/alikhanmba/   NaN
# 677          https://www.linkedin.com/in/daniellopezc/   NaN
# 678      https://www.linkedin.com/in/rim-bensouf-link/   NaN
# 679          https://www.linkedin.com/in/oguzcelikada/   NaN
# 680                                                NaN   NaN
#
#                                        linkedinProfile  \
# 0    https://www.linkedin.com/in/patrick-beeker-467...
# 1    https://www.linkedin.com/in/teena-kumari-0b835...
# 2         https://www.linkedin.com/in/mischagawronski/
# 3    https://www.linkedin.com/in/shuvam-kumar-sah-8...
# 4                https://www.linkedin.com/in/chalhoub/
# ..                                                 ...
# 676            https://www.linkedin.com/in/alikhanmba/
# 677          https://www.linkedin.com/in/daniellopezc/
# 678      https://www.linkedin.com/in/rim-bensouf-link/
# 679          https://www.linkedin.com/in/oguzcelikada/
# 680                                                NaN
#
#                                            description  \
# 0    Experienced professional with the ability to c...
# 1    I am a Product Owner at World Simplified UG, a...
# 2    Passionate and challenging influencer in strat...
# 3    Designer & Problem Solver | CS Student | Aimin...
# 4                                                  NaN
# ..                                                 ...
# 676  Experienced CX and E-Commerce professional, wi...
# 677  - 100% Customer oriented professional\n- Stron...
# 678                                                NaN
# 679  Experienced professional in human-centric busi...
# 680                                                NaN
#
#                                               headline  \
# 0    General Manager - US Finance, Legal, HR, Accou...
# 1                Tech product support intern at Holidu
# 2                      IGP Network | Creative Director
# 3                 Making Interfaces Sexier - UI/UX/Dev
# 4                                     Product & Growth
# ..                                                 ...
# 676                         Global Customer Experience
# 677  Transforming Education, Customer Focused, avid...
# 678  Product Owner at Sporttotal.tv\n\nAgile leader...
# 679                         Digital Product Consultant
# 680                      R&D E-mobility at Schaeffler
#
#                              location     firstName         lastName  ...  \
# 0    Carrollton, Texas, United States       Patrick           Beeker  ...
# 1             Berlin, Berlin, Germany         Teena           Kumari  ...
# 2             Berlin, Berlin, Germany        Mischa        Gawronski  ...
# 3             Berlin, Berlin, Germany  Shuvam Kumar              Sah  ...
# 4             Berlin, Berlin, Germany         Ayman         Chalhoub  ...
# ..                                ...           ...              ...  ...
# 676           Berlin, Berlin, Germany     Ali Akbar        Khan, MBA  ...
# 677           Berlin, Berlin, Germany        Daniel  López Contreras  ...
# 678          Berlin Metropolitan Area           Rim          Bensouf  ...
# 679           Berlin, Berlin, Germany          Oguz         Celikada  ...
# 680          Berlin Metropolitan Area    Althaf Ali    Mattummathodi  ...
#
#     subscribers                              mutualConnectionsText  \
# 0           NaN                                                NaN
# 1        1148.0  Carlo Cantarini, Thomas Hartmann, and 28 other...
# 2         149.0                                                NaN
# 3         467.0  🤖 Leon Meier and Nisha Kumari are mutual conne...
# 4        1975.0  Torben Schulz, Sonya Pobiedimska, and 2 other ...
# ..          ...                                                ...
# 676         NaN  Nick Mulder, Matteo Fava, and 1 other mutual c...
# 677      3160.0  Marie NEANG, Fabian Tröltzsch, and 39 other mu...
# 678       153.0              Maurice Dücker is a mutual connection
# 679       711.0  Tim Herbig, Mikhail Grinberg, and 4 other mutu...
# 680      1941.0  Andrea Franke, Andreas Weinberger, and 12 othe...
#
#                                                 imgUrl  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://media.licdn.com/dms/image/C5603AQHb9Mw...
# 3    https://media.licdn.com/dms/image/D4E03AQFcJ48...
# 4                                                  NaN
# ..                                                 ...
# 676  https://media.licdn.com/dms/image/C4E03AQHwf7j...
# 677  https://media.licdn.com/dms/image/C4E03AQF_30k...
# 678  https://media.licdn.com/dms/image/D4E03AQH2OhG...
# 679  https://media.licdn.com/dms/image/C4D03AQGbpHK...
# 680  https://media.licdn.com/dms/image/D5603AQFbJKt...
#
#                      website mail  connectedOn error phoneNumber  \
# 0                        NaN  NaN          NaN   NaN         NaN
# 1                        NaN  NaN          NaN   NaN         NaN
# 2                        NaN  NaN          NaN   NaN         NaN
# 3    dribbble.com/shuvam_sah  NaN          NaN   NaN         NaN
# 4                        NaN  NaN          NaN   NaN         NaN
# ..                       ...  ...          ...   ...         ...
# 676                      NaN  NaN          NaN   NaN         NaN
# 677                      NaN  NaN          NaN   NaN         NaN
# 678                      NaN  NaN          NaN   NaN         NaN
# 679                      NaN  NaN          NaN   NaN         NaN
# 680                      NaN  NaN          NaN   NaN         NaN
#
#     partialScreenshot facebookUrl
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# ..                ...         ...
# 676               NaN         NaN
# 677               NaN         NaN
# 678               NaN         NaN
# 679               NaN         NaN
# 680               NaN         NaN
#
# [681 rows x 69 columns]

# %%
data_events_ppl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204 entries, 0 to 1203
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Event                      1204 non-null   int64
#  1   First Name                 1204 non-null   object
#  2   Surname                    1204 non-null   object
#  3   Email                      1204 non-null   object
#  4   Attendee Status            1204 non-null   object
#  5   Your Job Position          706 non-null    object
#  6   Choose your role           477 non-null    object
#  7   Choose your role.1         85 non-null     object
#  8   Seniority                  62 non-null     object
#  9   How did you hear from us?  766 non-null    object
#  10  Company                    1127 non-null   object
#  11  Rain                       1204 non-null   object
#  12  Day                        1204 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 122.4+ KB

# %%
data_events_ppl["First Name"] = data_events_ppl["First Name"].apply(process_name)
data_events_ppl["Surname"] = data_events_ppl["Surname"].apply(process_name)
data_events_ppl["fullName"] = data_events_ppl["First Name"] + ' ' + data_events_ppl["Surname"]

data_events_ppl['Email'] = data_events_ppl['Email'].str.lower()
data_events_ppl['Company'] = data_events_ppl["Company"].apply(process_name)

# Create DF with unique IDs------------------------------

# Define custom function to get the first non-null value
def first_non_null(series):
    return series.dropna().iloc[0] if not series.dropna().empty else np.nan

# Columns where you want to apply the first_non_null function
columns_to_agg = ['First Name',
                  'Surname',
                  'fullName',
                  'Company',
                  'Your Job Position',
                  'Choose your role',
                  'Choose your role.1',
                  'Seniority'
                  ]

# %%
data_events_ppl.sample(20)
# Out:
#       Event   First Name            Surname                             Email  \
# 472       3         miji                lee           miji.lee.kr@hotmail.com
# 755       5       esther              vidal           hello@markos-esther.com
# 1169      7        elena                  t            tuzhikova.el@gmail.com
# 373       3        elisa               song          elisa.shanghai@gmail.com
# 674       5         lara             orrico              orricolara@gmail.com
# 399       3     catarina              pinto            catarinapp24@gmail.com
# 524       4       balaji              alagu             balaji.alagu@kenjo.io
# 527       4        janet                mao             janet.w.mao@gmail.com
# 910       6       vitali              kotik               talkotick@gmail.com
# 191       2       lilika  schulte-ostermann         lilikamagdalena@gmail.com
# 764       5  abdelrahman              elfar       abdelrahman.alfar@gmail.com
# 294       1        annie                 li               annie.li@figures.hr
# 699       5          ewa              kiwus                ewakiwus@gmail.com
# 975       6       halina          tkaczenko              halina.tkc@gmail.com
# 412       3         jiun                 lu            nicolelu1109@gmail.com
# 534       4        dalma              szabo                 dszabo@babbel.com
# 1180      7        jules           nijskens            jls.nijskens@gmail.com
# 495       4       daniil            tykheev        daniil.tykheev@hygraph.com
# 903       6        yusuf     pirlibeylioglu  yusufcanpirlibeylioglu@gmail.com
# 228       1     svitlana             khimka               s.s.himka@gmail.com
#
#      Attendee Status Your Job Position Choose your role Choose your role.1  \
# 472       Checked In    Data Analytics              NaN                NaN
# 755       Checked In            Design              NaN                NaN
# 1169      Checked In           Product  Product Manager                NaN
# 373        Attending    Data Analytics              NaN                NaN
# 674    Not Attending               NaN              NaN                NaN
# 399        Attending           Product              NaN    Product Manager
# 524    Not Attending               NaN              NaN                NaN
# 527    Not Attending               NaN              NaN                NaN
# 910    Not Attending               NaN              NaN                NaN
# 191       Checked In            Design              NaN                NaN
# 764       Checked In           Product  Product Manager                NaN
# 294    Not Attending               NaN              NaN                NaN
# 699    Not Attending               NaN              NaN                NaN
# 975       Checked In             Other              NaN                NaN
# 412    Not Attending               NaN              NaN                NaN
# 534    Not Attending               NaN              NaN                NaN
# 1180      Checked In           Product  Product Manager                NaN
# 495        Attending           Product  Product Manager                NaN
# 903    Not Attending               NaN              NaN                NaN
# 228        Attending               NaN              NaN                NaN
#
#      Seniority How did you hear from us?        Company Rain       Day  \
# 472        NaN                  LinkedIn     lieferando  Yes  Thursday
# 755        NaN          BPM Meetup group  markos-esther   No  Thursday
# 1169       NaN        Lenny's Newsletter      freelance   No   Tuesday
# 373        NaN           FOMO Newsletter     freelancer  Yes  Thursday
# 674        NaN                       NaN        product   No  Thursday
# 399        NaN  Word of Mouth / Referral          tesla  Yes  Thursday
# 524        NaN                       NaN          kenjo   No   Tuesday
# 527        NaN                       NaN       blinkist   No   Tuesday
# 910        NaN                       NaN           bolt  Yes  Thursday
# 191        NaN          BPM Meetup group         d-labs  Yes   Tuesday
# 764        NaN                  LinkedIn            sap   No  Thursday
# 294        NaN                       NaN                  No  Thursday
# 699        NaN                       NaN         recare   No  Thursday
# 975        NaN        WhatsApp Community           jido  Yes  Thursday
# 412        NaN                       NaN         berlin  Yes  Thursday
# 534        NaN                       NaN         babbel   No   Tuesday
# 1180       NaN                  LinkedIn       delivery   No   Tuesday
# 495        NaN        Lenny's Newsletter        hygraph   No   Tuesday
# 903        NaN                       NaN         pepper  Yes  Thursday
# 228        NaN                       NaN                  No  Thursday
#
#                       fullName
# 472                   miji lee
# 755               esther vidal
# 1169                   elena t
# 373                 elisa song
# 674                lara orrico
# 399             catarina pinto
# 524               balaji alagu
# 527                  janet mao
# 910               vitali kotik
# 191   lilika schulte-ostermann
# 764          abdelrahman elfar
# 294                   annie li
# 699                  ewa kiwus
# 975           halina tkaczenko
# 412                    jiun lu
# 534                dalma szabo
# 1180            jules nijskens
# 495             daniil tykheev
# 903       yusuf pirlibeylioglu
# 228            svitlana khimka

# %%
# Create a dictionary to specify aggregation functions for each column
agg_dict = {'Event': 'count'}
agg_dict.update({column: first_non_null for column in columns_to_agg})

# Group by 'fullName' and apply aggregation
unique_attendees = data_events_ppl.groupby(by='Email', as_index=False).agg(agg_dict)
unique_attendees["numEvents"] = unique_attendees.Event

# %%
unique_attendees
# Out:
#                                    Email  Event  First Name     Surname  \
# 0               01hub_gilders@icloud.com      2      marcin    belinski
# 1                1cmarcosrubio@gmail.com      1      marcos       rubio
# 2    4rz27gdtzp@privaterelay.appleid.com      3      marcin    belinski
# 3    4srk9xfkmw@privaterelay.appleid.com      3     mikhail    grinberg
# 4    9gfz8fnsm4@privaterelay.appleid.com      1       myles     sutholt
# ..                                   ...    ...         ...         ...
# 813                 zahrarouhi@gmail.com      1       zahra       rouhi
# 814                    zajczik@gmail.com      1         ola       zajac
# 815                zaron.arava@gmail.com      1       zaron       arava
# 816       zimmermannjennifer43@gmail.com      1  zimmermann    jennifer
# 817                zulfia@malyshenko.com      5     zulfiya  malyshenko
#
#                 fullName    Company Your Job Position Choose your role  \
# 0        marcin belinski  insurance           Product  Product Manager
# 1           marcos rubio     tucuvi               NaN              NaN
# 2        marcin belinski  insurance           Product  Product Manager
# 3       mikhail grinberg    looking           Product  Product Manager
# 4          myles sutholt  talent.io           Product  Head of Product
# ..                   ...        ...               ...              ...
# 813          zahra rouhi  yumlister            Design              NaN
# 814            ola zajac    zalando           Product  Product Manager
# 815          zaron arava        xxx             Other              NaN
# 816  zimmermann jennifer      gsgsg             Other              NaN
# 817   zulfiya malyshenko                      Product  Product Manager
#
#     Choose your role.1 Seniority  numEvents
# 0                  NaN       NaN          2
# 1                  NaN       NaN          1
# 2      Product Manager       NaN          3
# 3      Product Manager       NaN          3
# 4                  NaN       NaN          1
# ..                 ...       ...        ...
# 813                NaN       NaN          1
# 814                NaN       NaN          1
# 815                NaN       NaN          1
# 816                NaN       NaN          1
# 817                NaN       NaN          5
#
# [818 rows x 11 columns]

# %%
# Index in this table is now the user ID
unique_attendees['UserID'] = unique_attendees.index

# we have numEvents now instead
unique_attendees = unique_attendees.drop(labels='Event',axis=1)
unique_attendees["Company"] = unique_attendees["Company"].apply(process_name)

# %%
# Replace suspicious and empty strings in the Company name with NaNs
to_replace_list = ['','none','xxx','-','tbd','123','n','na','x','--','looking','gsgsg']
unique_attendees['Company'].replace(to_replace_list, np.nan, inplace=True)
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/4213797246.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   unique_attendees['Company'].replace(to_replace_list, np.nan, inplace=True)

# %%
unique_attendees
# Out:
#                                    Email  First Name     Surname  \
# 0               01hub_gilders@icloud.com      marcin    belinski
# 1                1cmarcosrubio@gmail.com      marcos       rubio
# 2    4rz27gdtzp@privaterelay.appleid.com      marcin    belinski
# 3    4srk9xfkmw@privaterelay.appleid.com     mikhail    grinberg
# 4    9gfz8fnsm4@privaterelay.appleid.com       myles     sutholt
# ..                                   ...         ...         ...
# 813                 zahrarouhi@gmail.com       zahra       rouhi
# 814                    zajczik@gmail.com         ola       zajac
# 815                zaron.arava@gmail.com       zaron       arava
# 816       zimmermannjennifer43@gmail.com  zimmermann    jennifer
# 817                zulfia@malyshenko.com     zulfiya  malyshenko
#
#                 fullName    Company Your Job Position Choose your role  \
# 0        marcin belinski  insurance           Product  Product Manager
# 1           marcos rubio     tucuvi               NaN              NaN
# 2        marcin belinski  insurance           Product  Product Manager
# 3       mikhail grinberg        NaN           Product  Product Manager
# 4          myles sutholt  talent.io           Product  Head of Product
# ..                   ...        ...               ...              ...
# 813          zahra rouhi  yumlister            Design              NaN
# 814            ola zajac    zalando           Product  Product Manager
# 815          zaron arava        NaN             Other              NaN
# 816  zimmermann jennifer        NaN             Other              NaN
# 817   zulfiya malyshenko        NaN           Product  Product Manager
#
#     Choose your role.1 Seniority  numEvents  UserID
# 0                  NaN       NaN          2       0
# 1                  NaN       NaN          1       1
# 2      Product Manager       NaN          3       2
# 3      Product Manager       NaN          3       3
# 4                  NaN       NaN          1       4
# ..                 ...       ...        ...     ...
# 813                NaN       NaN          1     813
# 814                NaN       NaN          1     814
# 815                NaN       NaN          1     815
# 816                NaN       NaN          1     816
# 817                NaN       NaN          5     817
#
# [818 rows x 11 columns]

# %%
# Try to aggregate one more time according to the full name - in case the person used different emails
agg_dict = {'numEvents': 'sum'}

# Columns where you want to apply the first_non_null function
columns_to_agg2 = ['First Name',
                  'Surname',
                  'Email',
                  'Company',
                  'Your Job Position',
                  'Choose your role',
                  'Choose your role.1',
                  'Seniority'
                  ]
agg_dict.update({column: first_non_null for column in columns_to_agg2})

# Group by 'fullName' and apply aggregation
unique_attendees2 = unique_attendees.groupby(by='fullName', as_index=False).agg(agg_dict)
unique_attendees2
# Out:
#                 fullName  numEvents   First Name      Surname  \
# 0      abdelrahman elfar          2  abdelrahman        elfar
# 1             abdo wahba          1         abdo        wahba
# 2            abhi kasoju          1         abhi       kasoju
# 3       abhishek agarwal          1     abhishek      agarwal
# 4        abhishek khatri          1     abhishek       khatri
# ..                   ...        ...          ...          ...
# 776  zimmermann jennifer          1   zimmermann     jennifer
# 777    ziyad mohiyudheen          2        ziyad  mohiyudheen
# 778            zsolt pap          1        zsolt          pap
# 779        zsolt szrapko          1        zsolt      szrapko
# 780   zulfiya malyshenko          5      zulfiya   malyshenko
#
#                                   Email     Company Your Job Position  \
# 0           abdelrahman.alfar@gmail.com         sap       Engineering
# 1           abdelrahman.wahba@gmail.com         NaN               NaN
# 2             kasoju.abhinaya@gmail.com        care    Data Analytics
# 3                aggyabhishek@gmail.com  appreciate     Founder / CXO
# 4            abhishekkhatri@hotmail.com     zalando             Other
# ..                                  ...         ...               ...
# 776      zimmermannjennifer43@gmail.com         NaN             Other
# 777                   mmziyad@gmail.com         NaN               NaN
# 778             papjanoszsolt@yahoo.com       axkro               NaN
# 779  szrapko.zsolt+eventbrite@gmail.com        goto           Product
# 780               zulfia@malyshenko.com         NaN           Product
#
#       Choose your role Choose your role.1 Seniority
# 0      Product Manager                NaN       NaN
# 1                  NaN                NaN       NaN
# 2                  NaN                NaN       NaN
# 3                  NaN                NaN       NaN
# 4                  NaN                NaN       NaN
# ..                 ...                ...       ...
# 776                NaN                NaN       NaN
# 777                NaN                NaN       NaN
# 778  eCommerce Manager                NaN       NaN
# 779    Product Manager                NaN       NaN
# 780    Product Manager                NaN       NaN
#
# [781 rows x 10 columns]

# %%
unique_attendees2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fullName            781 non-null    object
#  1   numEvents           781 non-null    int64
#  2   First Name          781 non-null    object
#  3   Surname             781 non-null    object
#  4   Email               781 non-null    object
#  5   Company             705 non-null    object
#  6   Your Job Position   523 non-null    object
#  7   Choose your role    364 non-null    object
#  8   Choose your role.1  77 non-null     object
#  9   Seniority           55 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 61.1+ KB

# %%
# Index in this table is now the user ID
unique_attendees2['UserID'] = unique_attendees2.index

# %%
data_scraped.dropna(subset=['url'], inplace=True)
data_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 668 entries, 0 to 680
# Data columns (total 69 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url                        668 non-null    object
#  1   title                      668 non-null    object
#  2   linkedinProfileUrl         617 non-null    object
#  3   email                      172 non-null    object
#  4   linkedinProfile            617 non-null    object
#  5   description                469 non-null    object
#  6   headline                   656 non-null    object
#  7   location                   656 non-null    object
#  8   firstName                  656 non-null    object
#  9   lastName                   656 non-null    object
#  10  fullName                   656 non-null    object
#  11  connectionDegree           656 non-null    object
#  12  vmid                       656 non-null    object
#  13  userId                     656 non-null    float64
#  14  linkedinSalesNavigatorUrl  656 non-null    object
#  15  connectionsCount           607 non-null    float64
#  16  connectionsUrl             656 non-null    object
#  17  mutualConnectionsUrl       656 non-null    object
#  18  company                    645 non-null    object
#  19  companyUrl                 583 non-null    object
#  20  jobTitle                   644 non-null    object
#  21  jobDescription             412 non-null    object
#  22  jobLocation                546 non-null    object
#  23  jobDateRange               635 non-null    object
#  24  jobDuration                634 non-null    object
#  25  company2                   628 non-null    object
#  26  companyUrl2                570 non-null    object
#  27  jobTitle2                  627 non-null    object
#  28  jobDescription2            499 non-null    object
#  29  jobLocation2               530 non-null    object
#  30  jobDateRange2              627 non-null    object
#  31  jobDuration2               626 non-null    object
#  32  school                     630 non-null    object
#  33  schoolUrl                  570 non-null    object
#  34  schoolDegree               616 non-null    object
#  35  schoolDescription          301 non-null    object
#  36  schoolDateRange            579 non-null    object
#  37  school2                    532 non-null    object
#  38  schoolUrl2                 449 non-null    object
#  39  schoolDegree2              514 non-null    object
#  40  schoolDescription2         229 non-null    object
#  41  schoolDateRange2           483 non-null    object
#  42  birthday                   259 non-null    object
#  43  allSkills                  623 non-null    object
#  44  skill1                     623 non-null    object
#  45  endorsement1               366 non-null    float64
#  46  skill2                     621 non-null    object
#  47  endorsement2               384 non-null    float64
#  48  skill3                     619 non-null    object
#  49  endorsement3               369 non-null    float64
#  50  skill4                     615 non-null    object
#  51  endorsement4               353 non-null    float64
#  52  skill5                     612 non-null    object
#  53  endorsement5               356 non-null    float64
#  54  skill6                     608 non-null    object
#  55  endorsement6               373 non-null    float64
#  56  baseUrl                    668 non-null    object
#  57  profileId                  656 non-null    object
#  58  timestamp                  668 non-null    object
#  59  subscribers                579 non-null    float64
#  60  mutualConnectionsText      565 non-null    object
#  61  imgUrl                     625 non-null    object
#  62  website                    165 non-null    object
#  63  mail                       172 non-null    object
#  64  connectedOn                177 non-null    object
#  65  error                      2 non-null      object
#  66  phoneNumber                30 non-null     object
#  67  partialScreenshot          409 non-null    object
#  68  facebookUrl                1 non-null      object
# dtypes: float64(9), object(60)
# memory usage: 365.3+ KB

# %%
data_scraped = data_scraped[data_scraped['error'].isnull()]
data_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 666 entries, 0 to 680
# Data columns (total 69 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url                        666 non-null    object
#  1   title                      666 non-null    object
#  2   linkedinProfileUrl         615 non-null    object
#  3   email                      172 non-null    object
#  4   linkedinProfile            615 non-null    object
#  5   description                469 non-null    object
#  6   headline                   656 non-null    object
#  7   location                   656 non-null    object
#  8   firstName                  656 non-null    object
#  9   lastName                   656 non-null    object
#  10  fullName                   656 non-null    object
#  11  connectionDegree           656 non-null    object
#  12  vmid                       656 non-null    object
#  13  userId                     656 non-null    float64
#  14  linkedinSalesNavigatorUrl  656 non-null    object
#  15  connectionsCount           607 non-null    float64
#  16  connectionsUrl             656 non-null    object
#  17  mutualConnectionsUrl       656 non-null    object
#  18  company                    645 non-null    object
#  19  companyUrl                 583 non-null    object
#  20  jobTitle                   644 non-null    object
#  21  jobDescription             412 non-null    object
#  22  jobLocation                546 non-null    object
#  23  jobDateRange               635 non-null    object
#  24  jobDuration                634 non-null    object
#  25  company2                   628 non-null    object
#  26  companyUrl2                570 non-null    object
#  27  jobTitle2                  627 non-null    object
#  28  jobDescription2            499 non-null    object
#  29  jobLocation2               530 non-null    object
#  30  jobDateRange2              627 non-null    object
#  31  jobDuration2               626 non-null    object
#  32  school                     630 non-null    object
#  33  schoolUrl                  570 non-null    object
#  34  schoolDegree               616 non-null    object
#  35  schoolDescription          301 non-null    object
#  36  schoolDateRange            579 non-null    object
#  37  school2                    532 non-null    object
#  38  schoolUrl2                 449 non-null    object
#  39  schoolDegree2              514 non-null    object
#  40  schoolDescription2         229 non-null    object
#  41  schoolDateRange2           483 non-null    object
#  42  birthday                   259 non-null    object
#  43  allSkills                  623 non-null    object
#  44  skill1                     623 non-null    object
#  45  endorsement1               366 non-null    float64
#  46  skill2                     621 non-null    object
#  47  endorsement2               384 non-null    float64
#  48  skill3                     619 non-null    object
#  49  endorsement3               369 non-null    float64
#  50  skill4                     615 non-null    object
#  51  endorsement4               353 non-null    float64
#  52  skill5                     612 non-null    object
#  53  endorsement5               356 non-null    float64
#  54  skill6                     608 non-null    object
#  55  endorsement6               373 non-null    float64
#  56  baseUrl                    666 non-null    object
#  57  profileId                  656 non-null    object
#  58  timestamp                  666 non-null    object
#  59  subscribers                579 non-null    float64
#  60  mutualConnectionsText      565 non-null    object
#  61  imgUrl                     625 non-null    object
#  62  website                    165 non-null    object
#  63  mail                       172 non-null    object
#  64  connectedOn                177 non-null    object
#  65  error                      0 non-null      object
#  66  phoneNumber                30 non-null     object
#  67  partialScreenshot          409 non-null    object
#  68  facebookUrl                1 non-null      object
# dtypes: float64(9), object(60)
# memory usage: 364.2+ KB

# %%
# Define a function to replace NaN values in fullName
def replace_nan_fullname(full_name, title):
    
    if pd.isna(full_name):
        print(title)
        # Split the title by whitespace
        words = title.split()

        # Check if there are only 2 words in the title
        if len(words) == 2:
            return ' '.join(words[:2])

        # Check for ',' or '-' signs and return the words before them
        for char in [',', '-']:
            if char in title:
                return title.split(char)[0]

    return full_name

# Apply the function to replace NaN values in the fullName column
data_scraped['fullName'] = data_scraped.apply(lambda row: replace_nan_fullname(row['fullName'], row['title']), axis=1)
data_scraped.info()
# Out:
# Adriano Ruiz - tripunkt GmbH
# Yanyan Ma – MBA Candidate – ESMT Berlin
# Armin Krahl - thermondo
# Veronica Sartore - Project coordinator - Yad be Yad (Kubus ...
# Katharina Andres - Nosto
# Siena Chan - cargo.one
# Fernanda Pugliero - Löwenzahn Organics GmbH
# Lynn Ng – Operations Assistant – Ginza Berlin
# Jessica He - HelloFresh
# Lara Orrico - Just Eat Takeaway.com
# <class 'pandas.core.frame.DataFrame'>
# Index: 666 entries, 0 to 680
# Data columns (total 69 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url                        666 non-null    object
#  1   title                      666 non-null    object
#  2   linkedinProfileUrl         615 non-null    object
#  3   email                      172 non-null    object
#  4   linkedinProfile            615 non-null    object
#  5   description                469 non-null    object
#  6   headline                   656 non-null    object
#  7   location                   656 non-null    object
#  8   firstName                  656 non-null    object
#  9   lastName                   656 non-null    object
#  10  fullName                   664 non-null    object
#  11  connectionDegree           656 non-null    object
#  12  vmid                       656 non-null    object
#  13  userId                     656 non-null    float64
#  14  linkedinSalesNavigatorUrl  656 non-null    object
#  15  connectionsCount           607 non-null    float64
#  16  connectionsUrl             656 non-null    object
#  17  mutualConnectionsUrl       656 non-null    object
#  18  company                    645 non-null    object
#  19  companyUrl                 583 non-null    object
#  20  jobTitle                   644 non-null    object
#  21  jobDescription             412 non-null    object
#  22  jobLocation                546 non-null    object
#  23  jobDateRange               635 non-null    object
#  24  jobDuration                634 non-null    object
#  25  company2                   628 non-null    object
#  26  companyUrl2                570 non-null    object
#  27  jobTitle2                  627 non-null    object
#  28  jobDescription2            499 non-null    object
#  29  jobLocation2               530 non-null    object
#  30  jobDateRange2              627 non-null    object
#  31  jobDuration2               626 non-null    object
#  32  school                     630 non-null    object
#  33  schoolUrl                  570 non-null    object
#  34  schoolDegree               616 non-null    object
#  35  schoolDescription          301 non-null    object
#  36  schoolDateRange            579 non-null    object
#  37  school2                    532 non-null    object
#  38  schoolUrl2                 449 non-null    object
#  39  schoolDegree2              514 non-null    object
#  40  schoolDescription2         229 non-null    object
#  41  schoolDateRange2           483 non-null    object
#  42  birthday                   259 non-null    object
#  43  allSkills                  623 non-null    object
#  44  skill1                     623 non-null    object
#  45  endorsement1               366 non-null    float64
#  46  skill2                     621 non-null    object
#  47  endorsement2               384 non-null    float64
#  48  skill3                     619 non-null    object
#  49  endorsement3               369 non-null    float64
#  50  skill4                     615 non-null    object
#  51  endorsement4               353 non-null    float64
#  52  skill5                     612 non-null    object
#  53  endorsement5               356 non-null    float64
#  54  skill6                     608 non-null    object
#  55  endorsement6               373 non-null    float64
#  56  baseUrl                    666 non-null    object
#  57  profileId                  656 non-null    object
#  58  timestamp                  666 non-null    object
#  59  subscribers                579 non-null    float64
#  60  mutualConnectionsText      565 non-null    object
#  61  imgUrl                     625 non-null    object
#  62  website                    165 non-null    object
#  63  mail                       172 non-null    object
#  64  connectedOn                177 non-null    object
#  65  error                      0 non-null      object
#  66  phoneNumber                30 non-null     object
#  67  partialScreenshot          409 non-null    object
#  68  facebookUrl                1 non-null      object
# dtypes: float64(9), object(60)
# memory usage: 364.2+ KB
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/1338588216.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['fullName'] = data_scraped.apply(lambda row: replace_nan_fullname(row['fullName'], row['title']), axis=1)

# %%
def replace_nan_fullname(full_name, title):
    if pd.isna(full_name):
        # Split the title by whitespace
        print(title)
        words = title.split()

        # Check if there are only 2 words in the title
        if len(words) == 2:
            return ' '.join(words[:2])

        # Check for ',' or '-' signs and return the words before the first occurrence
        for char in [',', '-','–']:
            if char in title:
                return title.split(char, 1)[0]

    return full_name
data_scraped['fullName'] = data_scraped.apply(lambda row: replace_nan_fullname(row['fullName'], row['title']), axis=1)
# Out:
# yanyan ma – mba candidate – esmt berlin
# lynn ng – operations assistant – ginza berlin
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/4075008215.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['fullName'] = data_scraped.apply(lambda row: replace_nan_fullname(row['fullName'], row['title']), axis=1)

# %%
data_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 666 entries, 0 to 680
# Data columns (total 70 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url                        666 non-null    object
#  1   title                      666 non-null    object
#  2   linkedinProfileUrl         615 non-null    object
#  3   email                      172 non-null    object
#  4   linkedinProfile            615 non-null    object
#  5   description                469 non-null    object
#  6   headline                   656 non-null    object
#  7   location                   656 non-null    object
#  8   firstName                  656 non-null    object
#  9   lastName                   656 non-null    object
#  10  fullName                   666 non-null    object
#  11  connectionDegree           656 non-null    object
#  12  vmid                       656 non-null    object
#  13  userId                     656 non-null    float64
#  14  linkedinSalesNavigatorUrl  656 non-null    object
#  15  connectionsCount           607 non-null    float64
#  16  connectionsUrl             656 non-null    object
#  17  mutualConnectionsUrl       656 non-null    object
#  18  company                    645 non-null    object
#  19  companyUrl                 583 non-null    object
#  20  jobTitle                   644 non-null    object
#  21  jobDescription             412 non-null    object
#  22  jobLocation                546 non-null    object
#  23  jobDateRange               635 non-null    object
#  24  jobDuration                634 non-null    object
#  25  company2                   628 non-null    object
#  26  companyUrl2                570 non-null    object
#  27  jobTitle2                  627 non-null    object
#  28  jobDescription2            499 non-null    object
#  29  jobLocation2               530 non-null    object
#  30  jobDateRange2              627 non-null    object
#  31  jobDuration2               626 non-null    object
#  32  school                     630 non-null    object
#  33  schoolUrl                  570 non-null    object
#  34  schoolDegree               616 non-null    object
#  35  schoolDescription          301 non-null    object
#  36  schoolDateRange            579 non-null    object
#  37  school2                    532 non-null    object
#  38  schoolUrl2                 449 non-null    object
#  39  schoolDegree2              514 non-null    object
#  40  schoolDescription2         229 non-null    object
#  41  schoolDateRange2           483 non-null    object
#  42  birthday                   259 non-null    object
#  43  allSkills                  623 non-null    object
#  44  skill1                     623 non-null    object
#  45  endorsement1               366 non-null    float64
#  46  skill2                     621 non-null    object
#  47  endorsement2               384 non-null    float64
#  48  skill3                     619 non-null    object
#  49  endorsement3               369 non-null    float64
#  50  skill4                     615 non-null    object
#  51  endorsement4               353 non-null    float64
#  52  skill5                     612 non-null    object
#  53  endorsement5               356 non-null    float64
#  54  skill6                     608 non-null    object
#  55  endorsement6               373 non-null    float64
#  56  baseUrl                    666 non-null    object
#  57  profileId                  656 non-null    object
#  58  timestamp                  666 non-null    object
#  59  subscribers                579 non-null    float64
#  60  mutualConnectionsText      565 non-null    object
#  61  imgUrl                     625 non-null    object
#  62  website                    165 non-null    object
#  63  mail                       172 non-null    object
#  64  connectedOn                177 non-null    object
#  65  error                      0 non-null      object
#  66  phoneNumber                30 non-null     object
#  67  partialScreenshot          409 non-null    object
#  68  facebookUrl                1 non-null      object
#  69  UserID                     1 non-null      float64
# dtypes: float64(10), object(60)
# memory usage: 385.6+ KB

# %%
# Clean data_scraped
data_scraped.fullName = data_scraped.fullName.str.lower()
data_scraped['email'] = data_scraped['email'].fillna('').str.lower()
data_scraped['company'] = data_scraped['company'].fillna('').str.lower().str.strip()

data_scraped['UserID'] = float('nan')
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/2086513390.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped.fullName = data_scraped.fullName.str.lower()
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/2086513390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['email'] = data_scraped['email'].fillna('').str.lower()
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/2086513390.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['company'] = data_scraped['company'].fillna('').str.lower().str.strip()
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/2086513390.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['UserID'] = float('nan')

# %%
unique_attendees2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fullName            781 non-null    object
#  1   numEvents           781 non-null    int64
#  2   First Name          781 non-null    object
#  3   Surname             781 non-null    object
#  4   Email               781 non-null    object
#  5   Company             781 non-null    object
#  6   Your Job Position   781 non-null    object
#  7   Choose your role    781 non-null    object
#  8   Choose your role.1  781 non-null    object
#  9   Seniority           55 non-null     object
#  10  UserID              781 non-null    int64
# dtypes: int64(2), object(9)
# memory usage: 67.2+ KB

# %%
unique_attendees2.Company = unique_attendees.Company.apply(process_name)
unique_attendees2['Your Job Position'] = unique_attendees2['Your Job Position'].apply(process_name)
unique_attendees2['Choose your role'] = unique_attendees2['Choose your role'].apply(process_name)
unique_attendees2['Choose your role.1'] = unique_attendees2['Choose your role.1'].apply(process_name)

# %%
data_scraped.fullName
# Out:
# 0                Patrick Beeker
# 1                  Teena Kumari
# 2              Mischa Gawronski
# 3              Shuvam Kumar Sah
# 4                Ayman Chalhoub
#                  ...
# 676         Ali Akbar Khan, MBA
# 677      Daniel López Contreras
# 678                 Rim Bensouf
# 679               Oguz Celikada
# 680    Althaf Ali Mattummathodi
# Name: fullName, Length: 666, dtype: object

# %%
data_scraped['title'] = data_scraped['title'].str.lower()
data_scraped['title']
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/650584040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['title'] = data_scraped['title'].str.lower()
# 0                                         patrick beeker
# 1      teena kumari – tech product support intern – h...
# 2       mischa gawronski – creative director – freelance
# 3                        shuvam kumar sah – web designer
# 4                                 ayman chalhoub - clink
#                              ...
# 676                  ali akbar khan, mba - delivery hero
# 677                daniel lópez contreras - masterschool
# 678         rim bensouf - product owner - sporttotal ...
# 679          oguz celikada – berlin, berlin, deutschland
# 680                althaf ali mattummathodi - schaeffler
# Name: title, Length: 666, dtype: object

# %%
data_scraped['Attendance'] = 0
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/4113917403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['Attendance'] = 0

# %%
data_scraped.firstName = data_scraped['firstName'].str.lower()
data_scraped.lastName = data_scraped['lastName'].str.lower()
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/27549687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped.firstName = data_scraped['firstName'].str.lower()
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/27549687.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped.lastName = data_scraped['lastName'].str.lower()

# %%
username = row_ids['Email'].split("@")[0]
# Match by username in the email
if len(username) != 0:
    if (username in row_scraped['fullName']) or (username in row_scraped['lastName']) or (username in row_scraped['email']):
    # if row_ids['fullName'].contains(username, na=False) | row_ids['Surname'].contains(username, na=False) | row_ids['Email'].contains(username, na=False):
        return True
    
username = username.split(".")[1]
if len(username) != 0:
    if (username in row_scraped['fullName']) or (username in row_scraped['lastName']) or (username in row_scraped['email']):
    # if row_ids['fullName'].contains(username, na=False) | row_ids['Surname'].contains(username, na=False) | row_ids['Email'].contains(username, na=False):
        return True

# %%
def custom_user_matching(row_scraped, row_ids):
    '''
    Utility function to match scraped data with UserIDs
    '''
    if row_scraped['fullName'] == row_ids['fullName']:
        print(f"Full name matched {row_ids['fullName']} for user {row_ids['UserID']}")
        return True

    # Compare the emails
    if row_scraped['email'] == row_ids['Email'] :
        return True

    # Match by only last name
    # print(row_scraped['fullName'], row_ids['fullName'])
    last_name = row_scraped['fullName'].split()[-1]
    if len(last_name) > 3:
        if ( last_name in row_ids['fullName']) or (last_name in row_ids['Company']) or (last_name in row_ids['Email']):
        # if row_ids['fullName'].contains(row_scraped['lastName'], na=False) | row_ids['Company'].contains( row_scraped['lastName'], na=False)|row_ids['Email'].contains(row_scraped['lastName'], na=False):
            print(f"Last name from full name matched {last_name} {row_ids['fullName']} for user {row_ids['UserID']}")
            return True  
    last_name = row_scraped['lastName']
    if (not pd.isna(last_name)) and (len(last_name) > 3):
        if ( last_name in row_ids['fullName']) or (last_name in row_ids['Company']) or (last_name in row_ids['Email']):
        # if row_ids['fullName'].contains(row_scraped['lastName'], na=False) | row_ids['Company'].contains( row_scraped['lastName'], na=False)|row_ids['Email'].contains(row_scraped['lastName'], na=False):
            print(f"Last name matched {last_name} {row_ids['fullName']} for user {row_ids['UserID']}")
            return True 

        # Compare first or last name match AND the company match
        #if row_ids['Surname'] in row_scraped['fullName']:
         #   if (row_ids['Company'] in row_scraped['company'].lower()) and ( len(row_ids['Company']) != 0):
          #      return True
           # if (row_ids['Your Job Position'] in row_scraped['title'].lower()) and ( len(row_ids['Your Job Position']) != 0):
       #         return True
       #     if (row_ids['Choose your role'] in row_scraped['title'].lower()) and ( len(row_ids['Choose your role']) != 0):
       #         return True
       #     if (row_ids['Choose your role.1'] in row_scraped['title'].lower()) and ( len(row_ids['Choose your role.1']) != 0):
        #        return True
    if row_ids['First Name'] in row_scraped['fullName']:
        if not pd.isna(row_scraped['company']):
            if (len(row_ids['Company']) != 0) and (row_ids['Company'] in row_scraped['company'].lower()):
                return True
        if (len(row_ids['Your Job Position']) != 0) and (row_ids['Your Job Position'] in row_scraped['title'].lower()) :
            print(f"Your Job Position matched!!! {row_ids['fullName']} {row_scraped['fullName']} for user {row_ids['UserID']}")
            return True
        if (len(row_ids['Choose your role']) != 0) and (row_ids['Choose your role'] in row_scraped['title'].lower()):
            print(f"Choose your role matched!!! {row_ids['fullName']} {row_scraped['fullName']} for user {row_ids['UserID']}")
            return True
        if ( len(row_ids['Choose your role.1']) != 0) and (row_ids['Choose your role.1'] in row_scraped['title'].lower()):
            print(f"Choose your role.1 matched!!! {row_ids['fullName']} {row_scraped['fullName']} for user {row_ids['UserID']}")
            return True
        #print(f"First name matched, but not found :( {row_ids['First Name']} {row_scraped['fullName']}")
    return False

# %%
data_scraped.fullName = data_scraped.fullName.str.lower()
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/4199408957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped.fullName = data_scraped.fullName.str.lower()

# %%
data_scraped.fullName = data_scraped.fullName.apply(process_name_not_removing)
# Out:
# patrick
# ['patrick']
# beeker
# ['patrick', 'beeker']
# teena
# ['teena']
# kumari
# ['teena', 'kumari']
# mischa
# ['mischa']
# gawronski
# ['mischa', 'gawronski']
# shuvam
# ['shuvam']
# kumar
# ['shuvam', 'kumar']
# sah
# ['shuvam', 'kumar', 'sah']
# ayman
# ['ayman']
# chalhoub
# ['ayman', 'chalhoub']
# elena
# ['elena']
# berendeeva
# ['elena', 'berendeeva']
# mircea
# ['mircea']
# giurca
# ['mircea', 'giurca']
# luísa
# ['lusa']
# suda
# ['lusa', 'suda']
# sidra
# ['sidra']
# aziz
# ['sidra', 'aziz']
# lisa-sophie
# ['lisasophie']
# rätze
# ['lisasophie', 'rtze']
# salvatorina
# ['salvatorina']
# rassu
# ['salvatorina', 'rassu']
# nikita
# ['nikita']
# zavyalov
# ['nikita', 'zavyalov']
# natalia
# ['natalia']
# pánshina
# ['natalia', 'pnshina']
# yuri
# ['yuri']
# orthey
# ['yuri', 'orthey']
# carolina
# ['carolina']
# torres
# ['carolina', 'torres']
# arzamendi
# ['carolina', 'torres', 'arzamendi']
# marcin
# ['marcin']
# fabianczyk
# ['marcin', 'fabianczyk']
# dilan
# ['dilan']
# gevsek
# ['dilan', 'gevsek']
# elisabeta
# ['elisabeta']
# g
# ['elisabeta', 'g']
# mritunjay
# ['mritunjay']
# kumar
# ['mritunjay', 'kumar']
# verma
# ['mritunjay', 'kumar', 'verma']
# vaibhav
# ['vaibhav']
# malik
# ['vaibhav', 'malik']
# mohamed
# ['mohamed']
# salah
# ['mohamed', 'salah']
# valerie
# ['valerie']
# d
# ['valerie', 'd']
# silvia
# ['silvia']
# lodato
# ['silvia', 'lodato']
# jean-luc
# ['jeanluc']
# hervé
# ['jeanluc', 'herv']
# ©
# ['jeanluc', 'herv', '']
# martinetti-dubuisson
# ['jeanluc', 'herv', '', 'martinettidubuisson']
# europa-union
# ['jeanluc', 'herv', '', 'martinettidubuisson', 'europaunion']
# paris
# ['jeanluc', 'herv', '', 'martinettidubuisson', 'europaunion', 'paris']
# liya
# ['liya']
# kachanova
# ['liya', 'kachanova']
# sindhu
# ['sindhu']
# maiyya
# ['sindhu', 'maiyya']
# max
# ['max']
# scheidlock
# ['max', 'scheidlock']
# francesco
# ['francesco']
# paltrinieri
# ['francesco', 'paltrinieri']
# sanjiv
# ['sanjiv']
# murali
# ['sanjiv', 'murali']
# jan
# ['jan']
# michael
# ['jan', 'michael']
# gerwin
# ['jan', 'michael', 'gerwin']
# sara
# ['sara']
# pattacini
# ['sara', 'pattacini']
# dheeraj
# ['dheeraj']
# suvarna
# ['dheeraj', 'suvarna']
# olya
# ['olya']
# l
# ['olya', 'l']
# attia
# ['attia']
# elsayed
# ['attia', 'elsayed']
# leonardo
# ['leonardo']
# tognon
# ['leonardo', 'tognon']
# nirvan
# ['nirvan']
# mahat
# ['nirvan', 'mahat']
# katie
# ['katie']
# hauser
# ['katie', 'hauser']
# amin
# ['amin']
# jmyi
# ['amin', 'jmyi']
# abolfazl
# ['abolfazl']
# jafarzadehpour
# ['abolfazl', 'jafarzadehpour']
# ximena
# ['ximena']
# hernandez
# ['ximena', 'hernandez']
# utpal
# ['utpal']
# das
# ['utpal', 'das']
# willian
# ['willian']
# magalhães
# ['willian', 'magalhes']
# sheena
# ['sheena']
# antonios
# ['sheena', 'antonios']
# komal
# ['komal']
# singh
# ['komal', 'singh']
# tauheed
# ['tauheed']
# ahmed
# ['tauheed', 'ahmed']
# sonya
# ['sonya']
# pobiedimska
# ['sonya', 'pobiedimska']
# daniela
# ['daniela']
# künstle
# ['daniela', 'knstle']
# evgenia
# ['evgenia']
# adam
# ['evgenia', 'adam']
# 🇺🇦
# ['']
# natalia
# ['', 'natalia']
# filvarova
# ['', 'natalia', 'filvarova']
# 🇺🇦
# ['', 'natalia', 'filvarova', '']
# ines
# ['ines']
# jordan
# ['ines', 'jordan']
# fabian
# ['fabian']
# kleeberger
# ['fabian', 'kleeberger']
# annemarie
# ['annemarie']
# sagner
# ['annemarie', 'sagner']
# sameer
# ['sameer']
# rizwan
# ['sameer', 'rizwan']
# qidwai
# ['sameer', 'rizwan', 'qidwai']
# renata
# ['renata']
# iwamoto
# ['renata', 'iwamoto']
# mathieu
# ['mathieu']
# ritter
# ['mathieu', 'ritter']
# (he/him)
# ['mathieu', 'ritter', 'hehim']
# ariel
# ['ariel']
# wu
# ['ariel', 'wu']
# dr.
# ['dr']
# jenny
# ['dr', 'jenny']
# lam
# ['dr', 'jenny', 'lam']
# senny
# ['senny']
# sanjung
# ['senny', 'sanjung']
# agestriani
# ['senny', 'sanjung', 'agestriani']
# leon
# ['leon']
# gerdes
# ['leon', 'gerdes']
# future
# ['future']
# female
# ['future', 'female']
# africa
# ['future', 'female', 'africa']
# soumitra
# ['soumitra']
# sahu
# ['soumitra', 'sahu']
# daniel
# ['daniel']
# schwarz
# ['daniel', 'schwarz']
# yusuf
# ['yusuf']
# algan
# ['yusuf', 'algan']
# max
# ['max']
# ostapenko
# ['max', 'ostapenko']
# merve
# ['merve']
# salmaz
# ['merve', 'salmaz']
# maximilian
# ['maximilian']
# walzel
# ['maximilian', 'walzel']
# von
# ['maximilian', 'walzel', 'von']
# wiesentreu
# ['maximilian', 'walzel', 'von', 'wiesentreu']
# tansel
# ['tansel']
# can
# ['tansel', 'can']
# ewa
# ['ewa']
# kiwus
# ['ewa', 'kiwus']
# radomir
# ['radomir']
# šebek
# ['radomir', 'ebek']
# seda
# ['seda']
# bavas
# ['seda', 'bavas']
# egor
# ['egor']
# zakharov
# ['egor', 'zakharov']
# professor
# ['professor']
# lisa
# ['professor', 'lisa']
# wilson
# ['professor', 'lisa', 'wilson']
# [short]
# ['professor', 'lisa', 'wilson', 'short']
# arzhang
# ['arzhang']
# mani,
# ['arzhang', 'mani']
# phd
# ['arzhang', 'mani', 'phd']
# louise
# ['louise']
# plessis
# ['louise', 'plessis']
# cindy
# ['cindy']
# janicke
# ['cindy', 'janicke']
# jona
# ['jona']
# david
# ['jona', 'david']
# hoffmann
# ['jona', 'david', 'hoffmann']
# cemal
# ['cemal']
# toprak
# ['cemal', 'toprak']
# nuwan
# ['nuwan']
# withanage
# ['nuwan', 'withanage']
# muhammad
# ['muhammad']
# banirahma
# ['muhammad', 'banirahma']
# syahroni
# ['muhammad', 'banirahma', 'syahroni']
# christine
# ['christine']
# plotz
# ['christine', 'plotz']
# isabella
# ['isabella']
# beck
# ['isabella', 'beck']
# will
# ['will']
# r
# ['will', 'r']
# igor
# ['igor']
# lahr
# ['igor', 'lahr']
# alexander
# ['alexander']
# fife
# ['alexander', 'fife']
# miguel
# ['miguel']
# leon
# ['miguel', 'leon']
# gutierrez
# ['miguel', 'leon', 'gutierrez']
# saptarshi
# ['saptarshi']
# baksi
# ['saptarshi', 'baksi']
# krzysztof
# ['krzysztof']
# glistak
# ['krzysztof', 'glistak']
# ilya
# ['ilya']
# blokh
# ['ilya', 'blokh']
# shantanu
# ['shantanu']
# dikshit
# ['shantanu', 'dikshit']
# miriam
# ['miriam']
# hutter
# ['miriam', 'hutter']
# aino
# ['aino']
# kivinen
# ['aino', 'kivinen']
# ovidiu
# ['ovidiu']
# oanca
# ['ovidiu', 'oanca']
# emilly
# ['emilly']
# leão
# ['emilly', 'leo']
# sabrina
# ['sabrina']
# luna
# ['sabrina', 'luna']
# abdelrahman
# ['abdelrahman']
# elfar
# ['abdelrahman', 'elfar']
# jitesh
# ['jitesh']
# nayak
# ['jitesh', 'nayak']
# simon
# ['simon']
# petrov
# ['simon', 'petrov']
# marijana
# ['marijana']
# medina
# ['marijana', 'medina']
# martin
# ['martin']
# klein
# ['martin', 'klein']
# blen
# ['blen']
# baheru
# ['blen', 'baheru']
# emre
# ['emre']
# karadayılar
# ['emre', 'karadaylar']
# maggie
# ['maggie']
# romano
# ['maggie', 'romano']
# isabell
# ['isabell']
# fringer
# ['isabell', 'fringer']
# john
# ['john']
# ngo
# ['john', 'ngo']
# mostakim
# ['mostakim']
# islam
# ['mostakim', 'islam']
# xiomara
# ['xiomara']
# guillorme
# ['xiomara', 'guillorme']
# seda
# ['seda']
# baskan
# ['seda', 'baskan']
# max
# ['max']
# beitler
# ['max', 'beitler']
# roman
# ['roman']
# prys
# ['roman', 'prys']
# daniel
# ['daniel']
# r
# ['daniel', 'r']
# 👨‍💻
# ['']
# daniel
# ['', 'daniel']
# bartholomae
# ['', 'daniel', 'bartholomae']
# omar
# ['omar']
# sherif
# ['omar', 'sherif']
# marcin
# ['marcin']
# belinski
# ['marcin', 'belinski']
# marta
# ['marta']
# osowiecka
# ['marta', 'osowiecka']
# volodymyr
# ['volodymyr']
# lunov
# ['volodymyr', 'lunov']
# ahmed
# ['ahmed']
# ragab
# ['ahmed', 'ragab']
# dan
# ['dan']
# léon
# ['dan', 'lon']
# krause
# ['dan', 'lon', 'krause']
# andrey
# ['andrey']
# schäfer
# ['andrey', 'schfer']
# sam
# ['sam']
# abdullaev
# ['sam', 'abdullaev']
# masha
# ['masha']
# lutsenko
# ['masha', 'lutsenko']
# nisha
# ['nisha']
# kumari
# ['nisha', 'kumari']
# kevin
# ['kevin']
# konrath
# ['kevin', 'konrath']
# ali
# ['ali']
# badawy
# ['ali', 'badawy']
# anastasia
# ['anastasia']
# kozmína
# ['anastasia', 'kozmna']
# elia
# ['elia']
# jona
# ['elia', 'jona']
# kargruber
# ['elia', 'jona', 'kargruber']
# irene
# ['irene']
# orsa
# ['irene', 'orsa']
# fanton
# ['irene', 'orsa', 'fanton']
# ann-christin
# ['annchristin']
# schönert
# ['annchristin', 'schnert']
# daria
# ['daria']
# elson
# ['daria', 'elson']
# neha
# ['neha']
# george
# ['neha', 'george']
# balaji
# ['balaji']
# alagu
# ['balaji', 'alagu']
# philipp
# ['philipp']
# tessmann
# ['philipp', 'tessmann']
# anastasia
# ['anastasia']
# bakhmutova
# ['anastasia', 'bakhmutova']
# amber
# ['amber']
# hasan
# ['amber', 'hasan']
# naqvi
# ['amber', 'hasan', 'naqvi']
# sándor
# ['sndor']
# dés
# ['sndor', 'ds']
# alcalá
# ['sndor', 'ds', 'alcal']
# alain
# ['alain']
# dujardin
# ['alain', 'dujardin']
# krutika
# ['krutika']
# gopalakrishnan
# ['krutika', 'gopalakrishnan']
# mridul
# ['mridul']
# jain
# ['mridul', 'jain']
# anna
# ['anna']
# lukyanovich
# ['anna', 'lukyanovich']
# alessandra
# ['alessandra']
# bari
# ['alessandra', 'bari']
# duroseme
# ['duroseme']
# taylor
# ['duroseme', 'taylor']
# aleksej
# ['aleksej']
# ruckoj
# ['aleksej', 'ruckoj']
# giacomo
# ['giacomo']
# giorgianni
# ['giacomo', 'giorgianni']
# umair
# ['umair']
# sarfraz
# ['umair', 'sarfraz']
# emanuele
# ['emanuele']
# libralato
# ['emanuele', 'libralato']
# seyma
# ['seyma']
# tuzer
# ['seyma', 'tuzer']
# sam
# ['sam']
# nurick
# ['sam', 'nurick']
# vadym
# ['vadym']
# kuzmenko
# ['vadym', 'kuzmenko']
# 👨🏻‍💻
# ['vadym', 'kuzmenko', '']
# catherine
# ['catherine']
# windorf
# ['catherine', 'windorf']
# annie
# ['annie']
# li
# ['annie', 'li']
# paul
# ['paul']
# hunger
# ['paul', 'hunger']
# elif
# ['elif']
# özçakmak
# ['elif', 'zakmak']
# charline
# ['charline']
# goethals
# ['charline', 'goethals']
# amon
# ['amon']
# fayz
# ['amon', 'fayz']
# hosna
# ['hosna']
# shayani
# ['hosna', 'shayani']
# anja
# ['anja']
# stoltz
# ['anja', 'stoltz']
# dr.
# ['dr']
# anamika
# ['dr', 'anamika']
# datta
# ['dr', 'anamika', 'datta']
# ken
# ['ken']
# kraft
# ['ken', 'kraft']
# alexander
# ['alexander']
# charles
# ['alexander', 'charles']
# boase,
# ['alexander', 'charles', 'boase']
# cspo
# ['alexander', 'charles', 'boase', 'cspo']
# kseniia
# ['kseniia']
# shyshkova
# ['kseniia', 'shyshkova']
# maurice
# ['maurice']
# zurstraßen
# ['maurice', 'zurstraen']
# andrea
# ['andrea']
# picco
# ['andrea', 'picco']
# sanjana
# ['sanjana']
# laddha
# ['sanjana', 'laddha']
# daniil
# ['daniil']
# matkov
# ['daniil', 'matkov']
# julia
# ['julia']
# steier
# ['julia', 'steier']
# anna
# ['anna']
# schneitz
# ['anna', 'schneitz']
# 🥙abdelrahman
# ['abdelrahman']
# (abdo)
# ['abdelrahman', 'abdo']
# wahba
# ['abdelrahman', 'abdo', 'wahba']
# alexander
# ['alexander']
# bahlk
# ['alexander', 'bahlk']
# babatunde
# ['babatunde']
# kufo
# ['babatunde', 'kufo']
# philip
# ['philip']
# homnack
# ['philip', 'homnack']
# debarati
# ['debarati']
# rakshit
# ['debarati', 'rakshit']
# ⚡️
# ['debarati', 'rakshit', '']
# indah
# ['indah']
# harahap
# ['indah', 'harahap']
# blagojche
# ['blagojche']
# kuzevski
# ['blagojche', 'kuzevski']
# deepu
# ['deepu']
# suresh
# ['deepu', 'suresh']
# kumar
# ['deepu', 'suresh', 'kumar']
# uday
# ['uday']
# singh
# ['uday', 'singh']
# olga
# ['olga']
# p
# ['olga', 'p']
# chandan
# ['chandan']
# deepak
# ['chandan', 'deepak']
# mehmi
# ['chandan', 'deepak', 'mehmi']
# catarina
# ['catarina']
# pinto,
# ['catarina', 'pinto']
# phd
# ['catarina', 'pinto', 'phd']
# pia
# ['pia']
# hösdorff
# ['pia', 'hsdorff']
# quezia
# ['quezia']
# barrozo
# ['quezia', 'barrozo']
# aditya
# ['aditya']
# raghunath
# ['aditya', 'raghunath']
# bola
# ['bola']
# oyebo
# ['bola', 'oyebo']
# lana
# ['lana']
# khimka
# ['lana', 'khimka']
# rahul
# ['rahul']
# ranjan
# ['rahul', 'ranjan']
# sean
# ['sean']
# kress
# ['sean', 'kress']
# heorhi
# ['heorhi']
# talochka
# ['heorhi', 'talochka']
# iswarya
# ['iswarya']
# sakthivel
# ['iswarya', 'sakthivel']
# andrea
# ['andrea']
# catalina
# ['andrea', 'catalina']
# motta
# ['andrea', 'catalina', 'motta']
# masood
# ['masood']
# rao
# ['masood', 'rao']
# nihad
# ['nihad']
# zeitouny
# ['nihad', 'zeitouny']
# caitlin
# ['caitlin']
# sullivan
# ['caitlin', 'sullivan']
# hamlet
# ['hamlet']
# hayrapetyan
# ['hamlet', 'hayrapetyan']
# anvesh
# ['anvesh']
# tripathi
# ['anvesh', 'tripathi']
# derek
# ['derek']
# myers
# ['derek', 'myers']
# esther
# ['esther']
# vidal
# ['esther', 'vidal']
# andreu
# ['esther', 'vidal', 'andreu']
# valdrin
# ['valdrin']
# trena
# ['valdrin', 'trena']
# lisa
# ['lisa']
# trueblood
# ['lisa', 'trueblood']
# ugam
# ['ugam']
# kumar
# ['ugam', 'kumar']
# afridha
# ['afridha']
# permatasari
# ['afridha', 'permatasari']
# lubis
# ['afridha', 'permatasari', 'lubis']
# irén
# ['irn']
# seres
# ['irn', 'seres']
# tim
# ['tim']
# heiler
# ['tim', 'heiler']
# rajesh
# ['rajesh']
# chowdary
# ['rajesh', 'chowdary']
# matt
# ['matt']
# matt
# ['matt', 'matt']
# aliyu
# ['aliyu']
# alkaleri
# ['aliyu', 'alkaleri']
# kate
# ['kate']
# yanke
# ['kate', 'yanke']
# phuc
# ['phuc']
# nguyen
# ['phuc', 'nguyen']
# jannik
# ['jannik']
# schewe
# ['jannik', 'schewe']
# kourosh
# ['kourosh']
# ehsan
# ['kourosh', 'ehsan']
# maleki
# ['kourosh', 'ehsan', 'maleki']
# malik
# ['malik']
# ebers
# ['malik', 'ebers']
# soumya
# ['soumya']
# patil
# ['soumya', 'patil']
# roswell
# ['roswell']
# balentien
# ['roswell', 'balentien']
# mari-liis
# ['mariliis']
# algma
# ['mariliis', 'algma']
# kelly
# ['kelly']
# hsu
# ['kelly', 'hsu']
# anmol
# ['anmol']
# kawatra
# ['anmol', 'kawatra']
# valentyna
# ['valentyna']
# pilianska
# ['valentyna', 'pilianska']
# nicola
# ['nicola']
# di
# ['nicola', 'di']
# nardo
# ['nicola', 'di', 'nardo']
# matthias
# ['matthias']
# siwy
# ['matthias', 'siwy']
# hayyaan
# ['hayyaan']
# ahmad
# ['hayyaan', 'ahmad']
# matthieu
# ['matthieu']
# sloves
# ['matthieu', 'sloves']
# anna
# ['anna']
# grosheva
# ['anna', 'grosheva']
# max
# ['max']
# grachev
# ['max', 'grachev']
# johannes
# ['johannes']
# holl
# ['johannes', 'holl']
# lucas
# ['lucas']
# zandoná
# ['lucas', 'zandon']
# isabelle
# ['isabelle']
# bedê
# ['isabelle', 'bed']
# (she/her)
# ['isabelle', 'bed', 'sheher']
# florian
# ['florian']
# straub
# ['florian', 'straub']
# natalia
# ['natalia']
# anastasova
# ['natalia', 'anastasova']
# anastasiia
# ['anastasiia']
# kostrub
# ['anastasiia', 'kostrub']
# ross
# ['ross']
# kinmont
# ['ross', 'kinmont']
# daniele
# ['daniele']
# ronca
# ['daniele', 'ronca']
# diane
# ['diane']
# catherine
# ['diane', 'catherine']
# gómez
# ['diane', 'catherine', 'gmez']
# casas
# ['diane', 'catherine', 'gmez', 'casas']
# thomas
# ['thomas']
# seidl
# ['thomas', 'seidl']
# ziyad
# ['ziyad']
# muhammed
# ['ziyad', 'muhammed']
# soumya
# ['soumya']
# p
# ['soumya', 'p']
# vishal
# ['vishal']
# patil
# ['vishal', 'patil']
# lualiny
# ['lualiny']
# brito
# ['lualiny', 'brito']
# ivan
# ['ivan']
# rublev
# ['ivan', 'rublev']
# chase
# ['chase']
# richards
# ['chase', 'richards']
# zulfiya
# ['zulfiya']
# malyshenko
# ['zulfiya', 'malyshenko']
# samuel
# ['samuel']
# ghebreab
# ['samuel', 'ghebreab']
# enes
# ['enes']
# döke
# ['enes', 'dke']
# peter
# ['peter']
# rubarth
# ['peter', 'rubarth']
# abhishek
# ['abhishek']
# wabale
# ['abhishek', 'wabale']
# marius
# ['marius']
# dörrenbach
# ['marius', 'drrenbach']
# niv
# ['niv']
# david
# ['niv', 'david']
# gourav
# ['gourav']
# gulati
# ['gourav', 'gulati']
# alberto
# ['alberto']
# pérez
# ['alberto', 'prez']
# prajwal
# ['prajwal']
# negapettam
# ['prajwal', 'negapettam']
# juan
# ['juan']
# jose
# ['juan', 'jose']
# mendoza
# ['juan', 'jose', 'mendoza']
# santana
# ['juan', 'jose', 'mendoza', 'santana']
# regina
# ['regina']
# hell
# ['regina', 'hell']
# neufeld
# ['regina', 'hell', 'neufeld']
# christine
# ['christine']
# thach
# ['christine', 'thach']
# dima
# ['dima']
# malyshenko
# ['dima', 'malyshenko']
# tal
# ['tal']
# karp-rudin
# ['tal', 'karprudin']
# valeriia
# ['valeriia']
# kaimashnikova
# ['valeriia', 'kaimashnikova']
# zsolt
# ['zsolt']
# pap
# ['zsolt', 'pap']
# hussam
# ['hussam']
# al
# ['hussam', 'al']
# alfe
# ['hussam', 'al', 'alfe']
# seb
# ['seb']
# hapte-selassie
# ['seb', 'hapteselassie']
# marc
# ['marc']
# boner
# ['marc', 'boner']
# daria
# ['daria']
# lezhai
# ['daria', 'lezhai']
# pradeep
# ['pradeep']
# jayarama
# ['pradeep', 'jayarama']
# khrystyna
# ['khrystyna']
# svarychevska
# ['khrystyna', 'svarychevska']
# fırat
# ['frat']
# gömi
# ['frat', 'gmi']
# christian
# ['christian']
# n.
# ['christian', 'n']
# mancini
# ['christian', 'n', 'mancini']
# (he/him)
# ['christian', 'n', 'mancini', 'hehim']
# erik
# ['erik']
# vollstädt
# ['erik', 'vollstdt']
# nikola
# ['nikola']
# domazet
# ['nikola', 'domazet']
# nataliia
# ['nataliia']
# senatorova
# ['nataliia', 'senatorova']
# nina
# ['nina']
# mannheimer
# ['nina', 'mannheimer']
# daniel
# ['daniel']
# zherenkov
# ['daniel', 'zherenkov']
# roland
# ['roland']
# butler
# ['roland', 'butler']
# mason
# ['mason']
# jeong
# ['mason', 'jeong']
# andrey
# ['andrey']
# shilin
# ['andrey', 'shilin']
# elisa
# ['elisa']
# schenke
# ['elisa', 'schenke']
# diana
# ['diana']
# kryuchkova
# ['diana', 'kryuchkova']
# adriano
# ['adriano']
# ruiz
# ['adriano', 'ruiz']
# yanyan
# ['yanyan']
# ma
# ['yanyan', 'ma']
# armin
# ['armin']
# krahl
# ['armin', 'krahl']
# veronica
# ['veronica']
# sartore
# ['veronica', 'sartore']
# katharina
# ['katharina']
# andres
# ['katharina', 'andres']
# siena
# ['siena']
# chan
# ['siena', 'chan']
# fernanda
# ['fernanda']
# pugliero
# ['fernanda', 'pugliero']
# lynn
# ['lynn']
# ng
# ['lynn', 'ng']
# jessica
# ['jessica']
# he
# ['jessica', 'he']
# lara
# ['lara']
# orrico
# ['lara', 'orrico']
# ifrah
# ['ifrah']
# khanyaree
# ['ifrah', 'khanyaree']
# fabius
# ['fabius']
# weiner
# ['fabius', 'weiner']
# christopher
# ['christopher']
# piazza
# ['christopher', 'piazza']
# rafael
# ['rafael']
# weninger
# ['rafael', 'weninger']
# ilaria
# ['ilaria']
# di
# ['ilaria', 'di']
# maio
# ['ilaria', 'di', 'maio']
# timm
# ['timm']
# kick
# ['timm', 'kick']
# gaurav
# ['gaurav']
# gulrajani
# ['gaurav', 'gulrajani']
# ana
# ['ana']
# reyes
# ['ana', 'reyes']
# garcía
# ['ana', 'reyes', 'garca']
# robert
# ['robert']
# lange
# ['robert', 'lange']
# darrena
# ['darrena']
# mamm
# ['darrena', 'mamm']
# valentin
# ['valentin']
# loginov
# ['valentin', 'loginov']
# mehmet
# ['mehmet']
# dadal
# ['mehmet', 'dadal']
# ercan
# ['mehmet', 'dadal', 'ercan']
# ali
# ['ali']
# al
# ['ali', 'al']
# qaisi
# ['ali', 'al', 'qaisi']
# mojtaba
# ['mojtaba']
# fattahi
# ['mojtaba', 'fattahi']
# matthias
# ['matthias']
# theves
# ['matthias', 'theves']
# jye
# ['jye']
# jiun
# ['jye', 'jiun']
# lu
# ['jye', 'jiun', 'lu']
# (jj)
# ['jye', 'jiun', 'lu', 'jj']
# johannes
# ['johannes']
# wrubel
# ['johannes', 'wrubel']
# fabian
# ['fabian']
# zagel
# ['fabian', 'zagel']
# miguel
# ['miguel']
# barrero
# ['miguel', 'barrero']
# julian
# ['julian']
# lindloff
# ['julian', 'lindloff']
# antonia
# ['antonia']
# landi
# ['antonia', 'landi']
# deniz
# ['deniz']
# ozkan
# ['deniz', 'ozkan']
# ruko
# ['ruko']
# kuga
# ['ruko', 'kuga']
# vignesh
# ['vignesh']
# kalimuthu
# ['vignesh', 'kalimuthu']
# milena
# ['milena']
# fagandini
# ['milena', 'fagandini']
# dr.
# ['dr']
# else
# ['dr', 'else']
# van
# ['dr', 'else', 'van']
# der
# ['dr', 'else', 'van', 'der']
# berg
# ['dr', 'else', 'van', 'der', 'berg']
# matt
# ['matt']
# roskovec
# ['matt', 'roskovec']
# 🇺🇦
# ['matt', 'roskovec', '']
# paula
# ['paula']
# andrea
# ['paula', 'andrea']
# castro
# ['paula', 'andrea', 'castro']
# matin
# ['matin']
# borhani
# ['matin', 'borhani']
# adi
# ['adi']
# kantor
# ['adi', 'kantor']
# borjan
# ['borjan']
# nikolov
# ['borjan', 'nikolov']
# chris
# ['chris']
# schlichting
# ['chris', 'schlichting']
# abdelah
# ['abdelah']
# barmou
# ['abdelah', 'barmou']
# fabio
# ['fabio']
# muroni
# ['fabio', 'muroni']
# stefanus
# ['stefanus']
# ardhito
# ['stefanus', 'ardhito']
# prasetya
# ['stefanus', 'ardhito', 'prasetya']
# sanyam
# ['sanyam']
# arya
# ['sanyam', 'arya']
# johanna
# ['johanna']
# kuhlee
# ['johanna', 'kuhlee']
# ⚡️
# ['johanna', 'kuhlee', '']
# iasmina
# ['iasmina']
# craciun
# ['iasmina', 'craciun']
# oskar
# ['oskar']
# salmhofer
# ['oskar', 'salmhofer']
# dominik
# ['dominik']
# hess
# ['dominik', 'hess']
# anton
# ['anton']
# gridz
# ['anton', 'gridz']
# chris
# ['chris']
# matthews
# ['chris', 'matthews']
# valeria
# ['valeria']
# flores-ducoing
# ['valeria', 'floresducoing']
# beka
# ['beka']
# kokoladze
# ['beka', 'kokoladze']
# sönke
# ['snke']
# peters
# ['snke', 'peters']
# riccardo
# ['riccardo']
# costi
# ['riccardo', 'costi']
# zihan
# ['zihan']
# wang
# ['zihan', 'wang']
# marina
# ['marina']
# ernst
# ['marina', 'ernst']
# hiba
# ['hiba']
# ganta
# ['hiba', 'ganta']
# shruthi
# ['shruthi']
# subramanian
# ['shruthi', 'subramanian']
# jakub
# ['jakub']
# uniejewski
# ['jakub', 'uniejewski']
# yasir
# ['yasir']
# qureshi
# ['yasir', 'qureshi']
# dave
# ['dave']
# feldman
# ['dave', 'feldman']
# felix
# ['felix']
# dahlmeyer
# ['felix', 'dahlmeyer']
# elliot
# ['elliot']
# altham
# ['elliot', 'altham']
# beat
# ['beat']
# weichsler
# ['beat', 'weichsler']
# srishti
# ['srishti']
# maitra
# ['srishti', 'maitra']
# maurice
# ['maurice']
# dücker
# ['maurice', 'dcker']
# hadi
# ['hadi']
# attaran
# ['hadi', 'attaran']
# daniil
# ['daniil']
# tykheev
# ['daniil', 'tykheev']
# vimal
# ['vimal']
# garg
# ['vimal', 'garg']
# eli
# ['eli']
# cohen
# ['eli', 'cohen']
# benedetta
# ['benedetta']
# montagnoli
# ['benedetta', 'montagnoli']
# julian
# ['julian']
# ringel
# ['julian', 'ringel']
# benedetta
# ['benedetta']
# formichi
# ['benedetta', 'formichi']
# jyoti
# ['jyoti']
# sharma
# ['jyoti', 'sharma']
# nadine
# ['nadine']
# radetzki
# ['nadine', 'radetzki']
# stephanie
# ['stephanie']
# bschorr
# ['stephanie', 'bschorr']
# ana
# ['ana']
# paula
# ['ana', 'paula']
# miranda
# ['ana', 'paula', 'miranda']
# joy
# ['joy']
# chatterjee
# ['joy', 'chatterjee']
# martin
# ['martin']
# koo
# ['martin', 'koo']
# rosenmejer
# ['martin', 'koo', 'rosenmejer']
# charles
# ['charles']
# vestal
# ['charles', 'vestal']
# sarvesh
# ['sarvesh']
# regmi
# ['sarvesh', 'regmi']
# sam
# ['sam']
# swasey
# ['sam', 'swasey']
# piotr
# ['piotr']
# tomaszewski
# ['piotr', 'tomaszewski']
# dalma
# ['dalma']
# szabo
# ['dalma', 'szabo']
# leif
# ['leif']
# neithöfer
# ['leif', 'neithfer']
# deniz
# ['deniz']
# öykü
# ['deniz', 'yk']
# yıldız
# ['deniz', 'yk', 'yldz']
# radu
# ['radu']
# lupu
# ['radu', 'lupu']
# olena
# ['olena']
# shapoval
# ['olena', 'shapoval']
# victoria
# ['victoria']
# kotlova
# ['victoria', 'kotlova']
# rodrigo
# ['rodrigo']
# catão
# ['rodrigo', 'cato']
# wally
# ['wally']
# l
# ['wally', 'l']
# lubena
# ['lubena']
# awan
# ['lubena', 'awan']
# lucas
# ['lucas']
# minetti
# ['lucas', 'minetti']
# vitalik
# ['vitalik']
# kotik
# ['vitalik', 'kotik']
# 🇺🇦
# ['vitalik', 'kotik', '']
# pasquale
# ['pasquale']
# romito
# ['pasquale', 'romito']
# nail
# ['nail']
# valiyev
# ['nail', 'valiyev']
# anvar
# ['anvar']
# atash
# ['anvar', 'atash']
# davud
# ['davud']
# samadov
# ['davud', 'samadov']
# alice
# ['alice']
# mendeleyeva
# ['alice', 'mendeleyeva']
# nadine
# ['nadine']
# verbeek
# ['nadine', 'verbeek']
# meltem
# ['meltem']
# şeyma
# ['meltem', 'eyma']
# behar
# ['meltem', 'eyma', 'behar']
# jack
# ['jack']
# lancaster
# ['jack', 'lancaster']
# saki
# ['saki']
# cansev
# ['saki', 'cansev']
# usman
# ['usman']
# nasir
# ['usman', 'nasir']
# christian
# ['christian']
# hoffmeister
# ['christian', 'hoffmeister']
# daniel
# ['daniel']
# b.
# ['daniel', 'b']
# stelzer
# ['daniel', 'b', 'stelzer']
# 🇺🇦
# ['daniel', 'b', 'stelzer', '']
# oleksii
# ['oleksii']
# klochai
# ['oleksii', 'klochai']
# emanoil
# ['emanoil']
# topalov
# ['emanoil', 'topalov']
# matthias
# ['matthias']
# diener
# ['matthias', 'diener']
# allison
# ['allison']
# palmer
# ['allison', 'palmer']
# manizeh
# ['manizeh']
# dossa
# ['manizeh', 'dossa']
# ahmad
# ['ahmad']
# ali
# ['ahmad', 'ali']
# saeed
# ['ahmad', 'ali', 'saeed']
# santhosh
# ['santhosh']
# kumar
# ['santhosh', 'kumar']
# setty
# ['santhosh', 'kumar', 'setty']
# anna
# ['anna']
# suprun
# ['anna', 'suprun']
# valerio
# ['valerio']
# van
# ['valerio', 'van']
# den
# ['valerio', 'van', 'den']
# broek
# ['valerio', 'van', 'den', 'broek']
# rosario
# ['rosario']
# marrazzo
# ['rosario', 'marrazzo']
# libin
# ['libin']
# sadique
# ['libin', 'sadique']
# david
# ['david']
# velandia
# ['david', 'velandia']
# sahil
# ['sahil']
# gambhir
# ['sahil', 'gambhir']
# aman
# ['aman']
# sadique
# ['aman', 'sadique']
# ivan
# ['ivan']
# kow
# ['ivan', 'kow']
# adela
# ['adela']
# urbina
# ['adela', 'urbina']
# victória
# ['victria']
# villela
# ['victria', 'villela']
# nunes
# ['victria', 'villela', 'nunes']
# antunes
# ['victria', 'villela', 'nunes', 'antunes']
# tim
# ['tim']
# schröder
# ['tim', 'schrder']
# mohammad
# ['mohammad']
# nasim
# ['mohammad', 'nasim']
# rasikh
# ['mohammad', 'nasim', 'rasikh']
# chris
# ['chris']
# hahn
# ['chris', 'hahn']
# despoina
# ['despoina']
# sarikou
# ['despoina', 'sarikou']
# jules
# ['jules']
# nijskens
# ['jules', 'nijskens']
# shubina
# ['shubina']
# roy
# ['shubina', 'roy']
# george
# ['george']
# gibson
# ['george', 'gibson']
# michele
# ['michele']
# cerullo
# ['michele', 'cerullo']
# andrew
# ['andrew']
# quan
# ['andrew', 'quan']
# tamara
# ['tamara']
# bülow
# ['tamara', 'blow']
# sanjeev
# ['sanjeev']
# rao
# ['sanjeev', 'rao']
# felix
# ['felix']
# preuss
# ['felix', 'preuss']
# aris
# ['aris']
# kress-kallidromitis
# ['aris', 'kresskallidromitis']
# anne
# ['anne']
# bauer
# ['anne', 'bauer']
# camila
# ['camila']
# jatahy
# ['camila', 'jatahy']
# olaf
# ['olaf']
# lenzmann
# ['olaf', 'lenzmann']
# ashish
# ['ashish']
# mishra
# ['ashish', 'mishra']
# antonija
# ['antonija']
# peshevski
# ['antonija', 'peshevski']
# aybala
# ['aybala']
# coskun
# ['aybala', 'coskun']
# karadayilar
# ['aybala', 'coskun', 'karadayilar']
# sabina
# ['sabina']
# radziush
# ['sabina', 'radziush']
# yashvir
# ['yashvir']
# chawla
# ['yashvir', 'chawla']
# eng.
# ['eng']
# vivek
# ['eng', 'vivek']
# arivazhagan
# ['eng', 'vivek', 'arivazhagan']
# mohit
# ['mohit']
# bansal
# ['mohit', 'bansal']
# marcos
# ['marcos']
# rubio
# ['marcos', 'rubio']
# rubio
# ['marcos', 'rubio', 'rubio']
# altea
# ['altea']
# mallor
# ['altea', 'mallor']
# hoya
# ['altea', 'mallor', 'hoya']
# vinicio
# ['vinicio']
# oliveira
# ['vinicio', 'oliveira']
# kimberly
# ['kimberly']
# schmitt
# ['kimberly', 'schmitt']
# alessandra
# ['alessandra']
# i
# ['alessandra', 'i']
# angel
# ['angel']
# poon
# ['angel', 'poon']
# laura
# ['laura']
# soto
# ['laura', 'soto']
# manu
# ['manu']
# raivio
# ['manu', 'raivio']
# vibhu
# ['vibhu']
# kumar
# ['vibhu', 'kumar']
# gaurav
# ['gaurav']
# gursahani
# ['gaurav', 'gursahani']
# joanna
# ['joanna']
# wilkans
# ['joanna', 'wilkans']
# sara
# ['sara']
# santanen
# ['sara', 'santanen']
# mikhail
# ['mikhail']
# grinberg
# ['mikhail', 'grinberg']
# elif
# ['elif']
# bakkal
# ['elif', 'bakkal']
# beatriz
# ['beatriz']
# ponce
# ['beatriz', 'ponce']
# snezhanna
# ['snezhanna']
# mineeva
# ['snezhanna', 'mineeva']
# wai
# ['wai']
# sum
# ['wai', 'sum']
# choy
# ['wai', 'sum', 'choy']
# nanette
# ['nanette']
# lange
# ['nanette', 'lange']
# tamer
# ['tamer']
# el-hawari
# ['tamer', 'elhawari']
# gina
# ['gina']
# kimiza
# ['gina', 'kimiza']
# tan
# ['gina', 'kimiza', 'tan']
# robert
# ['robert']
# novak
# ['robert', 'novak']
# palak
# ['palak']
# sharma
# ['palak', 'sharma']
# julia
# ['julia']
# gentsch
# ['julia', 'gentsch']
# irina
# ['irina']
# reinerth
# ['irina', 'reinerth']
# braian
# ['braian']
# lugo
# ['braian', 'lugo']
# roman
# ['roman']
# nikulin
# ['roman', 'nikulin']
# carlotta
# ['carlotta']
# clauter
# ['carlotta', 'clauter']
# alessandra
# ['alessandra']
# fiorentino
# ['alessandra', 'fiorentino']
# oleg
# ['oleg']
# yakovenko
# ['oleg', 'yakovenko']
# amelie
# ['amelie']
# kern
# ['amelie', 'kern']
# florian
# ['florian']
# bonnet
# ['florian', 'bonnet']
# dominik
# ['dominik']
# kress
# ['dominik', 'kress']
# julia
# ['julia']
# oehme
# ['julia', 'oehme']
# shahin
# ['shahin']
# sultana
# ['shahin', 'sultana']
# max
# ['max']
# hess
# ['max', 'hess']
# ramzy
# ['ramzy']
# ismail
# ['ramzy', 'ismail']
# karolina
# ['karolina']
# kiszela
# ['karolina', 'kiszela']
# jil
# ['jil']
# lulu
# ['jil', 'lulu']
# perrevoort
# ['jil', 'lulu', 'perrevoort']
# bella
# ['bella']
# grigoryants
# ['bella', 'grigoryants']
# luis
# ['luis']
# rieke
# ['luis', 'rieke']
# dmitry
# ['dmitry']
# deniskin
# ['dmitry', 'deniskin']
# mariella
# ['mariella']
# gruensteidl
# ['mariella', 'gruensteidl']
# sanna
# ['sanna']
# tietjen
# ['sanna', 'tietjen']
# satoru
# ['satoru']
# teshima
# ['satoru', 'teshima']
# valentine
# ['valentine']
# guettier
# ['valentine', 'guettier']
# hiya
# ['hiya']
# gaine
# ['hiya', 'gaine']
# krishen
# ['krishen']
# mertens
# ['krishen', 'mertens']
# anastasia
# ['anastasia']
# buryak
# ['anastasia', 'buryak']
# rebecca
# ['rebecca']
# schön
# ['rebecca', 'schn']
# mario
# ['mario']
# schwarz
# ['mario', 'schwarz']
# bastian
# ['bastian']
# m.
# ['bastian', 'm']
# busshardt
# ['bastian', 'm', 'busshardt']
# johannes
# ['johannes']
# schweig
# ['johannes', 'schweig']
# yuliya
# ['yuliya']
# gustap
# ['yuliya', 'gustap']
# katie
# ['katie']
# dang
# ['katie', 'dang']
# (dang
# ['katie', 'dang', 'dang']
# le
# ['katie', 'dang', 'dang', 'le']
# nguyen
# ['katie', 'dang', 'dang', 'le', 'nguyen']
# thi)
# ['katie', 'dang', 'dang', 'le', 'nguyen', 'thi']
# javier
# ['javier']
# garcía
# ['javier', 'garca']
# latorre
# ['javier', 'garca', 'latorre']
# vieri
# ['vieri']
# fidanza
# ['vieri', 'fidanza']
# nick
# ['nick']
# stübe
# ['nick', 'stbe']
# kristina
# ['kristina']
# riz
# ['kristina', 'riz']
# ruseva
# ['kristina', 'riz', 'ruseva']
# philipp
# ['philipp']
# baumer
# ['philipp', 'baumer']
# arkadeep
# ['arkadeep']
# sur
# ['arkadeep', 'sur']
# marie
# ['marie']
# aurhammer
# ['marie', 'aurhammer']
# uliana
# ['uliana']
# fedorova
# ['uliana', 'fedorova']
# eliza-marija
# ['elizamarija']
# hirvensalo
# ['elizamarija', 'hirvensalo']
# vadim
# ['vadim']
# bayandin
# ['vadim', 'bayandin']
# nicole
# ['nicole']
# calderon
# ['nicole', 'calderon']
# mathis
# ['mathis']
# lichtenberger
# ['mathis', 'lichtenberger']
# maaz
# ['maaz']
# bin
# ['maaz', 'bin']
# kashif
# ['maaz', 'bin', 'kashif']
# hwajung
# ['hwajung']
# hur
# ['hwajung', 'hur']
# ashu
# ['ashu']
# rranjan
# ['ashu', 'rranjan']
# pandey
# ['ashu', 'rranjan', 'pandey']
# ananthakrishnan
# ['ananthakrishnan']
# syamaprasad
# ['ananthakrishnan', 'syamaprasad']
# thomas
# ['thomas']
# letschert
# ['thomas', 'letschert']
# janine
# ['janine']
# magayanes
# ['janine', 'magayanes']
# karl
# ['karl']
# villanueva
# ['karl', 'villanueva']
# savani
# ['savani']
# nimonkar
# ['savani', 'nimonkar']
# lydia
# ['lydia']
# dietrich
# ['lydia', 'dietrich']
# busayomi
# ['busayomi']
# omotosho
# ['busayomi', 'omotosho']
# schultz-zehden
# ['schultzzehden']
# angela
# ['schultzzehden', 'angela']
# abhishek
# ['abhishek']
# khatri
# ['abhishek', 'khatri']
# ramin
# ['ramin']
# amirov
# ['ramin', 'amirov']
# simon
# ['simon']
# hicks
# ['simon', 'hicks']
# claudia
# ['claudia']
# dünckmann
# ['claudia', 'dnckmann']
# sarah
# ['sarah']
# greiner-miethe
# ['sarah', 'greinermiethe']
# stephanie
# ['stephanie']
# kazalac
# ['stephanie', 'kazalac']
# aleksandr
# ['aleksandr']
# volosha
# ['aleksandr', 'volosha']
# alfred
# ['alfred']
# francis
# ['alfred', 'francis']
# sebas
# ['sebas']
# tian
# ['sebas', 'tian']
# sarmad
# ['sarmad']
# ali
# ['sarmad', 'ali']
# haider
# ['sarmad', 'ali', 'haider']
# ekaterina
# ['ekaterina']
# zenkevich
# ['ekaterina', 'zenkevich']
# 🇺🇦🕊
# ['ekaterina', 'zenkevich', '']
# anita
# ['anita']
# đordić
# ['anita', 'ordi']
# milana
# ['milana']
# magurina
# ['milana', 'magurina']
# farideh
# ['farideh']
# samadi
# ['farideh', 'samadi']
# kaisa
# ['kaisa']
# berger
# ['kaisa', 'berger']
# volodymyr
# ['volodymyr']
# borodavchuk
# ['volodymyr', 'borodavchuk']
# david
# ['david']
# dewolfe
# ['david', 'dewolfe']
# prashanth
# ['prashanth']
# veeranki
# ['prashanth', 'veeranki']
# shubha
# ['shubha']
# pallavi
# ['shubha', 'pallavi']
# aqif
# ['aqif']
# hamid
# ['aqif', 'hamid']
# hashir
# ['hashir']
# rizwan
# ['hashir', 'rizwan']
# tameesh
# ['tameesh']
# biswas
# ['tameesh', 'biswas']
# mohammad
# ['mohammad']
# al
# ['mohammad', 'al']
# khateeb
# ['mohammad', 'al', 'khateeb']
# burak
# ['burak']
# yigen
# ['burak', 'yigen']
# xuejiao(shirlie)
# ['xuejiaoshirlie']
# wang
# ['xuejiaoshirlie', 'wang']
# linn
# ['linn']
# legros
# ['linn', 'legros']
# victor
# ['victor']
# semencenco
# ['victor', 'semencenco']
# sofia
# ['sofia']
# siepi
# ['sofia', 'siepi']
# michele
# ['michele']
# fumagalli
# ['michele', 'fumagalli']
# yusuf
# ['yusuf']
# can
# ['yusuf', 'can']
# pirlibeylioğlu
# ['yusuf', 'can', 'pirlibeyliolu']
# maycon
# ['maycon']
# stamboroski
# ['maycon', 'stamboroski']
# eleftherios
# ['eleftherios']
# christou
# ['eleftherios', 'christou']
# arthur
# ['arthur']
# annebicque
# ['arthur', 'annebicque']
# natalia
# ['natalia']
# petrova
# ['natalia', 'petrova']
# klara
# ['klara']
# murzabekova
# ['klara', 'murzabekova']
# dulano
# ['dulano']
# asalemo
# ['dulano', 'asalemo']
# evgeniia
# ['evgeniia']
# golubeva
# ['evgeniia', 'golubeva']
# nicolai
# ['nicolai']
# brunner
# ['nicolai', 'brunner']
# david
# ['david']
# wenk
# ['david', 'wenk']
# nuno
# ['nuno']
# moreira
# ['nuno', 'moreira']
# dave
# ['dave']
# bulhart
# ['dave', 'bulhart']
# (grund)
# ['dave', 'bulhart', 'grund']
# arailym
# ['arailym']
# kaiyrova
# ['arailym', 'kaiyrova']
# ekansh
# ['ekansh']
# malhotra
# ['ekansh', 'malhotra']
# girish
# ['girish']
# nalwade
# ['girish', 'nalwade']
# denis
# ['denis']
# liggeri
# ['denis', 'liggeri']
# rifqi
# ['rifqi']
# tjahjono
# ['rifqi', 'tjahjono']
# shuhrat
# ['shuhrat']
# pirnazarzoda
# ['shuhrat', 'pirnazarzoda']
# steffi
# ['steffi']
# m
# ['steffi', 'm']
# tatjana
# ['tatjana']
# stykel
# ['tatjana', 'stykel']
# ankit
# ['ankit']
# morajkar
# ['ankit', 'morajkar']
# agnel
# ['agnel']
# joby
# ['agnel', 'joby']
# tiago
# ['tiago']
# de
# ['tiago', 'de']
# almeida
# ['tiago', 'de', 'almeida']
# gautami
# ['gautami']
# pandit
# ['gautami', 'pandit']
# shivam
# ['shivam']
# runthala
# ['shivam', 'runthala']
# aniket
# ['aniket']
# ambekar
# ['aniket', 'ambekar']
# kunal
# ['kunal']
# kava
# ['kunal', 'kava']
# elisa
# ['elisa']
# marku
# ['elisa', 'marku']
# guseyn
# ['guseyn']
# gadirov
# ['guseyn', 'gadirov']
# sofiia
# ['sofiia']
# lukashevych
# ['sofiia', 'lukashevych']
# paris
# ['paris']
# charilaou
# ['paris', 'charilaou']
# mojgan
# ['mojgan']
# behravan
# ['mojgan', 'behravan']
# mehdi
# ['mehdi']
# eyvazzadeh
# ['mehdi', 'eyvazzadeh']
# myles
# ['myles']
# sutholt
# ['myles', 'sutholt']
# nifemi
# ['nifemi']
# omotola
# ['nifemi', 'omotola']
# nina
# ['nina']
# untch
# ['nina', 'untch']
# maria
# ['maria']
# teneva
# ['maria', 'teneva']
# sandra
# ['sandra']
# mary
# ['sandra', 'mary']
# herweck
# ['sandra', 'mary', 'herweck']
# shamaila
# ['shamaila']
# butt
# ['shamaila', 'butt']
# irma
# ['irma']
# gagulia
# ['irma', 'gagulia']
# karina
# ['karina']
# hasler
# ['karina', 'hasler']
# kai
# ['kai']
# wieland
# ['kai', 'wieland']
# elena
# ['elena']
# sergiampietri
# ['elena', 'sergiampietri']
# lucas
# ['lucas']
# rech
# ['lucas', 'rech']
# itir
# ['itir']
# ergin
# ['itir', 'ergin']
# antonio
# ['antonio']
# castillo
# ['antonio', 'castillo']
# pérez
# ['antonio', 'castillo', 'prez']
# jérôme
# ['jrme']
# roeser
# ['jrme', 'roeser']
# maría
# ['mara']
# josé
# ['mara', 'jos']
# salmerón
# ['mara', 'jos', 'salmern']
# ibáñez
# ['mara', 'jos', 'salmern', 'ibez']
# philipp
# ['philipp']
# schimmelfennig
# ['philipp', 'schimmelfennig']
# niklas
# ['niklas']
# springer
# ['niklas', 'springer']
# gurbinder
# ['gurbinder']
# singh
# ['gurbinder', 'singh']
# filippo
# ['filippo']
# palmieri
# ['filippo', 'palmieri']
# sergey
# ['sergey']
# zadyraka
# ['sergey', 'zadyraka']
# shilpa
# ['shilpa']
# baweja
# ['shilpa', 'baweja']
# gaurav
# ['gaurav']
# bobhate
# ['gaurav', 'bobhate']
# robin
# ['robin']
# rajan
# ['robin', 'rajan']
# lukas
# ['lukas']
# klehr
# ['lukas', 'klehr']
# denis
# ['denis']
# zlobin
# ['denis', 'zlobin']
# grace
# ['grace']
# hur
# ['grace', 'hur']
# yun
# ['yun']
# ru
# ['yun', 'ru']
# chen
# ['yun', 'ru', 'chen']
# partha
# ['partha']
# dash
# ['partha', 'dash']
# sarah
# ['sarah']
# lünsmann
# ['sarah', 'lnsmann']
# cristina
# ['cristina']
# simion
# ['cristina', 'simion']
# ekaterina
# ['ekaterina']
# firsova
# ['ekaterina', 'firsova']
# sahil
# ['sahil']
# aggarwal
# ['sahil', 'aggarwal']
# pujan
# ['pujan']
# chamani
# ['pujan', 'chamani']
# cheri
# ['pujan', 'chamani', 'cheri']
# erin
# ['erin']
# bohmiller
# ['erin', 'bohmiller']
# alexandra
# ['alexandra']
# "sasha"
# ['alexandra', 'sasha']
# maximova
# ['alexandra', 'sasha', 'maximova']
# ritika
# ['ritika']
# sahni
# ['ritika', 'sahni']
# saurabh
# ['saurabh']
# midha
# ['saurabh', 'midha']
# aditya
# ['aditya']
# konarde
# ['aditya', 'konarde']
# thomas
# ['thomas']
# abeln
# ['thomas', 'abeln']
# ilya
# ['ilya']
# egorov
# ['ilya', 'egorov']
# elitsa
# ['elitsa']
# menkova
# ['elitsa', 'menkova']
# arina
# ['arina']
# ignatenkova
# ['arina', 'ignatenkova']
# dr.
# ['dr']
# mario
# ['dr', 'mario']
# lenz
# ['dr', 'mario', 'lenz']
# grégoire
# ['grgoire']
# le
# ['grgoire', 'le']
# bras
# ['grgoire', 'le', 'bras']
# aleksey
# ['aleksey']
# goncharenko
# ['aleksey', 'goncharenko']
# martin
# ['martin']
# thiel
# ['martin', 'thiel']
# kira
# ['kira']
# valah
# ['kira', 'valah']
# faisal
# ['faisal']
# khushnood
# ['faisal', 'khushnood']
# nada
# ['nada']
# el
# ['nada', 'el']
# nadi
# ['nada', 'el', 'nadi']
# adva
# ['adva']
# bendov
# ['adva', 'bendov']
# georgiana
# ['georgiana']
# ciobotaru
# ['georgiana', 'ciobotaru']
# valentin
# ['valentin']
# klein
# ['valentin', 'klein']
# katia
# ['katia']
# cassano
# ['katia', 'cassano']
# (高凱蒂)
# ['katia', 'cassano', '']
# birte
# ['birte']
# loeckel
# ['birte', 'loeckel']
# thomas
# ['thomas']
# manoila
# ['thomas', 'manoila']
# luca-elia
# ['lucaelia']
# salomon,
# ['lucaelia', 'salomon']
# m.a
# ['lucaelia', 'salomon', 'ma']
# susana
# ['susana']
# arce
# ['susana', 'arce']
# silva
# ['susana', 'arce', 'silva']
# francisca
# ['francisca']
# errázuriz
# ['francisca', 'errzuriz']
# anex-dit-chenaud
# ['francisca', 'errzuriz', 'anexditchenaud']
# vipplov
# ['vipplov']
# c
# ['vipplov', 'c']
# irina
# ['irina']
# pușca
# ['irina', 'puca']
# david
# ['david']
# krebs
# ['david', 'krebs']
# sarvesh
# ['sarvesh']
# mishra
# ['sarvesh', 'mishra']
# abhishek
# ['abhishek']
# khanna
# ['abhishek', 'khanna']
# magnus
# ['magnus']
# ahmad
# ['magnus', 'ahmad']
# pouya
# ['pouya']
# naserian
# ['pouya', 'naserian']
# ranjith
# ['ranjith']
# puttarama
# ['ranjith', 'puttarama']
# sunanda
# ['ranjith', 'puttarama', 'sunanda']
# naik
# ['ranjith', 'puttarama', 'sunanda', 'naik']
# nitin
# ['nitin']
# nikesh
# ['nitin', 'nikesh']
# georgios
# ['georgios']
# gkoutsidis
# ['georgios', 'gkoutsidis']
# vibhuti
# ['vibhuti']
# singh
# ['vibhuti', 'singh']
# tanja
# ['tanja']
# bihler
# ['tanja', 'bihler']
# ha-jo
# ['hajo']
# konrad
# ['hajo', 'konrad']
# abdallah
# ['abdallah']
# khalidi
# ['abdallah', 'khalidi']
# ivan
# ['ivan']
# dudarev
# ['ivan', 'dudarev']
# corinne
# ['corinne']
# wilhelm
# ['corinne', 'wilhelm']
# 🚀
# ['corinne', 'wilhelm', '']
# communication
# ['corinne', 'wilhelm', '', 'communication']
# coach
# ['corinne', 'wilhelm', '', 'communication', 'coach']
# gaurang
# ['gaurang']
# bhatt
# ['gaurang', 'bhatt']
# evren
# ['evren']
# dombak
# ['evren', 'dombak']
# kathryn
# ['kathryn']
# ward-gittos
# ['kathryn', 'wardgittos']
# aditya
# ['aditya']
# varma
# ['aditya', 'varma']
# penmetsa
# ['aditya', 'varma', 'penmetsa']
# aleksandra
# ['aleksandra']
# tusz
# ['aleksandra', 'tusz']
# dr.
# ['dr']
# erik
# ['dr', 'erik']
# straub
# ['dr', 'erik', 'straub']
# cheng
# ['cheng']
# liu
# ['cheng', 'liu']
# erfan
# ['erfan']
# mohseninejad
# ['erfan', 'mohseninejad']
# pamela
# ['pamela']
# gonzalez
# ['pamela', 'gonzalez']
# daniele
# ['daniele']
# romio
# ['daniele', 'romio']
# muhammad
# ['muhammad']
# saad
# ['muhammad', 'saad']
# iqbal
# ['muhammad', 'saad', 'iqbal']
# marzieh
# ['marzieh']
# sasaninejad
# ['marzieh', 'sasaninejad']
# alice
# ['alice']
# sofie
# ['alice', 'sofie']
# schroeder
# ['alice', 'sofie', 'schroeder']
# dibyanshee
# ['dibyanshee']
# mishra
# ['dibyanshee', 'mishra']
# abhinav
# ['abhinav']
# paul
# ['abhinav', 'paul']
# ankur
# ['ankur']
# bhatia
# ['ankur', 'bhatia']
# iuliana
# ['iuliana']
# petrescu
# ['iuliana', 'petrescu']
# (formerly
# ['iuliana', 'petrescu', 'formerly']
# alexandrescu)
# ['iuliana', 'petrescu', 'formerly', 'alexandrescu']
# makedonka
# ['makedonka']
# stamatova
# ['makedonka', 'stamatova']
# felix
# ['felix']
# kalkuhl
# ['felix', 'kalkuhl']
# adrian
# ['adrian']
# molina
# ['adrian', 'molina']
# zainab
# ['zainab']
# ilo
# ['zainab', 'ilo']
# rohan
# ['rohan']
# parkar
# ['rohan', 'parkar']
# miji
# ['miji']
# lee
# ['miji', 'lee']
# sneha
# ['sneha']
# samanta
# ['sneha', 'samanta']
# sree
# ['sree']
# rama
# ['sree', 'rama']
# chinthamsetty
# ['sree', 'rama', 'chinthamsetty']
# sneha
# ['sneha']
# panda
# ['sneha', 'panda']
# jonathan
# ['jonathan']
# muehlbauer
# ['jonathan', 'muehlbauer']
# mariano
# ['mariano']
# fernández
# ['mariano', 'fernndez']
# cocirio
# ['mariano', 'fernndez', 'cocirio']
# jonas
# ['jonas']
# prigge
# ['jonas', 'prigge']
# ali
# ['ali']
# akbar
# ['ali', 'akbar']
# khan,
# ['ali', 'akbar', 'khan']
# mba
# ['ali', 'akbar', 'khan', 'mba']
# daniel
# ['daniel']
# lópez
# ['daniel', 'lpez']
# contreras
# ['daniel', 'lpez', 'contreras']
# rim
# ['rim']
# bensouf
# ['rim', 'bensouf']
# oguz
# ['oguz']
# celikada
# ['oguz', 'celikada']
# althaf
# ['althaf']
# ali
# ['althaf', 'ali']
# mattummathodi
# ['althaf', 'ali', 'mattummathodi']
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/2328978974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped.fullName = data_scraped.fullName.apply(process_name_not_removing)

# %%
data_scraped['lastName'] = data_scraped['lastName'].fillna('').str.lower()
data_scraped.lastName = data_scraped.lastName.apply(process_name_not_removing)
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/1248005558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['lastName'] = data_scraped['lastName'].fillna('').str.lower()
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/1248005558.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped.lastName = data_scraped.lastName.apply(process_name_not_removing)

# %%
import re # REGEX
def basic_cleaning(sentence):

    # 1. Removing whitespaces
    sentence = sentence.strip()

    #5 remove non-alpha characters
    sentence = re.sub(r"[^a-zA-Z]", '', sentence)

    # 2. Lowercasing
    sentence = sentence.lower()

    # 3. Removing numbers
    sentence = ''.join(char for char in sentence if not char.isdigit())

    # remove tags
    sentence = re.sub('<[^<]+>', "", sentence)

    # 4. Removing punctuation
    for punctuation in str.punctuation:
        sentence = sentence.replace(punctuation, '')

    return sentence

# %%
def process_name_not_removing(name):
    '''
    Utility function to process names
    '''''
    words = name.lower().strip(" .").split()

    processed_name = []
    # Iterate through each word
    for word in words:
        # Normalize the string to decomposed Unicode form
        word = basic_cleaning(word)
        normalized_s = unicodedata.normalize('NFD', word)        
        # Remove non-spacing marks (special characters)
        stripped_s = ''.join(c for c in normalized_s if unicodedata.category(c) != 'Mn')
        processed_name.append(stripped_s)
    return ' '.join(processed_name)

# %%
process_name_not_removing("fásdfg Npoih%7bx😆")
# Out:
# fásdfg
# ['fsdfg']
# npoih%7bx😆
# ['fsdfg', 'npoihbx']
# 'fsdfg npoihbx'

# %%
unique_attendees2['Company'] = unique_attendees2[['Company']].fillna('')

# %%
unique_attendees2.fullName = unique_attendees2.fullName.apply(process_name_not_removing)

# %%
unique_attendees2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fullName            781 non-null    object
#  1   numEvents           781 non-null    int64
#  2   First Name          781 non-null    object
#  3   Surname             781 non-null    object
#  4   Email               781 non-null    object
#  5   Company             781 non-null    object
#  6   Your Job Position   523 non-null    object
#  7   Choose your role    364 non-null    object
#  8   Choose your role.1  77 non-null     object
#  9   Seniority           55 non-null     object
#  10  UserID              781 non-null    int64
# dtypes: int64(2), object(9)
# memory usage: 67.2+ KB

# %%
data_scraped['UserID'] = float('nan')
# Out:
# /var/folders/5f/td3vxmq52mgbxcd36rlnh7wc0000gn/T/ipykernel_29737/1554709938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scraped['UserID'] = float('nan')

# %%
for j, row_ids in unique_attendees2.iterrows():
    # Iterate through each row in the scraped DataFrame
    found = False
    for index_scraped, row_scraped in data_scraped.iterrows():
        # Check if the rows match using the custom matching function
        if custom_user_matching(row_scraped, row_ids):
            # If a match is found, add the userID from the ids DataFrame to the scraped DataFrame
            data_scraped.at[index_scraped, 'UserID'] = row_ids['UserID']
            # data_scraped.at[index_scraped, 'Attendance'] = row_ids['Attendee Status']
            found = True
            break

    if found == False:
        print(f"Not found userID {row_ids['UserID']}  {row_ids['fullName']} {row_ids['Email']}")
# Out:
# Full name matched abdelrahman elfar for user 0
# Last name from full name matched wahba abdo wahba for user 1
# Not found userID 2  abhi kasoju kasoju.abhinaya@gmail.com
# Not found userID 3  abhishek agarwal aggyabhishek@gmail.com
# Full name matched abhishek khatri for user 4
# Full name matched abhishek wabale for user 5
# Full name matched abolfazl jafarzadehpour for user 6
# Not found userID 7  adithya krishnamurthy pkadithya90@gmail.com
# Not found userID 8  aditya bhirangi aditya_atul.bhirangi@edu.escp.eu
# Full name matched aditya konarde for user 9
# Full name matched aditya raghunath for user 10
# Full name matched adriano ruiz for user 11
# Full name matched adva bendov for user 12
# Full name matched agnel joby for user 13
# Not found userID 14  ahilan sundaralingam ahilan@be-light.app
# Last name from full name matched ahmad ahmad saeed for user 15
# Last name from full name matched ahmed ahmed ragab for user 16
# Full name matched aino kivinen for user 17
# Not found userID 18  akhrorova karomat tarkankaromat7@gmail.com
# Not found userID 19  akshay rote akshay.rote@gmail.com
# Your Job Position matched!!! al dede natalia pnshina for user 20
# Not found userID 21  alberto drateln albertovon@gmail.com
# Not found userID 22  alberto monaldi a.monaldi7@gmail.com
# Not found userID 24  aleksandr simukovic aleksandras.simukovic@gmail.com
# Full name matched aleksandr volosha for user 25
# Full name matched aleksej ruckoj for user 26
# Full name matched aleksey goncharenko for user 27
# Full name matched alessandra bari for user 28
# Full name matched alessandra fiorentino for user 29
# Your Job Position matched!!! alex boase alexander bahlk for user 31
# Your Job Position matched!!! alex bychok alexander bahlk for user 32
# Not found userID 33  alex diudiuk salesmacho@gmail.com
# Last name from full name matched fife alex fife for user 34
# Not found userID 35  alex gearing alexmgearing@gmail.com
# Your Job Position matched!!! alex simukovic alexander bahlk for user 36
# Full name matched alexander bahlk for user 37
# Full name matched alexander fife for user 38
# Not found userID 39  alexander suevalov suevalov.me@gmail.com
# Last name from full name matched maximova alexandra maximova for user 40
# Not found userID 41  alexandre landrieu alexandrelandrieu@gmail.com
# Your Job Position matched!!! ali badawy natalia pnshina for user 42
# Your Job Position matched!!! ali mahmoud natalia pnshina for user 43
# Full name matched alice mendeleyeva for user 44
# Not found userID 45  alicia mallor m.h.altea@gmail.com
# Not found userID 46  alina nekrasova nekrasova.alina99@gmail.com
# Last name from full name matched palmer alli palmer for user 47
# Not found userID 48  allison orsoni allison.orsoni@essec.edu
# Not found userID 49  amaka madueke amakagift10@gmail.com
# Last name from full name matched sadique aman sadique for user 50
# Last name from full name matched kern amelie kerne for user 51
# Full name matched amin jmyi for user 52
# Not found userID 53  amit koshta koshtaiitk@gmail.com
# Full name matched amon fayz for user 54
# Your Job Position matched!!! ana miranda anastasia bakhmutova for user 55
# Your Job Position matched!!! ana reyes anastasia kozmna for user 56
# Last name from full name matched datta anamika datta for user 57
# Not found userID 58  anand sridhar anandsridhar2073@gmail.com
# Not found userID 59  anant parashar anant.parashar@esmt.education
# Full name matched anastasia bakhmutova for user 60
# Your Job Position matched!!! anastasia buryak anastasia bakhmutova for user 61
# Not found userID 63  anastasia radziwill nastjadaff@gmail.com
# Full name matched anastasiia kostrub for user 64
# Not found userID 65  anastasiia kuzenkova kuzenkovanastya@gmail.com
# Not found userID 66  andre basora afbasora@gmail.com
# Not found userID 67  andrea guerra guerra.a82@gmail.com
# Last name from full name matched motta andrea motta for user 68
# Full name matched andrea picco for user 69
# Not found userID 70  andrei alekseev andr.alksv@gmail.com
# Last name from full name matched andres andres velandia for user 71
# Full name matched andrew quan for user 72
# Not found userID 73  andrey rk andrewklauds@gmail.com
# Full name matched andrey shilin for user 74
# Full name matched angel poon for user 75
# Last name from full name matched angela angela garay for user 76
# Not found userID 77  anica klinglermandig ruck.sack@posteo.de
# Full name matched aniket ambekar for user 78
# Full name matched ankit morajkar for user 80
# Full name matched anmol kawatra for user 81
# Your Job Position matched!!! ann khamitova jona david hoffmann for user 82
# Not found userID 83  annchristin schonert annchristin2008@yahoo.de
# Full name matched anna grosheva for user 84
# Full name matched anna lukyanovich for user 85
# Not found userID 86  anna schumacher anna-schumacher@gmx.net
# Full name matched anna suprun for user 87
# Full name matched anne bauer for user 88
# Full name matched annie li for user 89
# Not found userID 90  annika wiedera annikawiedera@aol.com
# Full name matched antonia landi for user 91
# Not found userID 92  anuja rana anuja.rana60@gmail.com
# Full name matched anvar atash for user 93
# Full name matched aqif hamid for user 94
# Full name matched arailym kaiyrova for user 95
# Full name matched ariel wu for user 96
# Not found userID 97  arik mezan amezan@gmail.com
# Full name matched arina ignatenkova for user 98
# Last name from full name matched kress aris kresskallidromitis for user 99
# Full name matched arkadeep sur for user 100
# Full name matched armin krahl for user 101
# Not found userID 102  artem ustinov ustinov.artem89@gmail.com
# Full name matched arthur annebicque for user 103
# Not found userID 104  arysthina arysanto theena.madeline@gmail.com
# Not found userID 107  augustina adolf augustina.adolf@gmail.com
# Last name from full name matched karadayilar aybala karadayilar for user 108
# Full name matched ayman chalhoub for user 109
# Full name matched babatunde kufo for user 110
# Full name matched balaji alagu for user 111
# Last name from full name matched syahroni banirahma syahroni for user 112
# Not found userID 113  basak akdas basakakdascan@gmail.com
# Not found userID 114  basavantrayagouda basanagouda vishalmu66@gmail.com
# Last name from full name matched busshardt bastian busshardt for user 115
# Last name from full name matched bonnet bastien bonneton for user 116
# Not found userID 117  bayangmbe mounmo bayangp0@gmail.com
# Full name matched beat weichsler for user 118
# Full name matched beatriz ponce for user 119
# Not found userID 120  bedrettin guener gunerb@gmail.com
# Full name matched beka kokoladze for user 121
# Full name matched bella grigoryants for user 122
# Full name matched benedetta montagnoli for user 124
# Not found userID 125  benjamin schriefer charlottenviertel.bs@gmail.com
# Not found userID 126  bhargavi mandadi mandhadi.bhargavireddy@gmail.com
# Full name matched blagojche kuzevski for user 127
# Full name matched blen baheru for user 128
# Full name matched bola oyebo for user 129
# Last name from full name matched awan bonsuk awani for user 130
# Full name matched borjan nikolov for user 131
# Full name matched braian lugo for user 132
# Not found userID 133  bruno pacheco bruno.pacheco.pro@gmail.com
# Full name matched burak yigen for user 134
# Full name matched busayomi omotosho for user 135
# Not found userID 136  cain hayward cainhayward.de.ux@gmail.com
# Full name matched caitlin sullivan for user 137
# Full name matched camila jatahy for user 138
# Not found userID 139  carlos alvarez cgalindo@babbel.com
# Full name matched carlotta clauter for user 140
# Last name from full name matched arzamendi carolina arzamendi for user 141
# Not found userID 142  carolina gomes carol.caiadogomes@gmail.com
# Not found userID 143  catarina pinto catarinapp24@gmail.com
# Last name from full name matched casas catherine gomez for user 144
# Full name matched cemal toprak for user 146
# Not found userID 147  chaitra taori chaitrataori2@gmail.com
# Last name from full name matched mehmi chan mehmi for user 148
# Last name from full name matched chan chandrashekhar surve for user 149
# Full name matched charles vestal for user 150
# Full name matched charline goethals for user 151
# Last name from full name matched cheri cheri s for user 152
# Not found userID 153  cheslin orie chesorie@gmail.com
# Last name from full name matched matt chris matthews for user 154
# Last name from full name matched piazza chris piazz for user 155
# Full name matched chris schlichting for user 156
# Last name from full name matched tian christian barra for user 157
# Last name from full name matched tian christian castillo for user 158
# Last name from full name matched tian christian mancini for user 159
# Full name matched christine plotz for user 160
# Full name matched christine thach for user 161
# Not found userID 162  christoph bresler cbresler@digitale-leute.de
# Last name from full name matched hahn christopher hahn for user 163
# Not found userID 164  colleen mccracken colleenmcc03@gmail.com
# Not found userID 165  cuilu fan cuilu.fan@gmail.com
# Full name matched dalma szabo for user 166
# Last name from full name matched krause dan krause for user 167
# Last name from full name matched bartholomae daniel bartholomae for user 168
# Full name matched daniel r for user 170
# Full name matched daniel schwarz for user 171
# Your Job Position matched!!! daniel zherenkov daniel schwarz for user 172
# Full name matched daniele ronca for user 174
# Full name matched daniil tykheev for user 175
# Not found userID 176  danish kanojia danishmcanit@gmail.com
# Full name matched daria elson for user 177
# Not found userID 178  daria kurchinskaia d.kurchinskaya@yandex.ru
# Full name matched daria lezhai for user 179
# Not found userID 180  daria shyman daria.shyman@gmail.com
# Not found userID 181  darian kusuma darian.kusuma@vimcar.com
# Not found userID 182  darinka burovska burovska@gmail.com
# Full name matched darrena mamm for user 183
# Last name from full name matched david dave feldman for user 184
# Last name from full name matched david david grund for user 185
# Last name from full name matched hoffmann david hoffmann for user 186
# Last name from full name matched david david wenk for user 187
# Full name matched davud samadov for user 188
# Not found userID 189  deanna wright deanna.j.wright@gmail.com
# Last name from full name matched rakshit debarati rakshit for user 190
# Full name matched denis liggeri for user 191
# Full name matched denis zlobin for user 192
# Full name matched derek myers for user 194
# Not found userID 195  desiree maestri maestri.desiree@gmail.com
# Full name matched despoina sarikou for user 196
# Full name matched dheeraj suvarna for user 198
# Full name matched dilan gevsek for user 200
# Last name from full name matched malyshenko dima malyshenko for user 201
# Full name matched dmitry deniskin for user 202
# Full name matched dominik hess for user 203
# Last name from full name matched kress dominik kress for user 204
# Not found userID 205  dominik wenzel dominik.wenzel@outlook.com
# Full name matched dulano asalemo for user 206
# Full name matched duroseme taylor for user 207
# Full name matched egor zakharov for user 208
# Your Job Position matched!!! ekaterina firsova ekaterina zenkevich  for user 209
# Last name from full name matched zenkevich ekaterina zenkevich for user 210
# Full name matched eleftherios christou for user 211
# Full name matched elena berendeeva for user 212
# Not found userID 213  elena kalambet tpe-cka@yandex.ru
# Full name matched elena sergiampietri for user 214
# Not found userID 215  elena t tuzhikova.el@gmail.com
# Full name matched eli cohen for user 216
# Last name from full name matched kargruber elia kargruber for user 217
# Full name matched elif bakkal for user 218
# Not found userID 219  elif gumus gumuselif84@gmail.com
# Full name matched elisa marku for user 221
# Not found userID 222  elisa song elisa.shanghai@gmail.com
# Not found userID 224  elisabeth chung echung@babbel.com
# Last name from full name matched hirvensalo eliza hirvensalo for user 225
# Not found userID 226  elizaveta pogasii lisa.pogasii@gmail.com
# Not found userID 227  ellen sea ellen.v.sea@gmail.com
# Full name matched elliot altham for user 228
# Not found userID 229  elroy chibex elroychibex@gmail.com
# Last name from full name matched berg else berg for user 230
# Full name matched emanoil topalov for user 231
# Full name matched emanuele libralato for user 232
# Not found userID 233  emilie wong emiliexw@gmail.com
# Not found userID 237  erfolk events evtbrt22@elevanation.com
# Your Job Position matched!!! erin bohmiller ekaterina zenkevich  for user 239
# Choose your role matched!!! esther vidal esther vidal andreu for user 240
# Full name matched evgenia adam for user 241
# Full name matched evgeniia golubeva for user 242
# Full name matched ewa kiwus for user 243
# Full name matched fabian kleeberger for user 244
# Last name from full name matched zagel fabian zag for user 245
# Full name matched fabio muroni for user 246
# Full name matched fabius weiner for user 247
# Not found userID 248  faheem mohammad faheem7791@gmail.com
# Full name matched faisal khushnood for user 249
# Full name matched farideh samadi for user 250
# Full name matched felix dahlmeyer for user 251
# Full name matched felix preuss for user 252
# Full name matched fernanda pugliero for user 253
# Not found userID 254  feten mansour feten.bmansour@gmail.com
# Full name matched filippo palmieri for user 255
# Not found userID 256  finn geldermann finn@co-ps.com
# Full name matched florian bonnet for user 258
# Full name matched florian straub for user 259
# Full name matched francesco paltrinieri for user 260
# Not found userID 261  galynka naumenko mrs.nazaruk@gmail.com
# Not found userID 262  gary touet garytouet@gmail.com
# Your Job Position matched!!! gaurav bobhate gaurav gulrajani for user 263
# Full name matched gautami pandit for user 265
# Not found userID 266  geonyoung lee geonyoung.lee.inbox@gmail.com
# Last name from full name matched george george gibson for user 267
# Full name matched georgiana ciobotaru for user 268
# Full name matched giacomo giorgianni for user 269
# Not found userID 270  giacomo hendel giacomo.he@gmail.com
# Full name matched girish nalwade for user 272
# Full name matched grace hur for user 273
# Last name from full name matched bras gregoire bras for user 274
# Not found userID 275  guillaume belhaj guillaume.belhaj@esmt.education
# Not found userID 276  gulsemin demir gulseminrisvan@gmail.com
# Full name matched hadi attaran for user 277
# Not found userID 278  halina tkaczenko hala.tkaczenko@gmail.com
# Full name matched hamlet hayrapetyan for user 279
# Last name from full name matched naqvi hasan naqvi for user 280
# Full name matched hashir rizwan for user 281
# Full name matched hayyaan ahmad for user 282
# Not found userID 283  heba ledwon heba.ledwon@gmail.com
# Not found userID 284  heike lewerenz heike-lewerenz@gmx.de
# Not found userID 285  heloisa piccirilli heloisa.piccirilli@gmail.com
# Full name matched heorhi talochka for user 286
# Full name matched hiba ganta for user 287
# Full name matched hiya gaine for user 288
# Full name matched hosna shayani for user 289
# Not found userID 290  hugo lofquist events@hugolofquist.com
# Not found userID 291  hussam shams hussam.shams@gmail.com
# Full name matched iasmina craciun for user 292
# Full name matched ifrah khanyaree for user 293
# Not found userID 294  ignasi buch ignasibuch@gmail.com
# Not found userID 295  igor kochman kochman.iv@gmail.com
# Full name matched igor lahr for user 296
# Your Job Position matched!!! ilan zarantonello milana magurina for user 297
# Full name matched ilya blokh for user 299
# Full name matched ilya egorov for user 300
# Not found userID 301  ilya sidyakin sidyaking@gmail.com
# Full name matched indah harahap for user 302
# Full name matched ines jordan for user 303
# Not found userID 304  ira sheveleva hiirinasheveleva@gmail.com
# Last name from full name matched seres iren seres for user 305
# Not found userID 307  irene lavandera pacinha84@gmail.com
# Choose your role matched!!! irina protasevich irina reinerth for user 308
# Full name matched irina reinerth for user 309
# Your Job Position matched!!! irina timofeeva irina reinerth for user 310
# Not found userID 311  irina ukhanova ukhanovait@gmail.com
# Full name matched irma gagulia for user 312
# Not found userID 313  irmela sinkewitsch irmela@unlearnbusinesslab.com
# Full name matched isabella beck for user 314
# Not found userID 316  isabelle silfver isabelle.silfver@gmail.com
# Not found userID 317  issagha diop issagh27@gmail.com
# Full name matched iswarya sakthivel for user 318
# Full name matched itir ergin for user 319
# Last name from full name matched andres iuliana petrescu for user 320
# Full name matched ivan dudarev for user 321
# Full name matched ivan rublev for user 322
# Not found userID 323  izzat raihan official.izzatr@gmail.com
# Full name matched jack lancaster for user 324
# Full name matched jakub uniejewski for user 325
# Not found userID 326  jane uzunovski jane@basicmath.co.jp
# Not found userID 327  janet mao janet.w.mao@gmail.com
# Full name matched janine magayanes for user 328
# Full name matched jannik schewe for user 329
# Not found userID 330  japhet ngoie japhetngoie184@gmail.com
# Not found userID 331  jatna algarra jat.algarra@gmail.com
# Not found userID 333  javier inocente javinocente@gmail.com
# Not found userID 334  jeeva john jeevajohn0079@gmail.com
# Not found userID 337  jess he jhe@hellofresh.com
# Not found userID 338  jiaxin l casin.lau@foxmail.com
# Last name from full name matched perrevoort jil perrevoort for user 339
# Full name matched jitesh nayak for user 340
# Not found userID 342  joanna bienko jmbienko@gmail.com
# Full name matched joanna wilkans for user 343
# Not found userID 345  johannes caspari johannes@caspari5.de
# Full name matched johannes holl for user 346
# Full name matched johannes schweig for user 347
# Full name matched johannes wrubel for user 348
# Full name matched john ngo for user 349
# Choose your role matched!!! juan mendoza juan jose mendoza santana for user 350
# Full name matched jules nijskens for user 351
# Full name matched julia gentsch for user 352
# Full name matched julia oehme for user 353
# Full name matched julia steier for user 354
# Full name matched julian lindloff for user 355
# Full name matched julian ringel for user 356
# Full name matched jyoti sharma for user 358
# Your Job Position matched!!! kai wieland valeriia kaimashnikova for user 359
# Last name from full name matched berg kaisa berger for user 360
# Not found userID 361  karina dubovik dubovikkn@gmail.com
# Full name matched karina hasler for user 362
# Full name matched karl villanueva for user 363
# Full name matched karolina kiszela for user 364
# Full name matched kate yanke for user 365
# Not found userID 366  kateryna kovtunovych katrina630@gmail.com
# Full name matched katharina andres for user 367
# Full name matched kelly hsu for user 369
# Not found userID 370  ken knoll ken.knoll@gmail.com
# Last name from full name matched matt ken r for user 371
# Not found userID 372  khemara ang engkhemara.ang@gmail.com
# Full name matched khrystyna svarychevska for user 373
# Full name matched kimberly schmitt for user 374
# Not found userID 375  kirandeep kaur kdkaur89@gmail.com
# Not found userID 376  klara haas klara-h@gmx.net
# Full name matched klara murzabekova for user 377
# Last name from full name matched maleki kourosh maleki for user 378
# Last name from full name matched chan krischan mertens for user 379
# Full name matched krishen mertens for user 380
# Last name from full name matched tian kristian herger for user 381
# Last name from full name matched ruseva kristina ruseva for user 382
# Full name matched krutika gopalakrishnan for user 383
# Full name matched krzysztof glistak for user 384
# Full name matched kseniia shyshkova for user 385
# Full name matched kunal kava for user 386
# Not found userID 387  kzltan yuceil kiziltan.yuceil@gmail.com
# Full name matched lara orrico for user 388
# Full name matched laura soto for user 389
# Full name matched leon gerdes for user 390
# Not found userID 391  leonard kehl kehl.leonard@gmail.com
# Full name matched leonardo tognon for user 392
# Not found userID 393  liliana pereira lilianapereira1000@gmail.com
# Not found userID 394  lilika schulteostermann lilikamagdalena@gmail.com
# Full name matched linn legros for user 395
# Full name matched lisa trueblood for user 396
# Not found userID 397  liubov antonova antonova.liubov.n@gmail.com
# Not found userID 398  livio marcheschi livmkk@gmail.com
# Full name matched liya kachanova for user 399
# Not found userID 400  logan ouellette oue.logan@gmail.com
# Full name matched louise plessis for user 401
# Full name matched lubena awan for user 402
# Full name matched lucas minetti for user 403
# Full name matched lucas rech for user 404
# Last name from full name matched zandon lucas zandona for user 405
# Full name matched luis rieke for user 406
# Last name from full name matched suda luisa suda for user 407
# Last name from full name matched quan luiza munhos for user 408
# Full name matched lukas klehr for user 409
# Full name matched lydia dietrich for user 410
# Full name matched lynn ng for user 411
# Not found userID 413  magda zochowska magda.zochowska@gmail.com
# Not found userID 414  magdalena kaaden lena.kaaden@gmail.com
# Last name from full name matched grachev maksim grachev for user 415
# Last name from full name matched malik malik ebers for user 416
# Last name from full name matched malik malika umarova for user 417
# Not found userID 418  malte scholz malte@airfocus.io
# Not found userID 419  mandy le mandy.le@gmx.net
# Full name matched manizeh dossa for user 420
# Last name from full name matched pandey manoj pandey for user 421
# Full name matched manu raivio for user 422
# Not found userID 423  marc atasoy marc.atasoy@hellofresh.com
# Full name matched marc boner for user 424
# Full name matched marcin belinski for user 425
# Full name matched marcin fabianczyk for user 426
# Not found userID 427  marco tormo marcotormomoran@gmail.com
# Not found userID 428  marcos monteiro marcos.femonteiro@gmail.com
# Last name from full name matched rubio marcos rubio for user 429
# Full name matched mariliis algma for user 430
# Not found userID 431  maria lachmann lachmannmaria@gmail.com
# Not found userID 432  maria muga mmugaesp@gmail.com
# Full name matched marie aurhammer for user 434
# Not found userID 435  marie boucomont marie.boucomont@sensirion.com
# Last name from full name matched gruensteidl mariella grunsteidl for user 436
# Your Job Position matched!!! mario lenz mario schwarz for user 437
# Last name from full name matched schwarz mario schwarz for user 438
# Not found userID 440  mark jennings markdjennings@gmail.com
# Full name matched marta osowiecka for user 441
# Full name matched martin klein for user 442
# Last name from full name matched rosenmejer martin rosenmejer for user 443
# Not found userID 444  martina gilic gilicmartina@gmail.com
# Not found userID 445  maryia dubrouskaya m.dubrouskaya@gmail.com
# Full name matched masha lutsenko for user 446
# Full name matched mason jeong for user 447
# Not found userID 448  mateusz hublewski hublewski@gmail.com
# Last name from full name matched berg mathis lichtenberger for user 450
# Not found userID 451  mats kipper kipper.mats@gmail.com
# Last name from full name matched matt matt a for user 452
# Last name from full name matched matt matt roskovec for user 453
# Last name from full name matched matt matteo donini for user 454
# Last name from full name matched matt matteo fava for user 455
# Last name from full name matched matt matteo kubuc for user 456
# Last name from full name matched matt matthias diener for user 457
# Last name from full name matched matt matthias siwy for user 458
# Last name from full name matched matt matthieu sloves for user 459
# Full name matched max beitler for user 461
# Last name from full name matched hess max heds for user 462
# Full name matched max ostapenko for user 463
# Full name matched max scheidlock for user 464
# Last name from full name matched wiesentreu maximilian wiesentreu for user 465
# Not found userID 466  maxmillian augoye maxoaugoye@gmail.com
# Full name matched maycon stamboroski for user 467
# Full name matched mehdi eyvazzadeh for user 468
# Last name from full name matched ercan mehmet ercan for user 469
# Last name from full name matched behar meltem behar for user 470
# Not found userID 471  merve erbaylar erbaylarmerve@gmail.com
# Full name matched merve salmaz for user 472
# Full name matched michele cerullo for user 473
# Full name matched michele fumagalli for user 474
# Last name from full name matched tian michelle tian for user 475
# Full name matched miji lee for user 477
# Not found userID 478  mikail p ticktak@mailbox.org
# Not found userID 479  mike betts mike.c.betts@mac.com
# Last name from full name matched berg mikhail grinberg for user 480
# Full name matched milana magurina for user 481
# Full name matched milena fagandini for user 482
# Full name matched mircea giurca for user 483
# Full name matched miriam hutter for user 484
# Not found userID 485  miwa km arumikawim@gmail.com
# Not found userID 486  miyuu harada miyuu.harada.jp@gmail.com
# Your Job Position matched!!! mohamed hanafy mohamed salah for user 487
# Full name matched mohamed salah for user 488
# Full name matched mohit bansal for user 489
# Full name matched mojgan behravan for user 490
# Full name matched mojtaba fattahi for user 491
# Not found userID 492  monika dubinska monikadubinska88@gmail.com
# Full name matched mridul jain for user 493
# Last name from full name matched verma mritunjay verma for user 494
# Last name from full name matched ahmed musavvir ahmed for user 495
# Full name matched myles sutholt for user 496
# Last name from full name matched nadi nada elnadi for user 497
# Full name matched nadine verbeek for user 498
# Not found userID 499  nadya klepcha n.d.klepcha@gmail.com
# Full name matched nail valiyev for user 500
# Not found userID 501  nana afriyie nana@asforafriyie.com
# Last name from full name matched lange nanette lange for user 502
# Your Job Position matched!!! natalia anastasova natalia pnshina for user 503
# Last name from full name matched filvarova natalia filvarova for user 504
# Your Job Position matched!!! natalia panshina natalia pnshina for user 505
# Not found userID 506  natalia pegoraro natipegoraro@gmail.com
# Last name from full name matched petrov natalia petrova for user 507
# Full name matched nataliia senatorova for user 508
# Full name matched neha george for user 509
# Not found userID 510  neli strukelj nelizabeta@gmail.com
# Not found userID 511  nesha siwi i@neshasiwi.de
# Not found userID 512  niamh teelingsann teelingn@tcd.ie
# Not found userID 513  nicholas laczkovich grinner@gmx.at
# Last name from full name matched stbe nick stube for user 514
# Last name from full name matched nardo nicola nardo for user 515
# Full name matched nicolai brunner for user 516
# Full name matched nicole calderon for user 517
# Full name matched nihad zeitouny for user 518
# Full name matched nikita zavyalov for user 519
# Full name matched niklas springer for user 520
# Full name matched nikola domazet for user 521
# Not found userID 522  nikolai rol rol.nikolay@gmail.com
# Full name matched nina mannheimer for user 523
# Full name matched nina untch for user 524
# Not found userID 525  nina wilken ninauix@gmail.com
# Full name matched nirvan mahat for user 526
# Last name from full name matched kumari nisha kumari for user 527
# Not found userID 528  nitin augustine nitintoc@gmail.com
# Full name matched niv david for user 529
# Not found userID 530  normani duma normani.deutsche@gmail.com
# Full name matched nuno moreira for user 531
# Full name matched nuwan withanage for user 532
# Full name matched oguz celikada for user 533
# Full name matched olaf lenzmann for user 535
# Full name matched oleksii klochai for user 536
# Not found userID 537  oleksiy sokolov os@sokolov.vc
# Full name matched olena shapoval for user 538
# Not found userID 539  olga pette acta@sent.com
# Not found userID 540  oli k oliver.ka8@gmail.com
# Not found userID 541  olivia dumnicka oliwia.dumnicka@gmail.com
# Not found userID 542  oliwia grobys o.liwier@hotmail.com
# Last name from full name matched omotola oluwanifemi omotola for user 543
# Not found userID 544  olya laktushina olya.laktushina@gmail.com
# Not found userID 545  osama abuhantash osamahantash@hotmail.com
# Not found userID 546  osama altalli osama_altalli@outlook.com
# Full name matched oskar salmhofer for user 547
# Full name matched ovidiu oanca for user 548
# Not found userID 549  pana y thewizearth@gmail.com
# Not found userID 550  panthip pooput z.toonzii@gmail.com
# Full name matched partha dash for user 551
# Not found userID 552  partha mandal partham16.colab@gmail.com
# Full name matched pasquale romito for user 553
# Full name matched patrick beeker for user 554
# Last name from full name matched castro paula castro for user 555
# Last name from full name matched castro paulo ferreira for user 556
# Last name from full name matched lubis permatasari lubis for user 557
# Not found userID 558  peter hilton peter.hilton@gmail.com
# Full name matched peter rubarth for user 559
# Full name matched philip homnack for user 560
# Full name matched philipp baumer for user 561
# Full name matched philipp schimmelfennig for user 562
# Full name matched philipp tessmann for user 563
# Not found userID 564  phillip schacht phillip.schacht@veve.com
# Full name matched phuc nguyen for user 565
# Not found userID 566  pia hosdorff pia.hoesdorff@live.de
# Full name matched piotr tomaszewski for user 567
# Not found userID 568  praewa sinntaweekarn p.prwask@gmail.com
# Full name matched prajwal negapettam for user 569
# Not found userID 570  prakruthi mollagavalli prakruthimp1596@gmail.com
# Full name matched prashanth veeranki for user 571
# Not found userID 572  prateek gaur dkvpckmzkn@privaterelay.appleid.com
# Full name matched quezia barrozo for user 573
# Last name from full name matched ebek radomir sebek for user 574
# Full name matched radu lupu for user 575
# Full name matched rafael weninger for user 576
# Not found userID 577  raghul babu raghulb.9510@gmail.com
# Last name from full name matched quan rahman shafiee for user 578
# Not found userID 579  rahul belekar belekarrahulvk18@gmail.com
# Full name matched rahul ranjan for user 580
# Full name matched rajesh chowdary for user 581
# Full name matched ramin amirov for user 582
# Full name matched ramzy ismail for user 583
# Not found userID 585  rao masood raoatifmasood@gmail.com
# Last name from full name matched neufeld regina neufeld for user 587
# Full name matched renata iwamoto for user 588
# Full name matched riccardo costi for user 589
# Not found userID 590  riccardo jacob riccardo.jacob96@gmail.com
# Not found userID 591  richard schardey r.schardey@gmail.com
# Last name from full name matched tjahjono rifqi tjahyono for user 592
# Not found userID 593  rijesh haridas rijesh.menon@gmail.com
# Full name matched robert lange for user 594
# Not found userID 595  robin greenwood robincgreenwood@gmail.com
# Full name matched roland butler for user 597
# Not found userID 598  romaisa fawad romaisa.fawad3@gmail.com
# Your Job Position matched!!! roman nikulin roman prys for user 599
# Last name from full name matched prys roman prysiazhniuk for user 600
# Not found userID 601  ronja klemm ronjaklm3@gmail.com
# Full name matched rosario marrazzo for user 602
# Full name matched ross kinmont for user 603
# Full name matched roswell balentien for user 604
# Last name from full name matched islam rubaiyat islam for user 605
# Full name matched ruko kuga for user 606
# Not found userID 607  rutu mistry rutumistryrishabh@gmail.com
# Full name matched sabina radziush for user 608
# Full name matched sabrina luna for user 609
# Not found userID 610  safi ullah safiu799@gmail.com
# Not found userID 611  saharukh shaikh cr7.saharukh@gmail.com
# Full name matched sahil aggarwal for user 612
# Full name matched sahil gambhir for user 613
# Not found userID 614  sahil senapaty sahilsnpt@gmail.com
# Full name matched saki cansev for user 615
# Full name matched salvatorina rassu for user 616
# Full name matched sam abdullaev for user 617
# Not found userID 618  sam c sson06825@gmail.com
# Last name from full name matched qidwai sameer qidwai for user 619
# Full name matched samuel ghebreab for user 620
# Full name matched sanjana laddha for user 622
# Full name matched sanjeev rao for user 623
# Full name matched sanjiv murali for user 624
# Last name from full name matched agestriani sanjung agestriani for user 625
# Full name matched sanna tietjen for user 626
# Last name from full name matched kumar santhosh kumar for user 627
# Last name from full name matched kumar santhosh ramasetty for user 628
# Full name matched sanyam arya for user 629
# Full name matched saptarshi baksi for user 630
# Your Job Position matched!!! sara forsthoff sara pattacini for user 631
# Full name matched sara santanen for user 632
# Last name from full name matched haider sarmad haider for user 634
# Full name matched sarvesh regmi for user 635
# Full name matched satoru teshima for user 636
# Not found userID 637  satpal pundeer de.satpal@gmail.com
# Full name matched saurabh midha for user 638
# Full name matched savani nimonkar for user 639
# Full name matched sean kress for user 640
# Last name from full name matched tian sebastian nordenbruch for user 641
# Full name matched seda baskan for user 643
# Full name matched seda bavas for user 644
# Full name matched sergey zadyraka for user 645
# Full name matched seyma tuzer for user 646
# Not found userID 647  shabbar raza syyedshabbarraza@gmail.com
# Last name from full name matched butt shahid butt for user 648
# Full name matched shantanu dikshit for user 649
# Not found userID 650  shay b shayb25.de@gmail.com
# Full name matched sheena antonios for user 651
# Last name from full name matched sherif sherif ragab for user 652
# Full name matched shilpa baweja for user 653
# Not found userID 654  shirin doroudian shirin.be.de@gmail.com
# Last name from full name matched wang shirlie wang for user 655
# Full name matched shivam runthala for user 656
# Full name matched shruthi subramanian for user 657
# Full name matched shubha pallavi for user 658
# Full name matched shubina roy for user 659
# Full name matched shuhrat pirnazarzoda for user 660
# Not found userID 661  shuvam sah shuvamshah98152@gmail.com
# Full name matched sidra aziz for user 662
# Full name matched siena chan for user 663
# Full name matched silvia lodato for user 664
# Full name matched simon hicks for user 665
# Full name matched simon petrov for user 666
# Not found userID 667  sinan oruc avisinan@gmail.com
# Full name matched sindhu maiyya for user 668
# Full name matched snezhanna mineeva for user 669
# Not found userID 670  soarea franchi soarea.franchi@gmail.com
# Full name matched sofia siepi for user 671
# Full name matched sofiia lukashevych for user 672
# Not found userID 673  solomiya khru solomia.khrushch@gmail.com
# Full name matched sonya pobiedimska for user 674
# Not found userID 675  soojin kim apponlyac@gmail.com
# Not found userID 676  soriniulian vidrascu sorin@b-projects.tech
# Full name matched soumitra sahu for user 677
# Full name matched soumya p for user 678
# Full name matched soumya patil for user 679
# Last name from full name matched chatterjee sreenjoy chatterjee for user 680
# Full name matched srishti maitra for user 681
# Full name matched stephanie kazalac for user 683
# Last name from full name matched kumar suresh kumar for user 684
# Last name from full name matched harahap suryani harahap for user 685
# Full name matched tamer elhawari for user 689
# Not found userID 690  tamirat lemma tamworku2@gmail.com
# Full name matched tansel can for user 691
# Not found userID 692  tanvi limaye tanvilimaye98@gmail.com
# Not found userID 693  tapan solanki tapan.solanki70@gmail.com
# Not found userID 694  tassia barros tassinha.cpr@gmail.com
# Last name from full name matched tian tatiana dzhambinova for user 695
# Last name from full name matched tian tatiana pridchenko for user 696
# Full name matched tauheed ahmed for user 697
# Full name matched teena kumari for user 698
# Not found userID 699  thang vu tng.vuduc@gmail.com
# Full name matched thomas abeln for user 700
# Full name matched thomas manoila for user 701
# Full name matched thomas seidl for user 702
# Last name from full name matched almeida tiago almeida for user 703
# Full name matched tim heiler for user 704
# Full name matched timm kick for user 706
# Not found userID 707  tom fisher profdrthomas@icloud.com
# Not found userID 708  tom klinge tom_klinge@outlook.de
# Not found userID 709  tom laufer tom@getloops.ai
# Not found userID 710  tommaso londi tommaso.londi@gmail.com
# Not found userID 711  tyler koenig tylerjkoenig@gmail.com
# Not found userID 712  tza dya adita@web.de
# Not found userID 713  tza tza aditya@zedat.fu-berlin.de
# Last name from full name matched singh udey singh for user 714
# Last name from full name matched kumar ugam kumar for user 715
# Not found userID 716  ugochukwu anaka allwise90@gmail.com
# Full name matched uliana fedorova for user 717
# Full name matched umair sarfraz for user 718
# Not found userID 719  umut dogdu umutdogdu@gmail.com
# Full name matched usman nasir for user 720
# Full name matched utpal das for user 721
# Full name matched vadim bayandin for user 722
# Full name matched vaibhav malik for user 724
# Full name matched valdrin trena for user 725
# Last name from full name matched klein valentin klein for user 726
# Not found userID 727  valentina barros valentinabarros7@gmail.com
# Full name matched valentyna pilianska for user 728
# Last name from full name matched floresducoing valeria ducoing for user 729
# Not found userID 730  valerie dehindejoseph donnadollinz9@gmail.com
# Full name matched valeriia kaimashnikova for user 731
# Not found userID 733  varsha lalwani varshalalwani94@gmail.com
# Last name from full name matched kumar vibhu kumar for user 734
# Not found userID 735  victor briestensky victor.eightyseven@gmail.com
# Full name matched victor semencenco for user 736
# Full name matched victoria kotlova for user 737
# Full name matched vieri fidanza for user 738
# Full name matched vimal garg for user 739
# Not found userID 740  vinanya gunnam vinanya.gunnam97@gmail.com
# Full name matched vinicio oliveira for user 741
# Not found userID 742  vinodh sampath vinodh.vinodh@gmail.com
# Not found userID 743  viola giorgione giorgioneviola@gmail.com
# Last name from full name matched sharma vipul sharma for user 744
# Last name from full name matched kotik vitali kotik for user 745
# Full name matched volodymyr borodavchuk for user 746
# Full name matched volodymyr lunov for user 747
# Not found userID 748  wahyu kusumawardani asriwahyukei@zoho.com
# Last name from full name matched choy waisum choy for user 749
# Not found userID 751  wanda raitelli wanraitelli@gmail.com
# Not found userID 752  wiktor gryff wgryff@yahoo.com
# Not found userID 755  wolfgang drews dr.wolfgang.drews@gmail.com
# Full name matched ximena hernandez for user 756
# Full name matched xiomara guillorme for user 757
# Your Job Position matched!!! xue chou xuejiaoshirlie wang for user 758
# Full name matched yanyan ma for user 759
# Full name matched yashvir chawla for user 760
# Full name matched yasir qureshi for user 761
# Not found userID 762  yasmin atrissi yasmin_atrissi@live.de
# Not found userID 763  yewande o wandy4wheels@gmail.com
# Not found userID 764  yorgo achkar yorgo.i.elachkar@gmail.com
# Not found userID 765  yulia vilenskiy yulkayulka@gmail.com
# Full name matched yuliya gustap for user 766
# Not found userID 767  yuno myung yuno+eventbrite@tomorrow.university
# Full name matched yuri orthey for user 768
# Full name matched yusuf algan for user 769
# Not found userID 771  yvonne hoeke jens-p.fischer@gmx.de
# Not found userID 772  zahra mirzaei z.mirzaii94@gmail.com
# Not found userID 773  zahra rouhi zahrarouhi@gmail.com
# Not found userID 774  zaron arava zaron.arava@gmail.com
# Full name matched zihan wang for user 775
# Not found userID 776  zimmermann jennifer zimmermannjennifer43@gmail.com
# Not found userID 777  ziyad mohiyudheen mmziyad@gmail.com
# Full name matched zsolt pap for user 778
# Not found userID 779  zsolt szrapko szrapko.zsolt+eventbrite@gmail.com
# Full name matched zulfiya malyshenko for user 780

# %%
# Iterate through each row in the ids DataFrame
for j, row_ids in unique_attendees2.iterrows():
    # Iterate through each row in the scraped DataFrame
    found = False
    for index_scraped, row_scraped in data_scraped.iterrows():
        # Check if the rows match using the custom matching function
        if custom_user_matching(row_scraped, row_ids):
            # If a match is found, add the userID from the ids DataFrame to the scraped DataFrame
            data_scraped.at[index_scraped, 'UserID'] = row_ids['UserID']
            # data_scraped.at[index_scraped, 'Attendance'] = row_ids['Attendee Status']
            found = True
            break
    if found == False:
 #       print(row_ids["fullName"], row_ids["Email"])
# Out:
# Full name matched abdelrahman elfar
# Last name from full name matched wahba abdo wahba
# First name matched, but not found :( abhi abhishek wabale
# First name matched, but not found :( abhi abhishek khatri
# First name matched, but not found :( abhi abhishek khanna
# First name matched, but not found :( abhi abhinav paul
# First name matched, but not found :( abhishek abhishek wabale
# First name matched, but not found :( abhishek abhishek khatri
# First name matched, but not found :( abhishek abhishek khanna
# First name matched, but not found :( abhishek abhishek wabale
# Full name matched abhishek khatri
# Full name matched abhishek wabale
# Full name matched abolfazl jafarzadehpour
# First name matched, but not found :( aditya aditya raghunath
# First name matched, but not found :( aditya aditya konarde
# First name matched, but not found :( aditya aditya varma penmetsa
# First name matched, but not found :( aditya aditya raghunath
# Full name matched aditya konarde
# Full name matched aditya raghunath
# Full name matched adriano ruiz
# Full name matched adva bendov
# Full name matched agnel joby
# Last name from full name matched ahmad ahmad saeed
# Last name from full name matched ahmed ahmed ragab
# Full name matched aino kivinen
# First name matched, but not found :( al ayman chalhoub
# First name matched, but not found :( al salvatorina rassu
# First name matched, but not found :( al nikita zavyalov
# Your Job Position matched!!! al natalia pnshina
# First name matched, but not found :( alberto alberto prez
# First name matched, but not found :( alberto alberto prez
# First name matched, but not found :( aleksandr aleksandr volosha
# First name matched, but not found :( aleksandr aleksandra tusz
# Full name matched aleksandr volosha
# Full name matched aleksej ruckoj
# Full name matched aleksey goncharenko
# Full name matched alessandra bari
# First name matched, but not found :( alessandra alessandra bari
# First name matched, but not found :( alessandra alessandra i
# Full name matched alessandra fiorentino
# First name matched, but not found :( alessandra alessandra bari
# First name matched, but not found :( alex alexander fife
# First name matched, but not found :( alex alexander charles boase cspo
# Your Job Position matched!!! alex alexander bahlk
# First name matched, but not found :( alex alexander fife
# First name matched, but not found :( alex alexander charles boase cspo
# Your Job Position matched!!! alex alexander bahlk
# First name matched, but not found :( alex alexander fife
# First name matched, but not found :( alex alexander charles boase cspo
# First name matched, but not found :( alex alexander bahlk
# First name matched, but not found :( alex alexandra sasha maximova
# First name matched, but not found :( alex iuliana petrescu formerly alexandrescu
# Last name from full name matched fife alex fife
# First name matched, but not found :( alex alexander fife
# First name matched, but not found :( alex alexander charles boase cspo
# First name matched, but not found :( alex alexander bahlk
# First name matched, but not found :( alex alexandra sasha maximova
# First name matched, but not found :( alex iuliana petrescu formerly alexandrescu
# First name matched, but not found :( alex alexander fife
# First name matched, but not found :( alex alexander charles boase cspo
# Your Job Position matched!!! alex alexander bahlk
# First name matched, but not found :( alexander alexander fife
# First name matched, but not found :( alexander alexander charles boase cspo
# Full name matched alexander bahlk
# Full name matched alexander fife
# First name matched, but not found :( alexander alexander fife
# First name matched, but not found :( alexander alexander charles boase cspo
# First name matched, but not found :( alexander alexander bahlk
# Last name from full name matched maximova alexandra maximova
# First name matched, but not found :( alexandre iuliana petrescu formerly alexandrescu
# Your Job Position matched!!! ali natalia pnshina
# Your Job Position matched!!! ali natalia pnshina
# Full name matched alice mendeleyeva
# First name matched, but not found :( alina andrea catalina motta
# Last name from full name matched palmer alli palmer
# First name matched, but not found :( allison allison palmer
# First name matched, but not found :( aman shruthi subramanian
# Last name from full name matched sadique aman sadique
# Last name from full name matched kern amelie kerne
# Full name matched amin jmyi
# Full name matched amon fayz
# First name matched, but not found :( ana nuwan withanage
# First name matched, but not found :( ana marijana medina
# First name matched, but not found :( ana anastasia kozmna
# Your Job Position matched!!! ana anastasia bakhmutova
# First name matched, but not found :( ana nuwan withanage
# First name matched, but not found :( ana marijana medina
# Your Job Position matched!!! ana anastasia kozmna
# Last name from full name matched datta anamika datta
# First name matched, but not found :( anant ananthakrishnan syamaprasad
# First name matched, but not found :( anastasia anastasia kozmna
# Full name matched anastasia bakhmutova
# First name matched, but not found :( anastasia anastasia kozmna
# Your Job Position matched!!! anastasia anastasia bakhmutova
# First name matched, but not found :( anastasia anastasia kozmna
# First name matched, but not found :( anastasia anastasia bakhmutova
# First name matched, but not found :( anastasia anastasia buryak
# Full name matched anastasiia kostrub
# First name matched, but not found :( anastasiia anastasiia kostrub
# First name matched, but not found :( andre andrey schfer
# First name matched, but not found :( andre andrea picco
# First name matched, but not found :( andre andrea catalina motta
# First name matched, but not found :( andre esther vidal andreu
# First name matched, but not found :( andre andrey shilin
# First name matched, but not found :( andre katharina andres
# First name matched, but not found :( andre paula andrea castro
# First name matched, but not found :( andre andrew quan
# First name matched, but not found :( andre iuliana petrescu formerly alexandrescu
# First name matched, but not found :( andrea andrea picco
# First name matched, but not found :( andrea andrea catalina motta
# First name matched, but not found :( andrea paula andrea castro
# First name matched, but not found :( andrea andrea picco
# Last name from full name matched motta andrea motta
# Full name matched andrea picco
# Last name from full name matched andres andres velandia
# Full name matched andrew quan
# First name matched, but not found :( andrey andrey schfer
# First name matched, but not found :( andrey andrey shilin
# First name matched, but not found :( andrey andrey schfer
# Full name matched andrey shilin
# Full name matched angel poon
# Last name from full name matched angela angela garay
# Full name matched aniket ambekar
# Full name matched ankit morajkar
# Full name matched anmol kawatra
# First name matched, but not found :( ann annemarie sagner
# Your Job Position matched!!! ann jona david hoffmann
# First name matched, but not found :( anna anna lukyanovich
# First name matched, but not found :( anna anna schneitz
# Full name matched anna grosheva
# Full name matched anna lukyanovich
# First name matched, but not found :( anna anna lukyanovich
# First name matched, but not found :( anna anna schneitz
# First name matched, but not found :( anna anna grosheva
# First name matched, but not found :( anna johanna kuhlee
# First name matched, but not found :( anna anna suprun
# First name matched, but not found :( anna joanna wilkans
# First name matched, but not found :( anna snezhanna mineeva
# First name matched, but not found :( anna sanna tietjen
# First name matched, but not found :( anna abhishek khanna
# First name matched, but not found :( anna anna lukyanovich
# First name matched, but not found :( anna anna schneitz
# First name matched, but not found :( anna anna grosheva
# First name matched, but not found :( anna johanna kuhlee
# Full name matched anna suprun
# First name matched, but not found :( anne annemarie sagner
# First name matched, but not found :( anne johannes holl
# First name matched, but not found :( anne johannes wrubel
# Full name matched anne bauer
# Full name matched annie li
# Full name matched antonia landi
# Full name matched anvar atash
# Full name matched aqif hamid
# Full name matched arailym kaiyrova
# Full name matched ariel wu
# First name matched, but not found :( arik despoina sarikou
# First name matched, but not found :( arina catarina pinto phd
# First name matched, but not found :( arina katharina andres
# First name matched, but not found :( arina marina ernst
# First name matched, but not found :( arina karina hasler
# Full name matched arina ignatenkova
# First name matched, but not found :( aris jeanluc herv  martinettidubuisson europaunion paris
# Last name from full name matched kress aris kresskallidromitis
# Full name matched arkadeep sur
# Full name matched armin krahl
# Full name matched arthur annebicque
# Last name from full name matched karadayilar aybala karadayilar
# Full name matched ayman chalhoub
# Full name matched babatunde kufo
# Full name matched balaji alagu
# Last name from full name matched syahroni banirahma syahroni
# Last name from full name matched busshardt bastian busshardt
# Last name from full name matched bonnet bastien bonneton
# Full name matched beat weichsler
# Full name matched beatriz ponce
# Full name matched beka kokoladze
# First name matched, but not found :( bella isabella beck
# Full name matched bella grigoryants
# Full name matched benedetta montagnoli
# Full name matched blagojche kuzevski
# Full name matched blen baheru
# Full name matched bola oyebo
# Last name from full name matched awan bonsuk awani
# Full name matched borjan nikolov
# Full name matched braian lugo
# Full name matched burak yigen
# Full name matched busayomi omotosho
# Full name matched caitlin sullivan
# Full name matched camila jatahy
# Full name matched carlotta clauter
# Last name from full name matched arzamendi carolina arzamendi
# First name matched, but not found :( carolina carolina torres arzamendi
# First name matched, but not found :( catarina catarina pinto phd
# First name matched, but not found :( catherine catherine windorf
# Last name from full name matched casas catherine gomez
# Full name matched cemal toprak
# First name matched, but not found :( chan liya kachanova
# Last name from full name matched mehmi chan mehmi
# Last name from full name matched chan chandrashekhar surve
# First name matched, but not found :( charles alexander charles boase cspo
# Full name matched charles vestal
# Full name matched charline goethals
# Last name from full name matched cheri cheri s
# First name matched, but not found :( chris christine plotz
# First name matched, but not found :( chris annchristin schnert
# Last name from full name matched matt chris matthews
# First name matched, but not found :( chris christine plotz
# First name matched, but not found :( chris annchristin schnert
# First name matched, but not found :( chris christine thach
# First name matched, but not found :( chris christian n mancini hehim
# Last name from full name matched piazza chris piazz
# First name matched, but not found :( chris christine plotz
# First name matched, but not found :( chris annchristin schnert
# First name matched, but not found :( chris christine thach
# First name matched, but not found :( chris christian n mancini hehim
# First name matched, but not found :( chris christopher piazza
# Full name matched chris schlichting
# First name matched, but not found :( christian christian n mancini hehim
# First name matched, but not found :( christian christian hoffmeister
# Last name from full name matched tian christian barra
# First name matched, but not found :( christian christian n mancini hehim
# First name matched, but not found :( christian christian hoffmeister
# Last name from full name matched tian christian castillo
# First name matched, but not found :( christian christian n mancini hehim
# First name matched, but not found :( christian christian hoffmeister
# Last name from full name matched tian christian mancini
# Full name matched christine plotz
# First name matched, but not found :( christine christine plotz
# Full name matched christine thach
# First name matched, but not found :( christoph christopher piazza
# First name matched, but not found :( christopher christopher piazza
# Last name from full name matched hahn christopher hahn
# Full name matched dalma szabo
# First name matched, but not found :( dan daniela knstle
# First name matched, but not found :( dan ines jordan
# First name matched, but not found :( dan daniel schwarz
# First name matched, but not found :( dan daniel r
# First name matched, but not found :( dan  daniel bartholomae
# Last name from full name matched krause dan krause
# First name matched, but not found :( daniel daniela knstle
# First name matched, but not found :( daniel daniel schwarz
# First name matched, but not found :( daniel daniel r
# Last name from full name matched bartholomae daniel bartholomae
# First name matched, but not found :( daniel daniela knstle
# First name matched, but not found :( daniel daniel schwarz
# First name matched, but not found :( daniel daniel r
# First name matched, but not found :( daniel  daniel bartholomae
# First name matched, but not found :( daniel daniele ronca
# First name matched, but not found :( daniel daniel zherenkov
# First name matched, but not found :( daniel daniela knstle
# First name matched, but not found :( daniel daniel schwarz
# Full name matched daniel r
# First name matched, but not found :( daniel daniela knstle
# Full name matched daniel schwarz
# First name matched, but not found :( daniel daniela knstle
# Your Job Position matched!!! daniel daniel schwarz
# Full name matched daniele ronca
# First name matched, but not found :( daniil daniil matkov
# Full name matched daniil tykheev
# Full name matched daria elson
# First name matched, but not found :( daria daria elson
# First name matched, but not found :( daria daria lezhai
# First name matched, but not found :( daria daria elson
# Full name matched daria lezhai
# First name matched, but not found :( daria daria elson
# First name matched, but not found :( daria daria lezhai
# Full name matched darrena mamm
# Last name from full name matched david dave feldman
# First name matched, but not found :( david jona david hoffmann
# Last name from full name matched david david grund
# Last name from full name matched hoffmann david hoffmann
# First name matched, but not found :( david jona david hoffmann
# Last name from full name matched david david wenk
# Full name matched davud samadov
# Last name from full name matched rakshit debarati rakshit
# First name matched, but not found :( denis dmitry deniskin
# Full name matched denis liggeri
# First name matched, but not found :( denis dmitry deniskin
# First name matched, but not found :( denis denis liggeri
# Full name matched denis zlobin
# First name matched, but not found :( deniz deniz ozkan
# Full name matched derek myers
# Full name matched despoina sarikou
# Full name matched dheeraj suvarna
# Full name matched dilan gevsek
# Last name from full name matched malyshenko dima malyshenko
# Full name matched dmitry deniskin
# Full name matched dominik hess
# Last name from full name matched kress dominik kress
# First name matched, but not found :( dominik dominik hess
# First name matched, but not found :( dominik dominik kress
# Full name matched dulano asalemo
# Full name matched duroseme taylor
# Full name matched egor zakharov
# Your Job Position matched!!! ekaterina ekaterina zenkevich
# Last name from full name matched zenkevich ekaterina zenkevich
# Full name matched eleftherios christou
# Full name matched elena berendeeva
# First name matched, but not found :( elena elena berendeeva
# First name matched, but not found :( elena elena sergiampietri
# First name matched, but not found :( elena elena berendeeva
# Full name matched elena sergiampietri
# First name matched, but not found :( elena elena berendeeva
# First name matched, but not found :( elena elena sergiampietri
# First name matched, but not found :( eli elisabeta g
# First name matched, but not found :( eli marcin belinski
# First name matched, but not found :( eli elia jona kargruber
# First name matched, but not found :( eli elif zakmak
# First name matched, but not found :( eli elisa schenke
# First name matched, but not found :( eli felix dahlmeyer
# Full name matched eli cohen
# Last name from full name matched kargruber elia kargruber
# First name matched, but not found :( elif elif zakmak
# Full name matched elif bakkal
# First name matched, but not found :( elif elif zakmak
# First name matched, but not found :( elif elif bakkal
# First name matched, but not found :( elisa elisabeta g
# First name matched, but not found :( elisa elisa schenke
# Full name matched elisa marku
# First name matched, but not found :( elisa elisabeta g
# First name matched, but not found :( elisa elisa schenke
# First name matched, but not found :( elisa elisa marku
# Last name from full name matched hirvensalo eliza hirvensalo
# Full name matched elliot altham
# Last name from full name matched berg else berg
# Full name matched emanoil topalov
# Full name matched emanuele libralato
# First name matched, but not found :( erin catherine windorf
# First name matched, but not found :( erin diane catherine gmez casas
# Your Job Position matched!!! erin ekaterina zenkevich
# Choose your role matched!!! esther esther vidal andreu
# Full name matched evgenia adam
# Full name matched evgeniia golubeva
# Full name matched ewa kiwus
# First name matched, but not found :( fabian marcin fabianczyk
# Full name matched fabian kleeberger
# First name matched, but not found :( fabian marcin fabianczyk
# First name matched, but not found :( fabian fabian kleeberger
# Last name from full name matched zagel fabian zag
# Full name matched fabio muroni
# Full name matched fabius weiner
# Full name matched faisal khushnood
# Full name matched farideh samadi
# Full name matched felix dahlmeyer
# First name matched, but not found :( felix felix dahlmeyer
# Full name matched felix preuss
# Full name matched fernanda pugliero
# Full name matched filippo palmieri
# First name matched, but not found :( florian florian straub
# Full name matched florian bonnet
# Full name matched florian straub
# Full name matched francesco paltrinieri
# Your Job Position matched!!! gaurav gaurav gulrajani
# Full name matched gautami pandit
# Last name from full name matched george george gibson
# Full name matched georgiana ciobotaru
# Full name matched giacomo giorgianni
# First name matched, but not found :( giacomo giacomo giorgianni
# First name matched, but not found :( gina regina hell neufeld
# Full name matched girish nalwade
# Full name matched grace hur
# Last name from full name matched bras gregoire bras
# Full name matched hadi attaran
# Full name matched hamlet hayrapetyan
# Last name from full name matched naqvi hasan naqvi
# Full name matched hashir rizwan
# Full name matched hayyaan ahmad
# Full name matched heorhi talochka
# Full name matched hiba ganta
# Full name matched hiya gaine
# Full name matched hosna shayani
# First name matched, but not found :( hussam hussam al alfe
# Full name matched iasmina craciun
# Full name matched ifrah khanyaree
# First name matched, but not found :( igor igor lahr
# First name matched, but not found :( igor bella grigoryants
# Full name matched igor lahr
# First name matched, but not found :( ilan dilan gevsek
# Your Job Position matched!!! ilan milana magurina
# Full name matched ilya blokh
# First name matched, but not found :( ilya ilya blokh
# Full name matched ilya egorov
# First name matched, but not found :( ilya ilya blokh
# First name matched, but not found :( ilya ilya egorov
# Full name matched indah harahap
# Full name matched ines jordan
# First name matched, but not found :( ira muhammad banirahma syahroni
# First name matched, but not found :( ira ana paula miranda
# First name matched, but not found :( ira vinicio oliveira
# First name matched, but not found :( ira nuno moreira
# First name matched, but not found :( ira kira valah
# First name matched, but not found :( iren irene orsa fanton
# Last name from full name matched seres iren seres
# First name matched, but not found :( irene irene orsa fanton
# Choose your role matched!!! irina irina reinerth
# Full name matched irina reinerth
# Your Job Position matched!!! irina irina reinerth
# First name matched, but not found :( irina irina reinerth
# First name matched, but not found :( irina irina puca
# Full name matched irma gagulia
# Full name matched isabella beck
# First name matched, but not found :( isabelle isabelle bed sheher
# Full name matched iswarya sakthivel
# Full name matched itir ergin
# Last name from full name matched andres iuliana petrescu
# First name matched, but not found :( ivan caitlin sullivan
# First name matched, but not found :( ivan ivan rublev
# First name matched, but not found :( ivan ivan kow
# Full name matched ivan dudarev
# First name matched, but not found :( ivan caitlin sullivan
# Full name matched ivan rublev
# Full name matched jack lancaster
# Full name matched jakub uniejewski
# Full name matched janine magayanes
# Full name matched jannik schewe
# First name matched, but not found :( javier javier garca latorre
# First name matched, but not found :( jess jessica he
# Last name from full name matched perrevoort jil perrevoort
# Full name matched jitesh nayak
# First name matched, but not found :( joanna joanna wilkans
# Full name matched joanna wilkans
# First name matched, but not found :( johannes johannes holl
# First name matched, but not found :( johannes johannes wrubel
# First name matched, but not found :( johannes johannes schweig
# Full name matched johannes holl
# First name matched, but not found :( johannes johannes holl
# First name matched, but not found :( johannes johannes wrubel
# Full name matched johannes schweig
# First name matched, but not found :( johannes johannes holl
# Full name matched johannes wrubel
# Full name matched john ngo
# Choose your role matched!!! juan juan jose mendoza santana
# Full name matched jules nijskens
# First name matched, but not found :( julia julia steier
# First name matched, but not found :( julia julian lindloff
# First name matched, but not found :( julia julian ringel
# Full name matched julia gentsch
# First name matched, but not found :( julia julia steier
# First name matched, but not found :( julia julian lindloff
# First name matched, but not found :( julia julian ringel
# First name matched, but not found :( julia julia gentsch
# Full name matched julia oehme
# Full name matched julia steier
# Full name matched julian lindloff
# First name matched, but not found :( julian julian lindloff
# Full name matched julian ringel
# First name matched, but not found :( jung senny sanjung agestriani
# Full name matched jyoti sharma
# Your Job Position matched!!! kai valeriia kaimashnikova
# Last name from full name matched berg kaisa berger
# First name matched, but not found :( karina karina hasler
# Full name matched karina hasler
# Full name matched karl villanueva
# Full name matched karolina kiszela
# Full name matched kate yanke
# Full name matched katharina andres
# First name matched, but not found :( katie katie hauser
# Full name matched kelly hsu
# First name matched, but not found :( ken ken kraft
# First name matched, but not found :( ken jules nijskens
# First name matched, but not found :( ken ken kraft
# Last name from full name matched matt ken r
# Full name matched khrystyna svarychevska
# Full name matched kimberly schmitt
# First name matched, but not found :( klara klara murzabekova
# Full name matched klara murzabekova
# Last name from full name matched maleki kourosh maleki
# Last name from full name matched chan krischan mertens
# Full name matched krishen mertens
# Last name from full name matched tian kristian herger
# Last name from full name matched ruseva kristina ruseva
# Full name matched krutika gopalakrishnan
# Full name matched krzysztof glistak
# Full name matched kseniia shyshkova
# Full name matched kunal kava
# Full name matched lara orrico
# Full name matched laura soto
# First name matched, but not found :( leon leonardo tognon
# Full name matched leon gerdes
# First name matched, but not found :( leonard leonardo tognon
# Full name matched leonardo tognon
# Full name matched linn legros
# First name matched, but not found :( lisa lisasophie rtze
# First name matched, but not found :( lisa elisabeta g
# First name matched, but not found :( lisa professor lisa wilson short
# Full name matched lisa trueblood
# Full name matched liya kachanova
# Full name matched louise plessis
# Full name matched lubena awan
# First name matched, but not found :( lucas lucas zandon
# Full name matched lucas minetti
# First name matched, but not found :( lucas lucas zandon
# First name matched, but not found :( lucas lucas minetti
# Full name matched lucas rech
# Last name from full name matched zandon lucas zandona
# Full name matched luis rieke
# Last name from full name matched suda luisa suda
# Last name from full name matched quan luiza munhos
# First name matched, but not found :( lukas sofiia lukashevych
# Full name matched lukas klehr
# Full name matched lydia dietrich
# Full name matched lynn ng
# Last name from full name matched grachev maksim grachev
# Last name from full name matched malik malik ebers
# Last name from full name matched malik malika umarova
# Full name matched manizeh dossa
# Last name from full name matched pandey manoj pandey
# First name matched, but not found :( manu emanuele libralato
# Full name matched manu raivio
# First name matched, but not found :( marc marcin fabianczyk
# First name matched, but not found :( marc marcin belinski
# First name matched, but not found :( marc marc boner
# First name matched, but not found :( marc marcos rubio rubio
# First name matched, but not found :( marc marcin fabianczyk
# First name matched, but not found :( marc marcin belinski
# Full name matched marc boner
# First name matched, but not found :( marcin marcin fabianczyk
# Full name matched marcin belinski
# Full name matched marcin fabianczyk
# First name matched, but not found :( marco marcos rubio rubio
# First name matched, but not found :( marcos marcos rubio rubio
# Last name from full name matched rubio marcos rubio
# Full name matched mariliis algma
# First name matched, but not found :( maria maria teneva
# First name matched, but not found :( maria mariano fernndez cocirio
# First name matched, but not found :( maria maria teneva
# First name matched, but not found :( maria mariano fernndez cocirio
# First name matched, but not found :( maria maria teneva
# First name matched, but not found :( marie annemarie sagner
# First name matched, but not found :( marie mariella gruensteidl
# Full name matched marie aurhammer
# First name matched, but not found :( marie annemarie sagner
# First name matched, but not found :( marie mariella gruensteidl
# First name matched, but not found :( marie marie aurhammer
# Last name from full name matched gruensteidl mariella grunsteidl
# Your Job Position matched!!! mario mario schwarz
# Last name from full name matched schwarz mario schwarz
# First name matched, but not found :( mark elisa marku
# Full name matched marta osowiecka
# First name matched, but not found :( martin jeanluc herv  martinettidubuisson europaunion paris
# Full name matched martin klein
# First name matched, but not found :( martin jeanluc herv  martinettidubuisson europaunion paris
# First name matched, but not found :( martin martin klein
# Last name from full name matched rosenmejer martin rosenmejer
# Full name matched masha lutsenko
# Full name matched mason jeong
# Last name from full name matched berg mathis lichtenberger
# Last name from full name matched matt matt a
# Last name from full name matched matt matt roskovec
# Last name from full name matched matt matteo donini
# Last name from full name matched matt matteo fava
# Last name from full name matched matt matteo kubuc
# Last name from full name matched matt matthias diener
# Last name from full name matched matt matthias siwy
# Last name from full name matched matt matthieu sloves
# First name matched, but not found :( maurice maurice zurstraen
# First name matched, but not found :( max max scheidlock
# First name matched, but not found :( max max ostapenko
# First name matched, but not found :( max maximilian walzel von wiesentreu
# Full name matched max beitler
# First name matched, but not found :( max max scheidlock
# First name matched, but not found :( max max ostapenko
# First name matched, but not found :( max maximilian walzel von wiesentreu
# First name matched, but not found :( max max beitler
# First name matched, but not found :( max max grachev
# Last name from full name matched hess max heds
# First name matched, but not found :( max max scheidlock
# Full name matched max ostapenko
# Full name matched max scheidlock
# Last name from full name matched wiesentreu maximilian wiesentreu
# Full name matched maycon stamboroski
# Full name matched mehdi eyvazzadeh
# Last name from full name matched ercan mehmet ercan
# Last name from full name matched behar meltem behar
# First name matched, but not found :( merve merve salmaz
# Full name matched merve salmaz
# Full name matched michele cerullo
# First name matched, but not found :( michele michele cerullo
# Full name matched michele fumagalli
# Last name from full name matched tian michelle tian
# Full name matched miji lee
# Last name from full name matched berg mikhail grinberg
# Full name matched milana magurina
# Full name matched milena fagandini
# Full name matched mircea giurca
# Full name matched miriam hutter
# Your Job Position matched!!! mohamed mohamed salah
# Full name matched mohamed salah
# Full name matched mohit bansal
# Full name matched mojgan behravan
# Full name matched mojtaba fattahi
# Full name matched mridul jain
# Last name from full name matched verma mritunjay verma
# Last name from full name matched ahmed musavvir ahmed
# Full name matched myles sutholt
# Last name from full name matched nadi nada elnadi
# First name matched, but not found :( nadine nadine radetzki
# Full name matched nadine verbeek
# Full name matched nail valiyev
# Last name from full name matched lange nanette lange
# Your Job Position matched!!! natalia natalia pnshina
# First name matched, but not found :( natalia natalia pnshina
# Last name from full name matched filvarova natalia filvarova
# Your Job Position matched!!! natalia natalia pnshina
# First name matched, but not found :( natalia natalia pnshina
# First name matched, but not found :( natalia  natalia filvarova
# First name matched, but not found :( natalia natalia anastasova
# First name matched, but not found :( natalia natalia petrova
# First name matched, but not found :( natalia natalia pnshina
# First name matched, but not found :( natalia  natalia filvarova
# Last name from full name matched petrov natalia petrova
# Full name matched nataliia senatorova
# Full name matched neha george
# First name matched, but not found :( nick cindy janicke
# Last name from full name matched stbe nick stube
# Last name from full name matched nardo nicola nardo
# Full name matched nicolai brunner
# Full name matched nicole calderon
# Full name matched nihad zeitouny
# Full name matched nikita zavyalov
# Full name matched niklas springer
# Full name matched nikola domazet
# Full name matched nina mannheimer
# First name matched, but not found :( nina nina mannheimer
# Full name matched nina untch
# First name matched, but not found :( nina nina mannheimer
# First name matched, but not found :( nina nina untch
# Full name matched nirvan mahat
# Last name from full name matched kumari nisha kumari
# First name matched, but not found :( nitin nitin nikesh
# Full name matched niv david
# Full name matched nuno moreira
# Full name matched nuwan withanage
# Full name matched oguz celikada
# First name matched, but not found :( ola bola oyebo
# First name matched, but not found :( ola nicola di nardo
# First name matched, but not found :( ola nikola domazet
# Full name matched olaf lenzmann
# Full name matched oleksii klochai
# Full name matched olena shapoval
# First name matched, but not found :( olga olga p
# First name matched, but not found :( oli carolina torres arzamendi
# First name matched, but not found :( oli benedetta montagnoli
# First name matched, but not found :( oli vinicio oliveira
# First name matched, but not found :( oli karolina kiszela
# First name matched, but not found :( oli adrian molina
# Last name from full name matched omotola oluwanifemi omotola
# First name matched, but not found :( olya olya l
# Full name matched oskar salmhofer
# Full name matched ovidiu oanca
# Full name matched partha dash
# First name matched, but not found :( partha partha dash
# Full name matched pasquale romito
# Full name matched patrick beeker
# Last name from full name matched castro paula castro
# Last name from full name matched castro paulo ferreira
# Last name from full name matched lubis permatasari lubis
# First name matched, but not found :( peter peter rubarth
# First name matched, but not found :( peter snke peters
# Full name matched peter rubarth
# First name matched, but not found :( philip philipp tessmann
# Full name matched philip homnack
# First name matched, but not found :( philipp philipp tessmann
# Full name matched philipp baumer
# First name matched, but not found :( philipp philipp tessmann
# First name matched, but not found :( philipp philipp baumer
# Full name matched philipp schimmelfennig
# Full name matched philipp tessmann
# Full name matched phuc nguyen
# First name matched, but not found :( pia pia hsdorff
# First name matched, but not found :( pia christopher piazza
# Full name matched piotr tomaszewski
# Full name matched prajwal negapettam
# Full name matched prashanth veeranki
# Full name matched quezia barrozo
# Last name from full name matched ebek radomir sebek
# Full name matched radu lupu
# Full name matched rafael weninger
# First name matched, but not found :( rahman abdelrahman elfar
# First name matched, but not found :( rahman abdelrahman abdo wahba
# Last name from full name matched quan rahman shafiee
# First name matched, but not found :( rahul rahul ranjan
# Full name matched rahul ranjan
# Full name matched rajesh chowdary
# Full name matched ramin amirov
# Full name matched ramzy ismail
# First name matched, but not found :( rao masood rao
# First name matched, but not found :( rao sanjeev rao
# Last name from full name matched neufeld regina neufeld
# Full name matched renata iwamoto
# Full name matched riccardo costi
# First name matched, but not found :( riccardo riccardo costi
# First name matched, but not found :( richard chase richards
# Last name from full name matched tjahjono rifqi tjahyono
# Full name matched robert lange
# First name matched, but not found :( robin robin rajan
# Full name matched roland butler
# First name matched, but not found :( roman maggie romano
# Your Job Position matched!!! roman roman prys
# First name matched, but not found :( roman maggie romano
# Last name from full name matched prys roman prysiazhniuk
# Full name matched rosario marrazzo
# Full name matched ross kinmont
# Full name matched roswell balentien
# Last name from full name matched islam rubaiyat islam
# Full name matched ruko kuga
# Full name matched sabina radziush
# Full name matched sabrina luna
# First name matched, but not found :( sahil sahil gambhir
# Full name matched sahil aggarwal
# Full name matched sahil gambhir
# First name matched, but not found :( sahil sahil gambhir
# First name matched, but not found :( sahil sahil aggarwal
# Full name matched saki cansev
# Full name matched salvatorina rassu
# First name matched, but not found :( sam sameer rizwan qidwai
# Full name matched sam abdullaev
# First name matched, but not found :( sam sameer rizwan qidwai
# First name matched, but not found :( sam sam abdullaev
# First name matched, but not found :( sam sam nurick
# First name matched, but not found :( sam samuel ghebreab
# First name matched, but not found :( sam hussam al alfe
# First name matched, but not found :( sam sam swasey
# First name matched, but not found :( sam davud samadov
# First name matched, but not found :( sam farideh samadi
# First name matched, but not found :( sam sneha samanta
# Last name from full name matched qidwai sameer qidwai
# Full name matched samuel ghebreab
# Full name matched sanjana laddha
# Full name matched sanjeev rao
# Full name matched sanjiv murali
# Last name from full name matched agestriani sanjung agestriani
# Full name matched sanna tietjen
# Last name from full name matched kumar santhosh kumar
# Last name from full name matched kumar santhosh ramasetty
# Full name matched sanyam arya
# Full name matched saptarshi baksi
# Your Job Position matched!!! sara sara pattacini
# First name matched, but not found :( sara sara pattacini
# Full name matched sara santanen
# First name matched, but not found :( sarah sarah greinermiethe
# Last name from full name matched haider sarmad haider
# Full name matched sarvesh regmi
# Full name matched satoru teshima
# Full name matched saurabh midha
# Full name matched savani nimonkar
# Full name matched sean kress
# Last name from full name matched tian sebastian nordenbruch
# First name matched, but not found :( seda seda bavas
# Full name matched seda baskan
# Full name matched seda bavas
# Full name matched sergey zadyraka
# Full name matched seyma tuzer
# Last name from full name matched butt shahid butt
# Full name matched shantanu dikshit
# First name matched, but not found :( shay hosna shayani
# Full name matched sheena antonios
# Last name from full name matched sherif sherif ragab
# Full name matched shilpa baweja
# Last name from full name matched wang shirlie wang
# Full name matched shivam runthala
# Full name matched shruthi subramanian
# Full name matched shubha pallavi
# Full name matched shubina roy
# Full name matched shuhrat pirnazarzoda
# First name matched, but not found :( shuvam shuvam kumar sah
# Full name matched sidra aziz
# Full name matched siena chan
# Full name matched silvia lodato
# First name matched, but not found :( simon simon petrov
# Full name matched simon hicks
# Full name matched simon petrov
# Full name matched sindhu maiyya
# Full name matched snezhanna mineeva
# Full name matched sofia siepi
# Full name matched sofiia lukashevych
# Full name matched sonya pobiedimska
# Full name matched soumitra sahu
# First name matched, but not found :( soumya soumya patil
# Full name matched soumya p
# Full name matched soumya patil
# Last name from full name matched chatterjee sreenjoy chatterjee
# Full name matched srishti maitra
# First name matched, but not found :( stephanie stephanie bschorr
# Full name matched stephanie kazalac
# Last name from full name matched kumar suresh kumar
# Last name from full name matched harahap suryani harahap
# First name matched, but not found :( tal natalia pnshina
# First name matched, but not found :( tal  natalia filvarova
# First name matched, but not found :( tal heorhi talochka
# First name matched, but not found :( tal andrea catalina motta
# First name matched, but not found :( tal natalia anastasova
# Full name matched tamer elhawari
# Full name matched tansel can
# Last name from full name matched tian tatiana dzhambinova
# Last name from full name matched tian tatiana pridchenko
# Full name matched tauheed ahmed
# Full name matched teena kumari
# First name matched, but not found :( thomas thomas seidl
# First name matched, but not found :( thomas thomas letschert
# Full name matched thomas abeln
# First name matched, but not found :( thomas thomas seidl
# First name matched, but not found :( thomas thomas letschert
# First name matched, but not found :( thomas thomas abeln
# Full name matched thomas manoila
# Full name matched thomas seidl
# Last name from full name matched almeida tiago almeida
# Full name matched tim heiler
# First name matched, but not found :( tim tim heiler
# First name matched, but not found :( tim timm kick
# Full name matched timm kick
# First name matched, but not found :( tom piotr tomaszewski
# First name matched, but not found :( tom piotr tomaszewski
# First name matched, but not found :( tom piotr tomaszewski
# Last name from full name matched singh udey singh
# Last name from full name matched kumar ugam kumar
# Full name matched uliana fedorova
# Full name matched umair sarfraz
# Full name matched usman nasir
# Full name matched utpal das
# Full name matched vadim bayandin
# Full name matched vaibhav malik
# Full name matched valdrin trena
# Last name from full name matched klein valentin klein
# Full name matched valentyna pilianska
# Last name from full name matched floresducoing valeria ducoing
# First name matched, but not found :( valerie valerie d
# Full name matched valeriia kaimashnikova
# Last name from full name matched kumar vibhu kumar
# First name matched, but not found :( victor victoria kotlova
# First name matched, but not found :( victor victor semencenco
# First name matched, but not found :( victor victoria kotlova
# Full name matched victor semencenco
# Full name matched victoria kotlova
# Full name matched vieri fidanza
# Full name matched vimal garg
# Full name matched vinicio oliveira
# Last name from full name matched sharma vipul sharma
# Last name from full name matched kotik vitali kotik
# First name matched, but not found :( volodymyr volodymyr lunov
# Full name matched volodymyr borodavchuk
# Full name matched volodymyr lunov
# Last name from full name matched choy waisum choy
# First name matched, but not found :( will willian magalhes
# Full name matched ximena hernandez
# Full name matched xiomara guillorme
# Your Job Position matched!!! xue xuejiaoshirlie wang
# Full name matched yanyan ma
# Full name matched yashvir chawla
# Full name matched yasir qureshi
# Full name matched yuliya gustap
# Full name matched yuri orthey
# Full name matched yusuf algan
# First name matched, but not found :( yusuf yusuf algan
# Full name matched zihan wang
# First name matched, but not found :( ziyad ziyad muhammed
# Full name matched zsolt pap
# First name matched, but not found :( zsolt zsolt pap
# Full name matched zulfiya malyshenko

# %%
data_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 666 entries, 0 to 680
# Data columns (total 70 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url                        666 non-null    object
#  1   title                      666 non-null    object
#  2   linkedinProfileUrl         615 non-null    object
#  3   email                      172 non-null    object
#  4   linkedinProfile            615 non-null    object
#  5   description                469 non-null    object
#  6   headline                   656 non-null    object
#  7   location                   656 non-null    object
#  8   firstName                  656 non-null    object
#  9   lastName                   666 non-null    object
#  10  fullName                   666 non-null    object
#  11  connectionDegree           656 non-null    object
#  12  vmid                       656 non-null    object
#  13  userId                     656 non-null    float64
#  14  linkedinSalesNavigatorUrl  656 non-null    object
#  15  connectionsCount           607 non-null    float64
#  16  connectionsUrl             656 non-null    object
#  17  mutualConnectionsUrl       656 non-null    object
#  18  company                    645 non-null    object
#  19  companyUrl                 583 non-null    object
#  20  jobTitle                   644 non-null    object
#  21  jobDescription             412 non-null    object
#  22  jobLocation                546 non-null    object
#  23  jobDateRange               635 non-null    object
#  24  jobDuration                634 non-null    object
#  25  company2                   628 non-null    object
#  26  companyUrl2                570 non-null    object
#  27  jobTitle2                  627 non-null    object
#  28  jobDescription2            499 non-null    object
#  29  jobLocation2               530 non-null    object
#  30  jobDateRange2              627 non-null    object
#  31  jobDuration2               626 non-null    object
#  32  school                     630 non-null    object
#  33  schoolUrl                  570 non-null    object
#  34  schoolDegree               616 non-null    object
#  35  schoolDescription          301 non-null    object
#  36  schoolDateRange            579 non-null    object
#  37  school2                    532 non-null    object
#  38  schoolUrl2                 449 non-null    object
#  39  schoolDegree2              514 non-null    object
#  40  schoolDescription2         229 non-null    object
#  41  schoolDateRange2           483 non-null    object
#  42  birthday                   259 non-null    object
#  43  allSkills                  623 non-null    object
#  44  skill1                     623 non-null    object
#  45  endorsement1               366 non-null    float64
#  46  skill2                     621 non-null    object
#  47  endorsement2               384 non-null    float64
#  48  skill3                     619 non-null    object
#  49  endorsement3               369 non-null    float64
#  50  skill4                     615 non-null    object
#  51  endorsement4               353 non-null    float64
#  52  skill5                     612 non-null    object
#  53  endorsement5               356 non-null    float64
#  54  skill6                     608 non-null    object
#  55  endorsement6               373 non-null    float64
#  56  baseUrl                    666 non-null    object
#  57  profileId                  656 non-null    object
#  58  timestamp                  666 non-null    object
#  59  subscribers                579 non-null    float64
#  60  mutualConnectionsText      565 non-null    object
#  61  imgUrl                     625 non-null    object
#  62  website                    165 non-null    object
#  63  mail                       172 non-null    object
#  64  connectedOn                177 non-null    object
#  65  error                      0 non-null      object
#  66  phoneNumber                30 non-null     object
#  67  partialScreenshot          409 non-null    object
#  68  facebookUrl                1 non-null      object
#  69  UserID                     479 non-null    float64
# dtypes: float64(10), object(60)
# memory usage: 385.6+ KB

# %%
unique_attendees2['Your Job Position'] = unique_attendees2['Your Job Position'].fillna('').str.lower()
unique_attendees2['Choose your role'] = unique_attendees2['Choose your role'].fillna('').str.lower()
unique_attendees2['Choose your role.1'] = unique_attendees2['Choose your role.1'].fillna('').str.lower()
unique_attendees2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   fullName            781 non-null    object
#  1   numEvents           781 non-null    int64
#  2   First Name          781 non-null    object
#  3   Surname             781 non-null    object
#  4   Email               781 non-null    object
#  5   Company             781 non-null    object
#  6   Your Job Position   781 non-null    object
#  7   Choose your role    781 non-null    object
#  8   Choose your role.1  781 non-null    object
#  9   Seniority           55 non-null     object
#  10  UserID              781 non-null    int64
# dtypes: int64(2), object(9)
# memory usage: 67.2+ KB

# %%
data_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 666 entries, 0 to 680
# Data columns (total 71 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url                        666 non-null    object
#  1   title                      666 non-null    object
#  2   linkedinProfileUrl         615 non-null    object
#  3   email                      666 non-null    object
#  4   linkedinProfile            615 non-null    object
#  5   description                469 non-null    object
#  6   headline                   656 non-null    object
#  7   location                   656 non-null    object
#  8   firstName                  656 non-null    object
#  9   lastName                   656 non-null    object
#  10  fullName                   666 non-null    object
#  11  connectionDegree           656 non-null    object
#  12  vmid                       656 non-null    object
#  13  userId                     656 non-null    float64
#  14  linkedinSalesNavigatorUrl  656 non-null    object
#  15  connectionsCount           607 non-null    float64
#  16  connectionsUrl             656 non-null    object
#  17  mutualConnectionsUrl       656 non-null    object
#  18  company                    666 non-null    object
#  19  companyUrl                 583 non-null    object
#  20  jobTitle                   644 non-null    object
#  21  jobDescription             412 non-null    object
#  22  jobLocation                546 non-null    object
#  23  jobDateRange               635 non-null    object
#  24  jobDuration                634 non-null    object
#  25  company2                   628 non-null    object
#  26  companyUrl2                570 non-null    object
#  27  jobTitle2                  627 non-null    object
#  28  jobDescription2            499 non-null    object
#  29  jobLocation2               530 non-null    object
#  30  jobDateRange2              627 non-null    object
#  31  jobDuration2               626 non-null    object
#  32  school                     630 non-null    object
#  33  schoolUrl                  570 non-null    object
#  34  schoolDegree               616 non-null    object
#  35  schoolDescription          301 non-null    object
#  36  schoolDateRange            579 non-null    object
#  37  school2                    532 non-null    object
#  38  schoolUrl2                 449 non-null    object
#  39  schoolDegree2              514 non-null    object
#  40  schoolDescription2         229 non-null    object
#  41  schoolDateRange2           483 non-null    object
#  42  birthday                   259 non-null    object
#  43  allSkills                  623 non-null    object
#  44  skill1                     623 non-null    object
#  45  endorsement1               366 non-null    float64
#  46  skill2                     621 non-null    object
#  47  endorsement2               384 non-null    float64
#  48  skill3                     619 non-null    object
#  49  endorsement3               369 non-null    float64
#  50  skill4                     615 non-null    object
#  51  endorsement4               353 non-null    float64
#  52  skill5                     612 non-null    object
#  53  endorsement5               356 non-null    float64
#  54  skill6                     608 non-null    object
#  55  endorsement6               373 non-null    float64
#  56  baseUrl                    666 non-null    object
#  57  profileId                  656 non-null    object
#  58  timestamp                  666 non-null    object
#  59  subscribers                579 non-null    float64
#  60  mutualConnectionsText      565 non-null    object
#  61  imgUrl                     625 non-null    object
#  62  website                    165 non-null    object
#  63  mail                       172 non-null    object
#  64  connectedOn                177 non-null    object
#  65  error                      0 non-null      object
#  66  phoneNumber                30 non-null     object
#  67  partialScreenshot          409 non-null    object
#  68  facebookUrl                1 non-null      object
#  69  UserID                     404 non-null    float64
#  70  Attendance                 666 non-null    int64
# dtypes: float64(10), int64(1), object(60)
# memory usage: 390.8+ KB

# %%
data_scraped_non_matched = data_scraped[data_scraped.UserID.isnull()]
data_scraped_non_matched = data_scraped_non_matched.drop(columns=['url','linkedinProfileUrl','linkedinProfile','facebookUrl','error','partialScreenshot','phoneNumber','connectedOn',
                                       'imgUrl','profileId','timestamp','schoolUrl','mutualConnectionsText','baseUrl','endorsement6','endorsement5',
                                      'endorsement4','endorsement3','endorsement2','endorsement1','birthday','mutualConnectionsUrl','connectionsUrl',
                                       'connectionsCount','vmid','userId','linkedinSalesNavigatorUrl','connectionDegree','subscribers','UserID'])

# %%
unique_attendees2
# Out:
#                 fullName  numEvents   First Name      Surname  \
# 0      abdelrahman elfar          2  abdelrahman        elfar
# 1             abdo wahba          1         abdo        wahba
# 2            abhi kasoju          1         abhi       kasoju
# 3       abhishek agarwal          1     abhishek      agarwal
# 4        abhishek khatri          1     abhishek       khatri
# ..                   ...        ...          ...          ...
# 776  zimmermann jennifer          1   zimmermann     jennifer
# 777    ziyad mohiyudheen          2        ziyad  mohiyudheen
# 778            zsolt pap          1        zsolt          pap
# 779        zsolt szrapko          1        zsolt      szrapko
# 780   zulfiya malyshenko          5      zulfiya   malyshenko
#
#                                   Email           Company Your Job Position  \
# 0           abdelrahman.alfar@gmail.com         insurance       engineering
# 1           abdelrahman.wahba@gmail.com            tucuvi
# 2             kasoju.abhinaya@gmail.com         insurance         analytics
# 3                aggyabhishek@gmail.com                             founder
# 4            abhishekkhatri@hotmail.com         talent.io             other
# ..                                  ...               ...               ...
# 776      zimmermannjennifer43@gmail.com  mediamarktsaturn             other
# 777                   mmziyad@gmail.com            spiced
# 778             papjanoszsolt@yahoo.com         verkstedt
# 779  szrapko.zsolt+eventbrite@gmail.com           academy           product
# 780               zulfia@malyshenko.com            babbel           product
#
#     Choose your role Choose your role.1 Seniority  UserID
# 0            product                          NaN       0
# 1                                             NaN       1
# 2                                             NaN       2
# 3                                             NaN       3
# 4                                             NaN       4
# ..               ...                ...       ...     ...
# 776                                           NaN     776
# 777                                           NaN     777
# 778        ecommerce                          NaN     778
# 779          product                          NaN     779
# 780          product                          NaN     780
#
# [781 rows x 11 columns]

# %%
data_scraped_non_matched
# Out:
#                                                  title email  \
# 0                                       patrick beeker   NaN
# 1    teena kumari – tech product support intern – h...   NaN
# 2     mischa gawronski – creative director – freelance   NaN
# 3                      shuvam kumar sah – web designer   NaN
# 4                               ayman chalhoub - clink   NaN
# ..                                                 ...   ...
# 676                ali akbar khan, mba - delivery hero   NaN
# 677              daniel lópez contreras - masterschool   NaN
# 678       rim bensouf - product owner - sporttotal ...   NaN
# 679        oguz celikada – berlin, berlin, deutschland   NaN
# 680              althaf ali mattummathodi - schaeffler   NaN
#
#                                            description  \
# 0    Experienced professional with the ability to c...
# 1    I am a Product Owner at World Simplified UG, a...
# 2    Passionate and challenging influencer in strat...
# 3    Designer & Problem Solver | CS Student | Aimin...
# 4                                                  NaN
# ..                                                 ...
# 676  Experienced CX and E-Commerce professional, wi...
# 677  - 100% Customer oriented professional\n- Stron...
# 678                                                NaN
# 679  Experienced professional in human-centric busi...
# 680                                                NaN
#
#                                               headline  \
# 0    General Manager - US Finance, Legal, HR, Accou...
# 1                Tech product support intern at Holidu
# 2                      IGP Network | Creative Director
# 3                 Making Interfaces Sexier - UI/UX/Dev
# 4                                     Product & Growth
# ..                                                 ...
# 676                         Global Customer Experience
# 677  Transforming Education, Customer Focused, avid...
# 678  Product Owner at Sporttotal.tv\n\nAgile leader...
# 679                         Digital Product Consultant
# 680                      R&D E-mobility at Schaeffler
#
#                              location     firstName        lastName  \
# 0    Carrollton, Texas, United States       patrick          beeker
# 1             Berlin, Berlin, Germany         teena          kumari
# 2             Berlin, Berlin, Germany        mischa       gawronski
# 3             Berlin, Berlin, Germany  shuvam kumar             sah
# 4             Berlin, Berlin, Germany         ayman        chalhoub
# ..                                ...           ...             ...
# 676           Berlin, Berlin, Germany     ali akbar        khan mba
# 677           Berlin, Berlin, Germany        daniel  lpez contreras
# 678          Berlin Metropolitan Area           rim         bensouf
# 679           Berlin, Berlin, Germany          oguz        celikada
# 680          Berlin Metropolitan Area    althaf ali   mattummathodi
#
#                      fullName                     company  \
# 0              patrick beeker               Orbis Systems
# 1                teena kumari                      Holidu
# 2            mischa gawronski                   Freelance
# 3            shuvam kumar sah    A.T.E.M. Management GmbH
# 4              ayman chalhoub                       Clink
# ..                        ...                         ...
# 676        ali akbar khan mba               Delivery Hero
# 677     daniel lpez contreras                Masterschool
# 678               rim bensouf  SPORTTOTAL TECHNOLOGY GmbH
# 679             oguz celikada                   Freelance
# 680  althaf ali mattummathodi                  Schaeffler
#
#                                      companyUrl  ...     schoolDateRange2  \
# 0    https://www.linkedin.com/company/25018031/  ...          1996 - 2001
# 1     https://www.linkedin.com/company/5257651/  ...  Dec 2014 - Jun 2020
# 2                                           NaN  ...                  NaN
# 3    https://www.linkedin.com/company/75730132/  ...  Aug 2021 - Jun 2022
# 4    https://www.linkedin.com/company/93780977/  ...                  NaN
# ..                                          ...  ...                  ...
# 676   https://www.linkedin.com/company/2393200/  ...          2009 - 2012
# 677  https://www.linkedin.com/company/75721942/  ...          2001 - 2007
# 678  https://www.linkedin.com/company/66650149/  ...  Sep 2009 - Oct 2011
# 679                                         NaN  ...          2008 - 2011
# 680    https://www.linkedin.com/company/305287/  ...          2013 - 2017
#
#                                              allSkills  \
# 0    Accounting, Management, Strategic Planning, Fo...
# 1    Market Research, Product Strategies, Team Lead...
# 2    Strategische Planung, Soziale Medien, Visuelle...
# 3    React.js, Java, JavaScript, Cascading Style Sh...
# 4    Product Marketing, Start-ups, Cross-functional...
# ..                                                 ...
# 676  Banking, Financial Analysis, Corporate Finance...
# 677  Public Speaking, Presentation Skills, Customer...
# 678  Business-to-Business (B2B), B2C, Over-the-Top ...
# 679  Human Computer Interaction, User Research, Qua...
# 680  Electrical Machines, Simulations, Gearboxes, G...
#
#                          skill1               skill2  \
# 0                    Accounting           Management
# 1               Market Research   Product Strategies
# 2          Strategische Planung       Soziale Medien
# 3                      React.js                 Java
# 4             Product Marketing            Start-ups
# ..                          ...                  ...
# 676                     Banking   Financial Analysis
# 677             Public Speaking  Presentation Skills
# 678  Business-to-Business (B2B)                  B2C
# 679  Human Computer Interaction        User Research
# 680         Electrical Machines          Simulations
#
#                                      skill3                            skill4  \
# 0                        Strategic Planning                       Forecasting
# 1                           Team Leadership  Cross-functional Team Leadership
# 2                    Visuelle Kommunikation                        Fotografie
# 3                                JavaScript      Cascading Style Sheets (CSS)
# 4          Cross-functional Team Leadership              Business Development
# ..                                      ...                               ...
# 676                       Corporate Finance              Portfolio Management
# 677  Customer Relationship Management (CRM)               Organization Skills
# 678              Over-the-Top Content (OTT)                      Sport stream
# 679                    Qualitative Research                       UX Research
# 680                               Gearboxes                Gear Manufacturing
#
#                          skill5                skill6  \
# 0    Organizational Development     Business Strategy
# 1              Project Planning  Business Development
# 2          Business Development     Critical Thinking
# 3         Front-End Development           Wireframing
# 4           Mobile Applications     Mobile Technology
# ..                          ...                   ...
# 676             Risk Management    Investment Banking
# 677          Account Management     Analytical Skills
# 678                        Jira      Agile Leadership
# 679        User Experience (UX)           Ethnography
# 680                    Simulink                MATLAB
#
#                      website mail
# 0                        NaN  NaN
# 1                        NaN  NaN
# 2                        NaN  NaN
# 3    dribbble.com/shuvam_sah  NaN
# 4                        NaN  NaN
# ..                       ...  ...
# 676                      NaN  NaN
# 677                      NaN  NaN
# 678                      NaN  NaN
# 679                      NaN  NaN
# 680                      NaN  NaN
#
# [666 rows x 40 columns]

# %%
unique_attendees2
# Out:
#                 fullName  numEvents   First Name      Surname  \
# 0      abdelrahman elfar          2  abdelrahman        elfar
# 1             abdo wahba          1         abdo        wahba
# 2            abhi kasoju          1         abhi       kasoju
# 3       abhishek agarwal          1     abhishek      agarwal
# 4        abhishek khatri          1     abhishek       khatri
# ..                   ...        ...          ...          ...
# 776  zimmermann jennifer          1   zimmermann     jennifer
# 777    ziyad mohiyudheen          2        ziyad  mohiyudheen
# 778            zsolt pap          1        zsolt          pap
# 779        zsolt szrapko          1        zsolt      szrapko
# 780   zulfiya malyshenko          5      zulfiya   malyshenko
#
#                                   Email           Company Your Job Position  \
# 0           abdelrahman.alfar@gmail.com         insurance       engineering
# 1           abdelrahman.wahba@gmail.com            tucuvi
# 2             kasoju.abhinaya@gmail.com         insurance         analytics
# 3                aggyabhishek@gmail.com                             founder
# 4            abhishekkhatri@hotmail.com         talent.io             other
# ..                                  ...               ...               ...
# 776      zimmermannjennifer43@gmail.com  mediamarktsaturn             other
# 777                   mmziyad@gmail.com            spiced
# 778             papjanoszsolt@yahoo.com         verkstedt
# 779  szrapko.zsolt+eventbrite@gmail.com           academy           product
# 780               zulfia@malyshenko.com            babbel           product
#
#     Choose your role Choose your role.1 Seniority  UserID
# 0            product                          NaN       0
# 1                                             NaN       1
# 2                                             NaN       2
# 3                                             NaN       3
# 4                                             NaN       4
# ..               ...                ...       ...     ...
# 776                                           NaN     776
# 777                                           NaN     777
# 778        ecommerce                          NaN     778
# 779          product                          NaN     779
# 780          product                          NaN     780
#
# [781 rows x 11 columns]

# %%
target_string = 'bartholomae' 
unique_attendees2[unique_attendees2['fullName'].str.contains(target_string, na=False) | 
          unique_attendees2['Surname'].str.contains( target_string, na=False)| 
                  unique_attendees2['Email'].str.contains(target_string, na=False)]
# Out:
#                fullName  numEvents First Name      Surname  \
# 168  daniel bartholomae          1     daniel  bartholomae
#
#                               Email  Company Your Job Position  \
# 168  daniel.bartholomae@optilyz.com  purpose           founder
#
#     Choose your role Choose your role.1 Seniority  UserID
# 168                                           CxO     168

# %%
target_string = 'bartholomae'
unique_attendees2[unique_attendees2['fullName'].str.contains(target_string, na=False) | 
          unique_attendees2['Surname'].str.contains( target_string, na=False)| 
                  unique_attendees2['Email'].str.contains(target_string, na=False)]

# %%
target_string = 'bartholomae'
data_scraped[data_scraped['lastName'].str.contains(target_string, na=False)]
# Out:
#                                      url                           title  \
# 112  https://linkedin.com/in/bartholomae  💻 daniel bartholomae - optilyz
#
#                            linkedinProfileUrl                    email  \
# 112  https://www.linkedin.com/in/bartholomae/  daniel@bartholomae.name
#
#                               linkedinProfile  \
# 112  https://www.linkedin.com/in/bartholomae/
#
#                                            description  \
# 112  If you want to connect, please add a note. I'm...
#
#                                       headline                 location  \
# 112  Entrepreneur, founder and tech enthusiast  Berlin, Berlin, Germany
#
#       firstName     lastName  ...  \
# 112  👨‍💻 daniel  bartholomae  ...
#
#                                                 imgUrl          website  \
# 112  https://media.licdn.com/dms/image/C4D03AQFqKHF...  startup-cto.net
#
#                         mail   connectedOn error      phoneNumber  \
# 112  daniel@bartholomae.name  May 11, 2023   NaN  +49 30 20847337
#
#     partialScreenshot facebookUrl UserID Attendance
# 112               NaN         NaN    NaN          0
#
# [1 rows x 71 columns]

# %%
target_string = 'olx'
unique_attendees2[unique_attendees2['fullName'].str.contains(target_string, na=False) | 
          unique_attendees2['Company'].str.contains( target_string, na=False)| 
                  unique_attendees2['Email'].str.contains(target_string, na=False)]
# Out:
#                fullName  numEvents First Name     Surname  \
# 442        martin klein          1     martin       klein
# 696  tatiana pridchenko          1    tatiana  pridchenko
#
#                         Email Company Your Job Position Choose your role  \
# 442  martin.klein@funktel.com     olx             other
# 696    tapridchenko@gmail.com     olx           student
#
#     Choose your role.1 Seniority  UserID
# 442                          NaN     442
# 696                          NaN     696

# %%
target_string = 'abhinav'
unique_attendees2[unique_attendees2['fullName'].str.contains(target_string, na=False) | 
          unique_attendees2['Company'].str.contains( target_string, na=False)| 
                  unique_attendees2['Email'].str.contains(target_string, na=False)]
# Out:
# Empty DataFrame
# Columns: [fullName, numEvents, First Name, Surname, Email, Company, Your Job Position, Choose your role, Choose your role.1, Seniority, UserID]
# Index: []

# %%
target_string = 'miranda' #matched by only last name
filtered_df[filtered_df['fullName'].str.contains(target_string, na=False) | 
          filtered_df['Surname'].str.contains( target_string, na=False)| 
                  filtered_df['Email'].str.contains(target_string, na=False)]
# Out:
#        fullName  numEvents First Name  Surname  \
# 55  ana miranda          1        ana  miranda
#
#                                Email    Company Your Job Position  \
# 55  apaulafernandesmiranda@gmail.com  akirolabs           product
#
#    Choose your role Choose your role.1 Seniority  UserID     _merge
# 55          product                          NaN      55  left_only

# %%
'miranda' in filtered_df['fullName']

# %%
filtered_df.loc[55,'fullName']
# Out:
# 'ana miranda'

# %%
'miranda' in filtered_df.loc[55,'fullName']
# Out:
# True

# %%
# Assuming unique_attendees2 is your DataFrame containing unique attendees with column UserID,
# and data_scraped is your DataFrame containing scraped data with column UserID

# Perform left join
merged_df = unique_attendees2.merge(data_scraped[['UserID']], on='UserID', how='left', indicator=True)

# Filter out rows where UserID from data_scraped is not null
filtered_df = merged_df[merged_df['_merge'] == 'left_only']

# %%
filtered_df
# Out:
#                   fullName  numEvents  First Name        Surname  \
# 1               abdo wahba          1        abdo          wahba
# 2              abhi kasoju          1        abhi         kasoju
# 3         abhishek agarwal          1    abhishek        agarwal
# 7    adithya krishnamurthy          2     adithya  krishnamurthy
# 8          aditya bhirangi          1      aditya       bhirangi
# ..                     ...        ...         ...            ...
# 773            zahra rouhi          1       zahra          rouhi
# 774            zaron arava          1       zaron          arava
# 776    zimmermann jennifer          1  zimmermann       jennifer
# 777      ziyad mohiyudheen          2       ziyad    mohiyudheen
# 779          zsolt szrapko          1       zsolt        szrapko
#
#                                   Email                    Company  \
# 1           abdelrahman.wahba@gmail.com                     tucuvi
# 2             kasoju.abhinaya@gmail.com                  insurance
# 3                aggyabhishek@gmail.com
# 7                 pkadithya90@gmail.com                  insurance
# 8      aditya_atul.bhirangi@edu.escp.eu                    memasik
# ..                                  ...                        ...
# 773                zahrarouhi@gmail.com  varshalalwani94@gmail.com
# 774               zaron.arava@gmail.com                    fintech
# 776      zimmermannjennifer43@gmail.com           mediamarktsaturn
# 777                   mmziyad@gmail.com                     spiced
# 779  szrapko.zsolt+eventbrite@gmail.com                    academy
#
#     Your Job Position Choose your role Choose your role.1 Seniority  UserID  \
# 1                                                               NaN       1
# 2           analytics                                           NaN       2
# 3             founder                                           NaN       3
# 7             product             lead                          NaN       7
# 8                                                               NaN       8
# ..                ...              ...                ...       ...     ...
# 773            design                                           NaN     773
# 774             other                                           NaN     774
# 776             other                                           NaN     776
# 777                                                             NaN     777
# 779           product          product                          NaN     779
#
#         _merge
# 1    left_only
# 2    left_only
# 3    left_only
# 7    left_only
# 8    left_only
# ..         ...
# 773  left_only
# 774  left_only
# 776  left_only
# 777  left_only
# 779  left_only
#
# [377 rows x 12 columns]

# %%
data_scraped_non_matched.to_csv('../raw_data/data_scraped_non_matched.csv')

# %%
filtered_df.to_csv('../raw_data/ids_non_matched.csv')

# %%
strin = "sdfssecretghth"

# %%
strin.str.contains("secret")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 strin.str.contains("secret")
#
# AttributeError: 'str' object has no attribute 'str'
